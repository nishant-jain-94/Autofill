# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.layers import Embedding
from nltk.tokenize import word_tokenize
import re

# %%
"""txt = re.sub('\,','',txt)
txt = re.sub('\?','',txt)
txt = re.sub('\(','',txt)
txt = re.sub('\)','',txt)
txt = re.sub('\:','',txt)
txt = re.sub('\;','',txt)
txt = re.sub('\'','',txt)
txt = re.sub('\!','',txt)
txt = re.sub('-','',txt)
txt = re.sub('\n','',txt)
txt = re.sub(' +',' ',txt)
"""

# %%
filename = "/home/user/Downloads/rnn-assignments/alice.txt"
txt = open(filename).read()
txt = txt.lower()
#txt = txt.replace(',.?!:;*',"")
txt = re.sub(r'[^\w\.]',' ',txt)

# %%
#tokenizing the input text
word_token = word_tokenize(txt)

# %%
# converting words to int
words = sorted(list(set(word_token)))
word_to_int = dict((w,i) for i,w in enumerate(words))

# reversed dict
reverse_dict = dict((word_to_int[i],i) for i in word_to_int)

# %%
# word and vocabulary count
n_words = len(word_token)
n_vocab = len(word_to_int)
print("Number of words : ",n_words)
print("Size of Vocabulary : ",n_vocab)
# Out:
# Number of words :  28326
# Size of Vocabulary :  2575

# %%
# parameters
window = 100
epoch = 1
batch_size = 256

# %%
# intialize arrays
x=[]
y=[]

# %%
# generating dataset
for i in range(0, n_words - window, 1):
    seq_in = word_token[i:i + window]
    seq_out = word_token[i + window]
    x.append([word_to_int[word] for word in seq_in])
    y.append(word_to_int[seq_out])
n_patterns = len(x)
print ("Dataset size : ", n_patterns)
# Out:
# Dataset size :  28226

# %%
# Reshaping input
x = np.reshape(x,(n_patterns, window, 1))
y = np_utils.to_categorical(y)

# %%
# Define the LSTM model
model = Sequential()
model.add(Embedding(n_vocab,100,input_length=window ))
model.add(LSTM(256, input_shape=(x.shape[1], x.shape[2]),return_sequences=True,implementation=2))
model.add(Dropout(0.2))
model.add(LSTM(128))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 100, 100)          257500
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100, 256)          365568
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100, 256)          0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 128)               197120
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2575)              332175
# =================================================================
# Total params: 1,152,363
# Trainable params: 1,152,363
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = np.reshape(x,(n_patterns, window))
x.shape
# Out:
# (28226, 100)

# %%
model.fit(x[:15000], y[:15000], epochs=epoch, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 12000 samples, validate on 3000 samples
# Epoch 1/1
# 12000/12000 [==============================] - 226s - loss: 6.5540 - acc: 0.0431 - val_loss: 6.1808 - val_acc: 0.0553

# %%
ans = model.predict_classes(x[0:300])
# Out:
# 300/300 [==============================] - 2s

# %%
# printing the original and predicted words
for i,j in zip(ans,range(0,200,1)):
    print("original sentence : ",word_token[j+95:j+100])
    print("predicted word : ",word_token[j+95:j+99]) 
    print(reverse_dict[i])
    print()
# Out:
# original sentence :  ['very', 'sleepy', 'and', 'stupid', 'whether']
# predicted word :  ['very', 'sleepy', 'and', 'stupid']
# the
#
# original sentence :  ['sleepy', 'and', 'stupid', 'whether', 'the']
# predicted word :  ['sleepy', 'and', 'stupid', 'whether']
# the
#
# original sentence :  ['and', 'stupid', 'whether', 'the', 'pleasure']
# predicted word :  ['and', 'stupid', 'whether', 'the']
# the
#
# original sentence :  ['stupid', 'whether', 'the', 'pleasure', 'of']
# predicted word :  ['stupid', 'whether', 'the', 'pleasure']
# the
#
# original sentence :  ['whether', 'the', 'pleasure', 'of', 'making']
# predicted word :  ['whether', 'the', 'pleasure', 'of']
# the
#
# original sentence :  ['the', 'pleasure', 'of', 'making', 'a']
# predicted word :  ['the', 'pleasure', 'of', 'making']
# the
#
# original sentence :  ['pleasure', 'of', 'making', 'a', 'daisy']
# predicted word :  ['pleasure', 'of', 'making', 'a']
# the
#
# original sentence :  ['of', 'making', 'a', 'daisy', 'chain']
# predicted word :  ['of', 'making', 'a', 'daisy']
# the
#
# original sentence :  ['making', 'a', 'daisy', 'chain', 'would']
# predicted word :  ['making', 'a', 'daisy', 'chain']
# the
#
# original sentence :  ['a', 'daisy', 'chain', 'would', 'be']
# predicted word :  ['a', 'daisy', 'chain', 'would']
# the
#
# original sentence :  ['daisy', 'chain', 'would', 'be', 'worth']
# predicted word :  ['daisy', 'chain', 'would', 'be']
# the
#
# original sentence :  ['chain', 'would', 'be', 'worth', 'the']
# predicted word :  ['chain', 'would', 'be', 'worth']
# the
#
# original sentence :  ['would', 'be', 'worth', 'the', 'trouble']
# predicted word :  ['would', 'be', 'worth', 'the']
# the
#
# original sentence :  ['be', 'worth', 'the', 'trouble', 'of']
# predicted word :  ['be', 'worth', 'the', 'trouble']
# the
#
# original sentence :  ['worth', 'the', 'trouble', 'of', 'getting']
# predicted word :  ['worth', 'the', 'trouble', 'of']
# the
#
# original sentence :  ['the', 'trouble', 'of', 'getting', 'up']
# predicted word :  ['the', 'trouble', 'of', 'getting']
# the
#
# original sentence :  ['trouble', 'of', 'getting', 'up', 'and']
# predicted word :  ['trouble', 'of', 'getting', 'up']
# the
#
# original sentence :  ['of', 'getting', 'up', 'and', 'picking']
# predicted word :  ['of', 'getting', 'up', 'and']
# the
#
# original sentence :  ['getting', 'up', 'and', 'picking', 'the']
# predicted word :  ['getting', 'up', 'and', 'picking']
# the
#
# original sentence :  ['up', 'and', 'picking', 'the', 'daisies']
# predicted word :  ['up', 'and', 'picking', 'the']
# the
#
# original sentence :  ['and', 'picking', 'the', 'daisies', 'when']
# predicted word :  ['and', 'picking', 'the', 'daisies']
# the
#
# original sentence :  ['picking', 'the', 'daisies', 'when', 'suddenly']
# predicted word :  ['picking', 'the', 'daisies', 'when']
# the
#
# original sentence :  ['the', 'daisies', 'when', 'suddenly', 'a']
# predicted word :  ['the', 'daisies', 'when', 'suddenly']
# the
#
# original sentence :  ['daisies', 'when', 'suddenly', 'a', 'white']
# predicted word :  ['daisies', 'when', 'suddenly', 'a']
# the
#
# original sentence :  ['when', 'suddenly', 'a', 'white', 'rabbit']
# predicted word :  ['when', 'suddenly', 'a', 'white']
# the
#
# original sentence :  ['suddenly', 'a', 'white', 'rabbit', 'with']
# predicted word :  ['suddenly', 'a', 'white', 'rabbit']
# the
#
# original sentence :  ['a', 'white', 'rabbit', 'with', 'pink']
# predicted word :  ['a', 'white', 'rabbit', 'with']
# the
#
# original sentence :  ['white', 'rabbit', 'with', 'pink', 'eyes']
# predicted word :  ['white', 'rabbit', 'with', 'pink']
# the
#
# original sentence :  ['rabbit', 'with', 'pink', 'eyes', 'ran']
# predicted word :  ['rabbit', 'with', 'pink', 'eyes']
# the
#
# original sentence :  ['with', 'pink', 'eyes', 'ran', 'close']
# predicted word :  ['with', 'pink', 'eyes', 'ran']
# the
#
# original sentence :  ['pink', 'eyes', 'ran', 'close', 'by']
# predicted word :  ['pink', 'eyes', 'ran', 'close']
# the
#
# original sentence :  ['eyes', 'ran', 'close', 'by', 'her']
# predicted word :  ['eyes', 'ran', 'close', 'by']
# the
#
# original sentence :  ['ran', 'close', 'by', 'her', '.']
# predicted word :  ['ran', 'close', 'by', 'her']
# the
#
# original sentence :  ['close', 'by', 'her', '.', 'there']
# predicted word :  ['close', 'by', 'her', '.']
# the
#
# original sentence :  ['by', 'her', '.', 'there', 'was']
# predicted word :  ['by', 'her', '.', 'there']
# the
#
# original sentence :  ['her', '.', 'there', 'was', 'nothing']
# predicted word :  ['her', '.', 'there', 'was']
# the
#
# original sentence :  ['.', 'there', 'was', 'nothing', 'so']
# predicted word :  ['.', 'there', 'was', 'nothing']
# the
#
# original sentence :  ['there', 'was', 'nothing', 'so', 'very']
# predicted word :  ['there', 'was', 'nothing', 'so']
# the
#
# original sentence :  ['was', 'nothing', 'so', 'very', 'remarkable']
# predicted word :  ['was', 'nothing', 'so', 'very']
# the
#
# original sentence :  ['nothing', 'so', 'very', 'remarkable', 'in']
# predicted word :  ['nothing', 'so', 'very', 'remarkable']
# the
#
# original sentence :  ['so', 'very', 'remarkable', 'in', 'that']
# predicted word :  ['so', 'very', 'remarkable', 'in']
# the
#
# original sentence :  ['very', 'remarkable', 'in', 'that', 'nor']
# predicted word :  ['very', 'remarkable', 'in', 'that']
# the
#
# original sentence :  ['remarkable', 'in', 'that', 'nor', 'did']
# predicted word :  ['remarkable', 'in', 'that', 'nor']
# the
#
# original sentence :  ['in', 'that', 'nor', 'did', 'alice']
# predicted word :  ['in', 'that', 'nor', 'did']
# the
#
# original sentence :  ['that', 'nor', 'did', 'alice', 'think']
# predicted word :  ['that', 'nor', 'did', 'alice']
# the
#
# original sentence :  ['nor', 'did', 'alice', 'think', 'it']
# predicted word :  ['nor', 'did', 'alice', 'think']
# the
#
# original sentence :  ['did', 'alice', 'think', 'it', 'so']
# predicted word :  ['did', 'alice', 'think', 'it']
# the
#
# original sentence :  ['alice', 'think', 'it', 'so', 'very']
# predicted word :  ['alice', 'think', 'it', 'so']
# the
#
# original sentence :  ['think', 'it', 'so', 'very', 'much']
# predicted word :  ['think', 'it', 'so', 'very']
# the
#
# original sentence :  ['it', 'so', 'very', 'much', 'out']
# predicted word :  ['it', 'so', 'very', 'much']
# the
#
# original sentence :  ['so', 'very', 'much', 'out', 'of']
# predicted word :  ['so', 'very', 'much', 'out']
# the
#
# original sentence :  ['very', 'much', 'out', 'of', 'the']
# predicted word :  ['very', 'much', 'out', 'of']
# the
#
# original sentence :  ['much', 'out', 'of', 'the', 'way']
# predicted word :  ['much', 'out', 'of', 'the']
# the
#
# original sentence :  ['out', 'of', 'the', 'way', 'to']
# predicted word :  ['out', 'of', 'the', 'way']
# the
#
# original sentence :  ['of', 'the', 'way', 'to', 'hear']
# predicted word :  ['of', 'the', 'way', 'to']
# the
#
# original sentence :  ['the', 'way', 'to', 'hear', 'the']
# predicted word :  ['the', 'way', 'to', 'hear']
# the
#
# original sentence :  ['way', 'to', 'hear', 'the', 'rabbit']
# predicted word :  ['way', 'to', 'hear', 'the']
# the
#
# original sentence :  ['to', 'hear', 'the', 'rabbit', 'say']
# predicted word :  ['to', 'hear', 'the', 'rabbit']
# the
#
# original sentence :  ['hear', 'the', 'rabbit', 'say', 'to']
# predicted word :  ['hear', 'the', 'rabbit', 'say']
# the
#
# original sentence :  ['the', 'rabbit', 'say', 'to', 'itself']
# predicted word :  ['the', 'rabbit', 'say', 'to']
# the
#
# original sentence :  ['rabbit', 'say', 'to', 'itself', 'oh']
# predicted word :  ['rabbit', 'say', 'to', 'itself']
# the
#
# original sentence :  ['say', 'to', 'itself', 'oh', 'dear']
# predicted word :  ['say', 'to', 'itself', 'oh']
# the
#
# original sentence :  ['to', 'itself', 'oh', 'dear', 'oh']
# predicted word :  ['to', 'itself', 'oh', 'dear']
# the
#
# original sentence :  ['itself', 'oh', 'dear', 'oh', 'dear']
# predicted word :  ['itself', 'oh', 'dear', 'oh']
# the
#
# original sentence :  ['oh', 'dear', 'oh', 'dear', 'i']
# predicted word :  ['oh', 'dear', 'oh', 'dear']
# the
#
# original sentence :  ['dear', 'oh', 'dear', 'i', 'shall']
# predicted word :  ['dear', 'oh', 'dear', 'i']
# the
#
# original sentence :  ['oh', 'dear', 'i', 'shall', 'be']
# predicted word :  ['oh', 'dear', 'i', 'shall']
# the
#
# original sentence :  ['dear', 'i', 'shall', 'be', 'late']
# predicted word :  ['dear', 'i', 'shall', 'be']
# the
#
# original sentence :  ['i', 'shall', 'be', 'late', 'when']
# predicted word :  ['i', 'shall', 'be', 'late']
# the
#
# original sentence :  ['shall', 'be', 'late', 'when', 'she']
# predicted word :  ['shall', 'be', 'late', 'when']
# the
#
# original sentence :  ['be', 'late', 'when', 'she', 'thought']
# predicted word :  ['be', 'late', 'when', 'she']
# the
#
# original sentence :  ['late', 'when', 'she', 'thought', 'it']
# predicted word :  ['late', 'when', 'she', 'thought']
# the
#
# original sentence :  ['when', 'she', 'thought', 'it', 'over']
# predicted word :  ['when', 'she', 'thought', 'it']
# the
#
# original sentence :  ['she', 'thought', 'it', 'over', 'afterwards']
# predicted word :  ['she', 'thought', 'it', 'over']
# the
#
# original sentence :  ['thought', 'it', 'over', 'afterwards', 'it']
# predicted word :  ['thought', 'it', 'over', 'afterwards']
# the
#
# original sentence :  ['it', 'over', 'afterwards', 'it', 'occurred']
# predicted word :  ['it', 'over', 'afterwards', 'it']
# the
#
# original sentence :  ['over', 'afterwards', 'it', 'occurred', 'to']
# predicted word :  ['over', 'afterwards', 'it', 'occurred']
# the
#
# original sentence :  ['afterwards', 'it', 'occurred', 'to', 'her']
# predicted word :  ['afterwards', 'it', 'occurred', 'to']
# the
#
# original sentence :  ['it', 'occurred', 'to', 'her', 'that']
# predicted word :  ['it', 'occurred', 'to', 'her']
# the
#
# original sentence :  ['occurred', 'to', 'her', 'that', 'she']
# predicted word :  ['occurred', 'to', 'her', 'that']
# the
#
# original sentence :  ['to', 'her', 'that', 'she', 'ought']
# predicted word :  ['to', 'her', 'that', 'she']
# the
#
# original sentence :  ['her', 'that', 'she', 'ought', 'to']
# predicted word :  ['her', 'that', 'she', 'ought']
# the
#
# original sentence :  ['that', 'she', 'ought', 'to', 'have']
# predicted word :  ['that', 'she', 'ought', 'to']
# the
#
# original sentence :  ['she', 'ought', 'to', 'have', 'wondered']
# predicted word :  ['she', 'ought', 'to', 'have']
# the
#
# original sentence :  ['ought', 'to', 'have', 'wondered', 'at']
# predicted word :  ['ought', 'to', 'have', 'wondered']
# the
#
# original sentence :  ['to', 'have', 'wondered', 'at', 'this']
# predicted word :  ['to', 'have', 'wondered', 'at']
# the
#
# original sentence :  ['have', 'wondered', 'at', 'this', 'but']
# predicted word :  ['have', 'wondered', 'at', 'this']
# the
#
# original sentence :  ['wondered', 'at', 'this', 'but', 'at']
# predicted word :  ['wondered', 'at', 'this', 'but']
# the
#
# original sentence :  ['at', 'this', 'but', 'at', 'the']
# predicted word :  ['at', 'this', 'but', 'at']
# the
#
# original sentence :  ['this', 'but', 'at', 'the', 'time']
# predicted word :  ['this', 'but', 'at', 'the']
# the
#
# original sentence :  ['but', 'at', 'the', 'time', 'it']
# predicted word :  ['but', 'at', 'the', 'time']
# the
#
# original sentence :  ['at', 'the', 'time', 'it', 'all']
# predicted word :  ['at', 'the', 'time', 'it']
# the
#
# original sentence :  ['the', 'time', 'it', 'all', 'seemed']
# predicted word :  ['the', 'time', 'it', 'all']
# the
#
# original sentence :  ['time', 'it', 'all', 'seemed', 'quite']
# predicted word :  ['time', 'it', 'all', 'seemed']
# the
#
# original sentence :  ['it', 'all', 'seemed', 'quite', 'natural']
# predicted word :  ['it', 'all', 'seemed', 'quite']
# the
#
# original sentence :  ['all', 'seemed', 'quite', 'natural', 'but']
# predicted word :  ['all', 'seemed', 'quite', 'natural']
# the
#
# original sentence :  ['seemed', 'quite', 'natural', 'but', 'when']
# predicted word :  ['seemed', 'quite', 'natural', 'but']
# the
#
# original sentence :  ['quite', 'natural', 'but', 'when', 'the']
# predicted word :  ['quite', 'natural', 'but', 'when']
# the
#
# original sentence :  ['natural', 'but', 'when', 'the', 'rabbit']
# predicted word :  ['natural', 'but', 'when', 'the']
# the
#
# original sentence :  ['but', 'when', 'the', 'rabbit', 'actually']
# predicted word :  ['but', 'when', 'the', 'rabbit']
# the
#
# original sentence :  ['when', 'the', 'rabbit', 'actually', 'took']
# predicted word :  ['when', 'the', 'rabbit', 'actually']
# the
#
# original sentence :  ['the', 'rabbit', 'actually', 'took', 'a']
# predicted word :  ['the', 'rabbit', 'actually', 'took']
# the
#
# original sentence :  ['rabbit', 'actually', 'took', 'a', 'watch']
# predicted word :  ['rabbit', 'actually', 'took', 'a']
# the
#
# original sentence :  ['actually', 'took', 'a', 'watch', 'out']
# predicted word :  ['actually', 'took', 'a', 'watch']
# the
#
# original sentence :  ['took', 'a', 'watch', 'out', 'of']
# predicted word :  ['took', 'a', 'watch', 'out']
# the
#
# original sentence :  ['a', 'watch', 'out', 'of', 'its']
# predicted word :  ['a', 'watch', 'out', 'of']
# the
#
# original sentence :  ['watch', 'out', 'of', 'its', 'waistcoat']
# predicted word :  ['watch', 'out', 'of', 'its']
# the
#
# original sentence :  ['out', 'of', 'its', 'waistcoat', 'pocket']
# predicted word :  ['out', 'of', 'its', 'waistcoat']
# the
#
# original sentence :  ['of', 'its', 'waistcoat', 'pocket', 'and']
# predicted word :  ['of', 'its', 'waistcoat', 'pocket']
# the
#
# original sentence :  ['its', 'waistcoat', 'pocket', 'and', 'looked']
# predicted word :  ['its', 'waistcoat', 'pocket', 'and']
# the
#
# original sentence :  ['waistcoat', 'pocket', 'and', 'looked', 'at']
# predicted word :  ['waistcoat', 'pocket', 'and', 'looked']
# the
#
# original sentence :  ['pocket', 'and', 'looked', 'at', 'it']
# predicted word :  ['pocket', 'and', 'looked', 'at']
# the
#
# original sentence :  ['and', 'looked', 'at', 'it', 'and']
# predicted word :  ['and', 'looked', 'at', 'it']
# the
#
# original sentence :  ['looked', 'at', 'it', 'and', 'then']
# predicted word :  ['looked', 'at', 'it', 'and']
# the
#
# original sentence :  ['at', 'it', 'and', 'then', 'hurried']
# predicted word :  ['at', 'it', 'and', 'then']
# the
#
# original sentence :  ['it', 'and', 'then', 'hurried', 'on']
# predicted word :  ['it', 'and', 'then', 'hurried']
# the
#
# original sentence :  ['and', 'then', 'hurried', 'on', 'alice']
# predicted word :  ['and', 'then', 'hurried', 'on']
# the
#
# original sentence :  ['then', 'hurried', 'on', 'alice', 'started']
# predicted word :  ['then', 'hurried', 'on', 'alice']
# the
#
# original sentence :  ['hurried', 'on', 'alice', 'started', 'to']
# predicted word :  ['hurried', 'on', 'alice', 'started']
# the
#
# original sentence :  ['on', 'alice', 'started', 'to', 'her']
# predicted word :  ['on', 'alice', 'started', 'to']
# the
#
# original sentence :  ['alice', 'started', 'to', 'her', 'feet']
# predicted word :  ['alice', 'started', 'to', 'her']
# the
#
# original sentence :  ['started', 'to', 'her', 'feet', 'for']
# predicted word :  ['started', 'to', 'her', 'feet']
# the
#
# original sentence :  ['to', 'her', 'feet', 'for', 'it']
# predicted word :  ['to', 'her', 'feet', 'for']
# the
#
# original sentence :  ['her', 'feet', 'for', 'it', 'flashed']
# predicted word :  ['her', 'feet', 'for', 'it']
# the
#
# original sentence :  ['feet', 'for', 'it', 'flashed', 'across']
# predicted word :  ['feet', 'for', 'it', 'flashed']
# the
#
# original sentence :  ['for', 'it', 'flashed', 'across', 'her']
# predicted word :  ['for', 'it', 'flashed', 'across']
# the
#
# original sentence :  ['it', 'flashed', 'across', 'her', 'mind']
# predicted word :  ['it', 'flashed', 'across', 'her']
# the
#
# original sentence :  ['flashed', 'across', 'her', 'mind', 'that']
# predicted word :  ['flashed', 'across', 'her', 'mind']
# the
#
# original sentence :  ['across', 'her', 'mind', 'that', 'she']
# predicted word :  ['across', 'her', 'mind', 'that']
# the
#
# original sentence :  ['her', 'mind', 'that', 'she', 'had']
# predicted word :  ['her', 'mind', 'that', 'she']
# the
#
# original sentence :  ['mind', 'that', 'she', 'had', 'never']
# predicted word :  ['mind', 'that', 'she', 'had']
# the
#
# original sentence :  ['that', 'she', 'had', 'never', 'before']
# predicted word :  ['that', 'she', 'had', 'never']
# the
#
# original sentence :  ['she', 'had', 'never', 'before', 'seen']
# predicted word :  ['she', 'had', 'never', 'before']
# the
#
# original sentence :  ['had', 'never', 'before', 'seen', 'a']
# predicted word :  ['had', 'never', 'before', 'seen']
# the
#
# original sentence :  ['never', 'before', 'seen', 'a', 'rabbit']
# predicted word :  ['never', 'before', 'seen', 'a']
# the
#
# original sentence :  ['before', 'seen', 'a', 'rabbit', 'with']
# predicted word :  ['before', 'seen', 'a', 'rabbit']
# the
#
# original sentence :  ['seen', 'a', 'rabbit', 'with', 'either']
# predicted word :  ['seen', 'a', 'rabbit', 'with']
# the
#
# original sentence :  ['a', 'rabbit', 'with', 'either', 'a']
# predicted word :  ['a', 'rabbit', 'with', 'either']
# the
#
# original sentence :  ['rabbit', 'with', 'either', 'a', 'waistcoat']
# predicted word :  ['rabbit', 'with', 'either', 'a']
# the
#
# original sentence :  ['with', 'either', 'a', 'waistcoat', 'pocket']
# predicted word :  ['with', 'either', 'a', 'waistcoat']
# the
#
# original sentence :  ['either', 'a', 'waistcoat', 'pocket', 'or']
# predicted word :  ['either', 'a', 'waistcoat', 'pocket']
# the
#
# original sentence :  ['a', 'waistcoat', 'pocket', 'or', 'a']
# predicted word :  ['a', 'waistcoat', 'pocket', 'or']
# the
#
# original sentence :  ['waistcoat', 'pocket', 'or', 'a', 'watch']
# predicted word :  ['waistcoat', 'pocket', 'or', 'a']
# the
#
# original sentence :  ['pocket', 'or', 'a', 'watch', 'to']
# predicted word :  ['pocket', 'or', 'a', 'watch']
# the
#
# original sentence :  ['or', 'a', 'watch', 'to', 'take']
# predicted word :  ['or', 'a', 'watch', 'to']
# the
#
# original sentence :  ['a', 'watch', 'to', 'take', 'out']
# predicted word :  ['a', 'watch', 'to', 'take']
# the
#
# original sentence :  ['watch', 'to', 'take', 'out', 'of']
# predicted word :  ['watch', 'to', 'take', 'out']
# the
#
# original sentence :  ['to', 'take', 'out', 'of', 'it']
# predicted word :  ['to', 'take', 'out', 'of']
# the
#
# original sentence :  ['take', 'out', 'of', 'it', 'and']
# predicted word :  ['take', 'out', 'of', 'it']
# the
#
# original sentence :  ['out', 'of', 'it', 'and', 'burning']
# predicted word :  ['out', 'of', 'it', 'and']
# the
#
# original sentence :  ['of', 'it', 'and', 'burning', 'with']
# predicted word :  ['of', 'it', 'and', 'burning']
# the
#
# original sentence :  ['it', 'and', 'burning', 'with', 'curiosity']
# predicted word :  ['it', 'and', 'burning', 'with']
# the
#
# original sentence :  ['and', 'burning', 'with', 'curiosity', 'she']
# predicted word :  ['and', 'burning', 'with', 'curiosity']
# the
#
# original sentence :  ['burning', 'with', 'curiosity', 'she', 'ran']
# predicted word :  ['burning', 'with', 'curiosity', 'she']
# the
#
# original sentence :  ['with', 'curiosity', 'she', 'ran', 'across']
# predicted word :  ['with', 'curiosity', 'she', 'ran']
# the
#
# original sentence :  ['curiosity', 'she', 'ran', 'across', 'the']
# predicted word :  ['curiosity', 'she', 'ran', 'across']
# the
#
# original sentence :  ['she', 'ran', 'across', 'the', 'field']
# predicted word :  ['she', 'ran', 'across', 'the']
# the
#
# original sentence :  ['ran', 'across', 'the', 'field', 'after']
# predicted word :  ['ran', 'across', 'the', 'field']
# the
#
# original sentence :  ['across', 'the', 'field', 'after', 'it']
# predicted word :  ['across', 'the', 'field', 'after']
# the
#
# original sentence :  ['the', 'field', 'after', 'it', 'and']
# predicted word :  ['the', 'field', 'after', 'it']
# the
#
# original sentence :  ['field', 'after', 'it', 'and', 'fortunately']
# predicted word :  ['field', 'after', 'it', 'and']
# the
#
# original sentence :  ['after', 'it', 'and', 'fortunately', 'was']
# predicted word :  ['after', 'it', 'and', 'fortunately']
# the
#
# original sentence :  ['it', 'and', 'fortunately', 'was', 'just']
# predicted word :  ['it', 'and', 'fortunately', 'was']
# the
#
# original sentence :  ['and', 'fortunately', 'was', 'just', 'in']
# predicted word :  ['and', 'fortunately', 'was', 'just']
# the
#
# original sentence :  ['fortunately', 'was', 'just', 'in', 'time']
# predicted word :  ['fortunately', 'was', 'just', 'in']
# the
#
# original sentence :  ['was', 'just', 'in', 'time', 'to']
# predicted word :  ['was', 'just', 'in', 'time']
# the
#
# original sentence :  ['just', 'in', 'time', 'to', 'see']
# predicted word :  ['just', 'in', 'time', 'to']
# the
#
# original sentence :  ['in', 'time', 'to', 'see', 'it']
# predicted word :  ['in', 'time', 'to', 'see']
# the
#
# original sentence :  ['time', 'to', 'see', 'it', 'pop']
# predicted word :  ['time', 'to', 'see', 'it']
# the
#
# original sentence :  ['to', 'see', 'it', 'pop', 'down']
# predicted word :  ['to', 'see', 'it', 'pop']
# the
#
# original sentence :  ['see', 'it', 'pop', 'down', 'a']
# predicted word :  ['see', 'it', 'pop', 'down']
# the
#
# original sentence :  ['it', 'pop', 'down', 'a', 'large']
# predicted word :  ['it', 'pop', 'down', 'a']
# the
#
# original sentence :  ['pop', 'down', 'a', 'large', 'rabbit']
# predicted word :  ['pop', 'down', 'a', 'large']
# the
#
# original sentence :  ['down', 'a', 'large', 'rabbit', 'hole']
# predicted word :  ['down', 'a', 'large', 'rabbit']
# the
#
# original sentence :  ['a', 'large', 'rabbit', 'hole', 'under']
# predicted word :  ['a', 'large', 'rabbit', 'hole']
# the
#
# original sentence :  ['large', 'rabbit', 'hole', 'under', 'the']
# predicted word :  ['large', 'rabbit', 'hole', 'under']
# the
#
# original sentence :  ['rabbit', 'hole', 'under', 'the', 'hedge']
# predicted word :  ['rabbit', 'hole', 'under', 'the']
# the
#
# original sentence :  ['hole', 'under', 'the', 'hedge', '.']
# predicted word :  ['hole', 'under', 'the', 'hedge']
# the
#
# original sentence :  ['under', 'the', 'hedge', '.', 'in']
# predicted word :  ['under', 'the', 'hedge', '.']
# the
#
# original sentence :  ['the', 'hedge', '.', 'in', 'another']
# predicted word :  ['the', 'hedge', '.', 'in']
# the
#
# original sentence :  ['hedge', '.', 'in', 'another', 'moment']
# predicted word :  ['hedge', '.', 'in', 'another']
# the
#
# original sentence :  ['.', 'in', 'another', 'moment', 'down']
# predicted word :  ['.', 'in', 'another', 'moment']
# the
#
# original sentence :  ['in', 'another', 'moment', 'down', 'went']
# predicted word :  ['in', 'another', 'moment', 'down']
# the
#
# original sentence :  ['another', 'moment', 'down', 'went', 'alice']
# predicted word :  ['another', 'moment', 'down', 'went']
# the
#
# original sentence :  ['moment', 'down', 'went', 'alice', 'after']
# predicted word :  ['moment', 'down', 'went', 'alice']
# the
#
# original sentence :  ['down', 'went', 'alice', 'after', 'it']
# predicted word :  ['down', 'went', 'alice', 'after']
# the
#
# original sentence :  ['went', 'alice', 'after', 'it', 'never']
# predicted word :  ['went', 'alice', 'after', 'it']
# the
#
# original sentence :  ['alice', 'after', 'it', 'never', 'once']
# predicted word :  ['alice', 'after', 'it', 'never']
# the
#
# original sentence :  ['after', 'it', 'never', 'once', 'considering']
# predicted word :  ['after', 'it', 'never', 'once']
# the
#
# original sentence :  ['it', 'never', 'once', 'considering', 'how']
# predicted word :  ['it', 'never', 'once', 'considering']
# the
#
# original sentence :  ['never', 'once', 'considering', 'how', 'in']
# predicted word :  ['never', 'once', 'considering', 'how']
# the
#
# original sentence :  ['once', 'considering', 'how', 'in', 'the']
# predicted word :  ['once', 'considering', 'how', 'in']
# the
#
# original sentence :  ['considering', 'how', 'in', 'the', 'world']
# predicted word :  ['considering', 'how', 'in', 'the']
# the
#
# original sentence :  ['how', 'in', 'the', 'world', 'she']
# predicted word :  ['how', 'in', 'the', 'world']
# the
#
# original sentence :  ['in', 'the', 'world', 'she', 'was']
# predicted word :  ['in', 'the', 'world', 'she']
# the
#
# original sentence :  ['the', 'world', 'she', 'was', 'to']
# predicted word :  ['the', 'world', 'she', 'was']
# the
#
# original sentence :  ['world', 'she', 'was', 'to', 'get']
# predicted word :  ['world', 'she', 'was', 'to']
# the
#
# original sentence :  ['she', 'was', 'to', 'get', 'out']
# predicted word :  ['she', 'was', 'to', 'get']
# the
#
# original sentence :  ['was', 'to', 'get', 'out', 'again']
# predicted word :  ['was', 'to', 'get', 'out']
# the
#
# original sentence :  ['to', 'get', 'out', 'again', '.']
# predicted word :  ['to', 'get', 'out', 'again']
# the
