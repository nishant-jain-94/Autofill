# %% [markdown]
# ### importing require packages

# %%
from __future__ import print_function

import json
import os
import numpy as np
import sys
import h5py

from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from keras.layers import Embedding
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM, Bidirectional
from keras.preprocessing import sequence
from intersect_embeddings import Embeddings
from keras.callbacks import ModelCheckpoint

from nltk.tokenize import word_tokenize
import random
from itertools import groupby
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Instantiate Embeddings

# %%
embeddings = Embeddings(300, 4, 1, 4)

# %% [markdown]
# ### Getting data from preprocessing

# %%
word2vec_model = embeddings.get_intersected_model()
word2index, index2word = embeddings.get_vocabulary()
word2vec_weights = word2vec_model.wv.syn0
tokenized_indexed_sentences = embeddings.get_indexed_sentences()
# Out:
# Loading Indexed Sentences...

# %%
word2index = {word:index+1 for word, index in word2index.items()}
index2word = {index:word for word, index in word2index.items()}

# %%
word2index
# Out:
# {'cardiologist': 16130,
#  '2006_to_2013': 44097,
#  'extratropical': 18745,
#  'buffer': 38176,
#  'meisporangia': 32247,
#  'tukugawa': 23628,
#  'worker': 4427,
#  'mechanize': 44411,
#  'drain-source': 48469,
#  'forcing': 29530,
#  'spotted': 14339,
#  'lefevre': 45598,
#  'oxide': 3369,
#  'jungle': 19978,
#  'byelorussian_soviet_socialist_republic': 25980,
#  'accreditation': 9737,
#  'saturn': 4979,
#  'dinghai': 32179,
#  'secondarily': 43588,
#  'repayment': 17785,
#  'abound': 47760,
#  'the_geneva_conference': 36099,
#  'premiere': 3511,
#  'deep-fried': 38238,
#  'the_red_book_cd-da': 22530,
#  'kindergartens': 25779,
#  'oranges': 48300,
#  'notebooks': 9927,
#  '1534': 20855,
#  '3-stage': 48158,
#  'polonia_warsaw': 30824,
#  'dealkalization': 25914,
#  'duke_of_kent': 49502,
#  'psychologists': 10074,
#  'chlamydomonas': 52308,
#  'as-502': 30581,
#  '1000': 4277,
#  'greenman': 34291,
#  'salamis': 49523,
#  'thieves': 48599,
#  'crank': 45971,
#  'wupv': 29905,
#  'spring': 3023,
#  'dangerous': 4370,
#  'the_west_end': 24236,
#  'the_institute_of_russian_language': 43264,
#  'consent': 2669,
#  'electronically': 13845,
#  'cried': 28556,
#  'feminism': 21428,
#  'prussian': 1699,
#  'monotheistic': 21110,
#  'la_toscana_village': 43525,
#  'the_end_of_the_15th_century': 44670,
#  'edward_coke': 12542,
#  'panoramic': 30958,
#  'novello': 51531,
#  'drunken': 33627,
#  'the_court_and_social': 27308,
#  'evangelical_protestants': 27789,
#  'george_westinghouse': 33547,
#  'general_roman_calendar': 28127,
#  'urbanised': 16048,
#  'caribbean_carnivals': 44959,
#  'the_simla_accord': 29330,
#  'about_half': 13823,
#  'continuously': 5959,
#  'radioactive': 7940,
#  'debt-to-gdp': 50569,
#  'phycoerytherin': 23213,
#  'mormon': 14647,
#  'weeks': 4929,
#  'boyz_ii_men': 45964,
#  'inhibition': 17093,
#  'acids': 3626,
#  'autumn': 9846,
#  'mime': 28269,
#  'john_goldsmith': 29516,
#  'the_premier_leagues': 30108,
#  'aftar': 39595,
#  'donatello': 33753,
#  'nanyue': 30406,
#  'marxism': 16447,
#  'ismail_i': 24719,
#  'blurry': 45572,
#  'aswan_high_dam': 18236,
#  'agress': 50434,
#  'bid': 4155,
#  'the_northern_suburbs': 38579,
#  'adaptively': 23869,
#  'automakers': 26052,
#  'consequences': 5449,
#  'apollo': 837,
#  'hardvard_mark': 31981,
#  'the_beacon_the': 45600,
#  'prosperity': 7819,
#  'headlines': 30694,
#  'bicameral': 14635,
#  'block-making': 19962,
#  'mrnas': 46491,
#  'the_portugese_africa': 16846,
#  'uploader': 27953,
#  'freedom': 2075,
#  'mohammad_iqbal': 36758,
#  'farmed': 14044,
#  'loops': 23107,
#  'the_early_19th_and_20th_century': 33779,
#  'maastricht': 13729,
#  'adjusted': 5094,
#  'shine-dalgarno': 46118,
#  'restrict': 9640,
#  'cost-benefit': 26478,
#  'golden_boot': 35722,
#  'george_york': 29571,
#  'narth': 11027,
#  'lieage': 44972,
#  'eacg': 46298,
#  'firing': 5985,
#  'vimara_knighted': 34072,
#  'human_development_report': 5268,
#  'debtors': 45766,
#  'un-elected': 27392,
#  'dioxide': 5937,
#  'springs': 19133,
#  'mehmed_vi': 35753,
#  'hieroglyghics': 25583,
#  'laurisilva': 22396,
#  'the_latest_century': 45524,
#  '1796': 15150,
#  'officeholder': 20166,
#  'majuscales': 27774,
#  'reducing': 4865,
#  'english-speaking': 7014,
#  'georgie': 19383,
#  'phytochoria': 29202,
#  'sagan': 36632,
#  'incunabula': 16563,
#  'windows_ultrabooks': 28489,
#  '189': 23015,
#  'environmentalist': 49564,
#  'the_toepler_pump': 25367,
#  'exceptional': 21871,
#  '1876': 4301,
#  'emigrant': 17143,
#  'the_mint_act': 52146,
#  'heraldy': 24921,
#  'kallamaa': 47061,
#  'the_hungarian_revolution': 16504,
#  '1016': 44171,
#  'adinath': 29674,
#  'joins': 6804,
#  'retified': 36872,
#  'pashupatinath': 17924,
#  'slackta': 52643,
#  "the_great_north_children's_hospital": 36026,
#  'responsibility': 2496,
#  'emil': 33302,
#  'deutsche_universal-film_ag': 24141,
#  'between_1993_and_2005': 16768,
#  'copyists': 15278,
#  'sportspalast': 39828,
#  'recycling': 8965,
#  'i-40': 49887,
#  'bleaching': 14989,
#  'sky+': 41646,
#  'ethninticy': 28094,
#  'the_north_carolina_road': 34492,
#  'virus': 3883,
#  'nancy_astor': 32132,
#  'between_2006_and_2007': 43069,
#  'premium': 14507,
#  'disestablish': 35762,
#  'feb_20_2013': 37844,
#  'unrolled': 52427,
#  'the_portuguese_constitution': 22385,
#  'falcon': 14069,
#  'pieter_claesen_wyckoff_house': 17742,
#  'russian-born': 39068,
#  'gradation': 24704,
#  'wasted': 7945,
#  'doses': 30408,
#  'corinth': 23044,
#  'zhuge_liang': 18063,
#  'divers': 20692,
#  'arahant': 46285,
#  'during': 43,
#  'fort_peck': 29841,
#  'the_american_battle_monuments_commission': 38065,
#  'troublesome': 18710,
#  'incoherent': 34613,
#  'national_guardsmen': 47909,
#  'the_abc_radio': 43436,
#  'pay': 765,
#  'thwon': 25913,
#  'orson_welles': 48647,
#  'elisabeth_bumiller': 40170,
#  'nobel_prize-winning': 27660,
#  'renting': 33154,
#  'david_steel': 22294,
#  'the_fourth_amendment': 36842,
#  'abhisit_vejjajiva': 29625,
#  'violator': 21689,
#  'firebirds': 35806,
#  'switching': 4383,
#  'culminates': 47839,
#  'receice': 47470,
#  'plunder': 41929,
#  'guizhou': 52498,
#  'amoy': 18137,
#  'nm': 12420,
#  'myriad': 41509,
#  'trip': 3042,
#  'al-faqih': 30708,
#  'lowland': 12109,
#  'dissovling': 35822,
#  'summed': 23734,
#  'mark': 2409,
#  'eduard_lasker': 44441,
#  'rider': 16373,
#  'midwest': 45786,
#  'dariajs': 24617,
#  'polychaete': 17429,
#  'vested': 16944,
#  'throwing': 44361,
#  'parapodia': 11974,
#  'rationale': 22824,
#  'forest': 2105,
#  'duet': 8978,
#  'reworking': 38662,
#  'the_kingsmen': 32046,
#  '1903': 7535,
#  'countering': 32562,
#  'pcm': 45862,
#  'silver_nemesis': 33610,
#  'the_super_bowl_mvp': 32356,
#  'as-202': 48668,
#  'harp': 44803,
#  'anabolic': 34693,
#  'january_of_1977': 41077,
#  'battle': 212,
#  'purvey': 43709,
#  'great_island': 16255,
#  'hatchability': 40300,
#  'suspending': 16008,
#  'ph': 21385,
#  'rlvs': 22592,
#  'assize_of_arms': 49109,
#  'multinational': 15523,
#  'worst': 2782,
#  'the_royal_oak': 51620,
#  'the_war_department': 35709,
#  'switchover': 39757,
#  'homophones': 26283,
#  'guidebook': 37049,
#  'flags': 5506,
#  'marveltimely': 33095,
#  '2012_to_2015': 31491,
#  'dogsled': 51466,
#  'aim': 2129,
#  'full-fledged': 42988,
#  'jr': 4153,
#  'embraced': 6543,
#  'lutenists': 25668,
#  'westwood': 10041,
#  "'war-gamed": 50394,
#  'sabbatical': 35723,
#  'diaries': 15129,
#  'jamaa_islamiya': 36462,
#  'november_29_1945': 43336,
#  'ford': 5204,
#  'rolling': 18860,
#  'sponsored': 3783,
#  'santa_clara_convention_center': 44736,
#  'stuntman': 38321,
#  'sciences': 3207,
#  'uno_ab_alto': 38600,
#  'romances': 43228,
#  'the_flag_of_lebanon': 38627,
#  'paldiski': 35074,
#  'the_american_film_institute': 35132,
#  '190': 39279,
#  'paisos_catalans': 32287,
#  'the_kheuveren_river': 46470,
#  'pigs': 15222,
#  'counter-parts': 28815,
#  'world_heritage_site': 19766,
#  'macarthur': 5601,
#  'the_maritime_forces_atlantic': 49240,
#  'marauders': 40315,
#  'aung': 23883,
#  'direct': 1367,
#  'flavoring': 38325,
#  'kxyz': 37307,
#  'tawfiq_al-hakim': 37204,
#  'spur': 10454,
#  '304': 41512,
#  'pope_gregory': 27464,
#  'precdence': 32374,
#  'osha': 18410,
#  'cdmx': 34903,
#  'neo-sumerian': 51573,
#  'the_summer_solstice': 42661,
#  'pliable': 22750,
#  'hurts': 32249,
#  'hypersensitivities': 47252,
#  'poets': 6673,
#  'exercise-induced': 16112,
#  'homens': 42918,
#  'billions_of_dollars': 18413,
#  'at_1': 49944,
#  '7-bit': 19461,
#  'astika': 17699,
#  'proximaty': 45770,
#  'kensington': 26334,
#  'vegetal': 17352,
#  'exposition': 8699,
#  'semiplamated': 33828,
#  'convulsions': 47797,
#  'envelop': 49862,
#  'cabaret': 21234,
#  'surprised': 7409,
#  'editions': 5431,
#  'odinga': 21363,
#  'early_french': 29388,
#  'players': 941,
#  'northumbrian': 19265,
#  'shut-down': 29101,
#  'the_randolph_air_force_base': 32731,
#  'national_guard': 32497,
#  'glam': 11790,
#  'hyper-responsiveness': 28381,
#  'araniko': 21370,
#  'atone': 31946,
#  'laurissilva': 49249,
#  'the_2006_elections': 49038,
#  'phagocytes': 11586,
#  'bardeen': 50280,
#  'prestal': 34543,
#  'the_propaganda_due_lodge': 32394,
#  'bill_clinton': 7450,
#  'engravers': 39962,
#  'lifetime_achievement_award': 44137,
#  'courtship': 16616,
#  'ics': 28687,
#  'cleaned': 18435,
#  'the_territorial_council': 44577,
#  'monotheism': 19754,
#  'moni': 20961,
#  'gor': 46073,
#  'mccarthy': 8298,
#  'palce': 38403,
#  'windsor': 13234,
#  'anti-discriminaory': 45707,
#  'universally-accepted': 51435,
#  'webly_stadium': 41192,
#  'solves': 31814,
#  'fsf': 17064,
#  'hula': 32695,
#  'qing_qianlong_emperor': 42261,
#  'trending': 35222,
#  'upthrusting': 31165,
#  'impede': 35286,
#  'bauhaus': 32055,
#  'the_southside_halls': 45267,
#  'antipater': 13394,
#  'bluebuck': 42733,
#  'eicosanoids': 34782,
#  'hunter-gathering': 15467,
#  'rhys_chatham': 38611,
#  'waitz': 9684,
#  'transform': 5553,
#  'lighthouse_point': 34106,
#  'the_national_army': 41124,
#  'canonisation': 30008,
#  'acent': 52377,
#  'biologists': 14105,
#  'rao': 44544,
#  'sea-creatures': 47970,
#  'the_city_of_paris': 47751,
#  'grenade': 23788,
#  'high-definition': 27722,
#  'rob_pardo': 31882,
#  'speaker': 3252,
#  'billions': 12119,
#  'gravel': 42017,
#  'sampled': 41993,
#  'the_world_trade_organization': 19219,
#  'flew': 6800,
#  'strategic': 4156,
#  'biology': 7215,
#  '21st-century': 39207,
#  'unbalanced': 51851,
#  'commuter': 10139,
#  'timesharing': 51928,
#  'intestinal': 15162,
#  'bce': 4604,
#  'torah': 6128,
#  'agent': 3582,
#  'derivatives': 8737,
#  'π2': 38901,
#  'rejects': 6373,
#  'sky_italia': 30894,
#  'veggies': 48863,
#  'oxides': 10117,
#  'mig-15': 39090,
#  'smelting': 9324,
#  'tutored': 16053,
#  'aravelli': 30134,
#  'those': 674,
#  'rectified': 51687,
#  'tribesmen': 16713,
#  'tonnage': 22060,
#  'mestizos': 47116,
#  'gaius_marius': 17408,
#  'baltic': 4482,
#  'galician-portuguese': 36144,
#  'aspires': 22586,
#  'menzie': 36112,
#  'child-care': 39597,
#  'between_2002_and_2007': 26133,
#  'remedios_varo': 44020,
#  'punt': 9687,
#  'turner': 9822,
#  'combats': 19086,
#  'novgotod': 39508,
#  'bellow': 26152,
#  'apology': 12074,
#  'exists': 2458,
#  'president': 128,
#  'attributes_of_mercy': 29501,
#  'flatter': 44627,
#  'reich': 44039,
#  'köppen': 11055,
#  'ye_olde_trip_to_jerusalem': 26326,
#  'occasionally': 3697,
#  'tells': 10805,
#  'protestant': 1645,
#  'revolutionary_war_motto': 31164,
#  'livingstone': 24738,
#  'celebrity': 5952,
#  'prehistory': 49520,
#  'spartacus': 44541,
#  'hipparchus': 11419,
#  'miraclous': 51910,
#  'new_year': 46252,
#  'avoir': 31087,
#  'seemingly': 11952,
#  'severly': 52047,
#  'joseph_schelling': 29219,
#  'obtain': 2032,
#  'iman_crosson': 35259,
#  'nymphs': 45698,
#  'sher_shah_suri': 34245,
#  'equates': 23204,
#  'hexafluoride': 18991,
#  'the_science_fiction_hall_of_fame': 49964,
#  'new_york_city': 879,
#  'oregeny': 16868,
#  'shuts': 48088,
#  'dr_ali_el': 28036,
#  'the_university_of_erfurt': 20525,
#  'types': 206,
#  'feacal': 35551,
#  'malicious': 14393,
#  'earls': 26693,
#  'catching': 26729,
#  'malian': 16237,
#  'the_prophet_muhammad': 40722,
#  'untenable': 13351,
#  'excuse': 9929,
#  'ssr': 12457,
#  'doing_business_index': 43493,
#  '1408': 37588,
#  'kato_kiyomasa': 15119,
#  'amber': 17103,
#  'substrate': 27503,
#  'equivalency': 35295,
#  'build': 771,
#  'administratively': 43634,
#  'the_american_revolution': 5940,
#  'cointelpro': 15169,
#  'coulomb': 18807,
#  'epoch': 12639,
#  'anchored': 22006,
#  'seclusion': 26819,
#  'ugly': 45477,
#  'gymnastiscs': 52421,
#  'john_melody': 23364,
#  'between_1953_and_1958': 44738,
#  'lord_rosebery': 20859,
#  '1-95': 43170,
#  'transcendent': 52180,
#  'vilnius': 20522,
#  'the_greek_war_of_independence': 34741,
#  'handel': 24352,
#  'dust': 3731,
#  'superior': 3836,
#  'vary': 3226,
#  'mutates': 41489,
#  'message': 2858,
#  'seize': 5226,
#  'newcastle': 884,
#  'gravelines': 38185,
#  'waived': 17432,
#  'yvonne_fletcher': 32097,
#  'february_8_1955': 26545,
#  'which_21st_century': 28380,
#  'probably': 3257,
#  'child-to-adulthood': 45913,
#  'proportional': 5636,
#  '1930s': 13758,
#  'the_untouchables_to_cbs_in': 45146,
#  'fertility': 7263,
#  'württemberg-baden': 21266,
#  'etioplast': 32760,
#  'bpc': 27838,
#  'paparazzi': 17003,
#  'participants': 5033,
#  'the_east_indies': 15751,
#  '76_centimeters': 44513,
#  'distances': 7985,
#  '600000': 43664,
#  'embarkation': 38336,
#  'onions': 39023,
#  'macbook': 26971,
#  'talent': 7770,
#  'giovan_battista': 43245,
#  'the_a': 42475,
#  'francois_mauriac': 43344,
#  'nociceptive': 38563,
#  'paler': 49003,
#  'd-shell': 47932,
#  'detriments': 46819,
#  'answered': 41792,
#  'height': 1971,
#  'adopt': 1441,
#  'plan_de_guadalupe': 17297,
#  'lumiance': 21832,
#  'filaments': 5496,
#  'gisbon_mandolin': 32004,
#  'non-wrinkle': 25165,
#  'juan_rodriguez_cabrillo': 30855,
#  'soviet_union': 7825,
#  'vows': 15688,
#  'tajik': 9104,
#  'the_continental_edison_company': 16928,
#  'tuvaluan': 6884,
#  'ckpg': 31451,
#  'capitals': 11031,
#  'examinations': 9142,
#  'mind': 2853,
#  'the_home_nations': 30096,
#  'crusaders': 10876,
#  'rushed': 21552,
#  'maurice_schlesinger': 33834,
#  'silent_sunday_nights': 52271,
#  'the_marquis_mu_ying': 40281,
#  'johnny_cash': 30055,
#  'content_id': 19985,
#  'signs': 3447,
#  'focussed': 41587,
#  'transformator': 10684,
#  'the_census_of': 34949,
#  'yang_sanbao': 15573,
#  'safety': 1970,
#  'mp3gain': 30757,
#  'interplanetary': 36822,
#  'insect': 966,
#  'the_countess_mountbatten_house': 36744,
#  'the_mianyang_hi-tech_industrial_development_zone': 14083,
#  'software': 992,
#  'alexandria_university': 47860,
#  'franklin': 21244,
#  'lobbied': 11388,
#  'casket': 29682,
#  'aslace': 19435,
#  'commission_v': 44982,
#  'mosques': 17410,
#  'umayyad': 4769,
#  'wars': 1670,
#  'scounting': 33153,
#  'ratification': 8933,
#  'condemned': 4960,
#  'planning': 2537,
#  'mis': 31779,
#  'lecturers': 33223,
#  'james_hutton': 14468,
#  'the_virginia_museum_of_fine_arts': 41185,
#  'withhold': 15069,
#  'potions': 48308,
#  'tiled': 50102,
#  'gay': 3487,
#  'samarkand': 13054,
#  'ally': 2631,
#  'savior': 31513,
#  'grandma': 36887,
#  'june': 6571,
#  "'the_world_in_grey": 15293,
#  'dodona': 31454,
#  'cadmium': 23958,
#  'intifada': 34926,
#  'on-campus': 49360,
#  'roger_ii': 31287,
#  'hajjar': 48774,
#  'the_persian_gulf': 23830,
#  'frankiln_roosevelt': 46279,
#  'navarre': 40517,
#  'westquay': 47350,
#  'spin': 9493,
#  'premier_league': 6217,
#  'giuseppe_vinaccia': 35829,
#  'linguistically': 12519,
#  'sample': 5899,
#  'charters': 6816,
#  'paramanu': 27201,
#  'liberalized': 30798,
#  'albert_memorial': 42748,
#  'too': 1466,
#  '121': 22432,
#  'evacuees': 19280,
#  'disruptions': 46580,
#  'appraised': 46586,
#  'the_minister_president': 41395,
#  'utah': 8379,
#  'elf4': 30424,
#  'enhances': 22753,
#  'hank_paulson': 35933,
#  'route_128': 25858,
#  'ferro': 51379,
#  'the_richmind-petersburg': 28967,
#  'divisison': 25871,
#  'dynastie': 48102,
#  'thesis': 6802,
#  'frowning': 29885,
#  'wetlands': 31659,
#  'new_zealand': 2386,
#  'algae': 5039,
#  'yellowstonw_national_park': 38450,
#  'deform': 49730,
#  'güshi_khan': 7633,
#  'sharia': 10200,
#  'trans': 15167,
#  'vii': 21622,
#  'lifeline': 42420,
#  'someone': 1167,
#  'willful': 41009,
#  'vietnam': 2875,
#  'the_gempei_war': 20702,
#  'colony': 1306,
#  'sign': 880,
#  'porter-gaud_school': 32207,
#  'opposites': 45824,
#  'directive': 4944,
#  'hovering': 31477,
#  'epigenetic': 29803,
#  'particlar': 30850,
#  'november_3_2008': 47322,
#  'the_alaska_marine_highway': 23674,
#  'ranked': 791,
#  'antitrust': 13853,
#  'brood': 27158,
#  'polytechnical': 29079,
#  'robert_schumann': 49672,
#  'swinging': 29921,
#  'nimitze': 30915,
#  'positives': 20635,
#  'para': 33775,
#  'accident': 4764,
#  'hemicellulose': 17695,
#  'ile': 27824,
#  'marshall': 5525,
#  'omina': 48106,
#  'polonasises': 32550,
#  'leafless': 40350,
#  'melbourne_transportation_plan': 50925,
#  'probing': 35422,
#  'wholly-owned': 34854,
#  'duval_county': 33907,
#  'cutting': 8819,
#  'the_5th_season': 21419,
#  'sunderland': 21493,
#  '1917-1920': 43813,
#  '1814': 7897,
#  'wed': 18263,
#  'co-np': 21316,
#  'north_east': 49864,
#  'industrialized': 16353,
#  'rotors': 8903,
#  'woodrow_wilson': 17126,
#  'waer': 46835,
#  'empiresovereignty': 31520,
#  'uses': 601,
#  'inefficiency': 26382,
#  'haruspicy': 18153,
#  'mosley': 36619,
#  'tonearm': 48239,
#  'datanet_1': 46208,
#  'theys': 51812,
#  'hpv': 24871,
#  'tremor': 44243,
#  'william_orton': 32323,
#  'irokawa_daikichi': 41412,
#  'reorganizing': 24396,
#  'wic': 38806,
#  'haq': 14338,
#  'care': 1994,
#  'finnish': 9931,
#  'morsi': 37041,
#  'speaches': 46117,
#  'encirclement': 24038,
#  'fort_william_henry': 19539,
#  'only_about_half': 24495,
#  'toalt': 36795,
#  'george_iii': 7180,
#  'avoids': 34037,
#  'avalanche': 25823,
#  'the_hungry_eye_gallery': 30047,
#  'unsuccessful': 6473,
#  'hybrids': 13397,
#  'self-concept': 14424,
#  '1931': 4437,
#  'life_sciences_and_physical': 31933,
#  '2007-08': 52190,
#  'blackbeards': 17616,
#  'avant': 18778,
#  'suriname': 10756,
#  'statutory': 9191,
#  'reaching': 4802,
#  'xiang_yu': 23920,
#  'inflow': 40113,
#  '1492': 9490,
#  'iteration': 45650,
#  'janjaap_ruijssenaars': 25458,
#  'the_morean_war': 40910,
#  'the_1920s': 4914,
#  'parrish': 41505,
#  'specifications': 11329,
#  'jim_walter': 31815,
#  'back-translation': 12201,
#  'sirmium': 46513,
#  'govenor_bush_realize': 41647,
#  'edward_the_confessor': 18451,
#  'photo_gallery': 16885,
#  'novi_sad_agreement': 24198,
#  'the_pro_bowl': 13643,
#  'abdirashid_ali_shermarke': 14950,
#  'overturned': 5936,
#  'cortes': 41479,
#  'the_fan_save': 25963,
#  'somtal': 16126,
#  'devonshire_hunting_tapestries': 46263,
#  'third-most-prevalent': 31668,
#  'minded': 26732,
#  'vandalism': 44444,
#  '1962': 3775,
#  'sheet': 6344,
#  'the_cooper_river': 20974,
#  'honoree': 29483,
#  'the_federal_trade_commission': 40469,
#  'embarrassed': 31292,
#  'ferroelectric': 38246,
#  'norte': 46072,
#  'scenery': 48384,
#  'crystal': 8499,
#  'potsdam': 24083,
#  'populist': 13652,
#  'beheading': 34504,
#  'elephant': 12007,
#  'discreditedempty': 30213,
#  'eyeglasses': 18966,
#  'pharmacists': 3290,
#  'the_university_of_melbourne': 24590,
#  'curtail': 20275,
#  'shumer': 26794,
#  'the_houston_community_college': 46026,
#  'the_connecticut_colony': 46601,
#  'consumes': 35682,
#  'pastures': 25601,
#  'vestiges': 13404,
#  'until': 396,
#  'holt': 26023,
#  'ptolemies': 23832,
#  'three-hour': 37063,
#  'modern': 178,
#  'seaway': 49693,
#  'mews': 30260,
#  'manuscript': 7112,
#  'botany': 5318,
#  'rubble': 14476,
#  'benaadir': 25667,
#  'ṣalībī': 17251,
#  'gross': 2796,
#  'the_thirteenth_century': 43740,
#  'domsticated': 32674,
#  'activates': 34144,
#  'degree-granting': 21487,
#  'james_madison': 15889,
#  'the_reclamation_act': 28177,
#  'ingredient': 5556,
#  'claris': 19841,
#  'redress': 13530,
#  'samuel_marsden': 49451,
#  'juan': 18633,
#  'higher-elevation': 44787,
#  'undercroft': 16421,
#  'dental': 19502,
#  'the_passing_parade': 52219,
#  'san_bernardino': 8294,
#  'the_lodge_of': 41473,
#  'oliver_cromwell': 30110,
#  'objection': 8118,
#  'imperfection': 16852,
#  'sheryl_crow': 23985,
#  'st_helens': 36426,
#  'reiterate': 33675,
#  'the_southampton_ferry_port': 50888,
#  'desperately': 19570,
#  'headphones': 17494,
#  'ricci': 51806,
#  'asexual': 8498,
#  'join': 645,
#  'lag': 22341,
#  'genoese': 26209,
#  'lawmaking': 11268,
#  'bullied': 17942,
#  'assoc': 38483,
#  'march_of_1924': 29090,
#  'guns_n_roses_long': 46960,
#  'hamburgers': 49820,
#  'crop': 2617,
#  'classifed': 29661,
#  'alfred_hitchcock': 50335,
#  'preachers': 5882,
#  'lows': 29827,
#  'coronations': 38549,
#  'vaccines': 8462,
#  'cbssn': 45846,
#  'ticketed': 37848,
#  'eschatology': 21908,
#  'attested': 20171,
#  'uss_enterprise': 35877,
#  'lawrence_durrell': 20287,
#  'calibrated': 15837,
#  'heartwood': 4038,
#  'usamgik': 32271,
#  'the_health_serviced_group': 34281,
#  'dollar': 1951,
#  'subsequently': 6199,
#  '96_zinc': 29744,
#  'strippers': 30376,
#  'february_23': 29071,
#  'retard': 50651,
#  'tender': 13478,
#  'the_royal_canadian_air_force': 32161,
#  'rip': 37640,
#  'journalism': 6928,
#  '450th': 32315,
#  '2012-2013': 9548,
#  'f14': 39936,
#  'savile': 48447,
#  'city_for_biking': 48749,
#  'crc': 50661,
#  'the_north_american_snes': 42271,
#  'matrox': 17893,
#  'analogy': 41427,
#  'bedridden': 23383,
#  'teh_20th_century': 39318,
#  'cig': 40180,
#  'buckingham': 4715,
#  'contagiously': 33584,
#  'moon': 1739,
#  'sketched': 42067,
#  'calcidiol': 40636,
#  'retainers': 40618,
#  'greener': 21336,
#  '5th': 3989,
#  '1890s': 22390,
#  'maximizing': 39136,
#  'six_days': 18148,
#  'devo': 19450,
#  'draining': 16967,
#  'absurd': 45659,
#  'the_american_geographical_society': 35918,
#  'vampirovibrio': 37625,
#  'starters': 27815,
#  'usurp': 21851,
#  'awareness': 6843,
#  'styles': 2473,
#  'heels': 29229,
#  'nicholas_ii': 25329,
#  'lykegenes': 28208,
#  'imperialist': 12679,
#  'nri': 12253,
#  'immunostimulators': 31235,
#  'transmitter': 4820,
#  'the_six_dynasties_end': 33871,
#  'comfortable': 13789,
#  'bradley_county': 41865,
#  'ballades': 40304,
#  'the_malbork_castle': 23009,
#  'state-run': 12573,
#  'richard_h_sander': 42166,
#  'the_presbyterian_church_of_east_africa': 30607,
#  'pioneer_square': 23659,
#  'unglazed': 27387,
#  'housekeeping': 51639,
#  'the_qing_dynasty': 9026,
#  'repeating': 24483,
#  'excerpts': 16491,
#  'protopriest': 20484,
#  'chancellor_wrighton': 50465,
#  'helm': 34293,
#  "'ve": 5227,
#  'bodhisattva': 12936,
#  'permission': 4391,
#  'ld-700': 14436,
#  'august': 4613,
#  'conscripted': 7154,
#  'acting': 4943,
#  'gerda_abts': 32560,
#  'giovance': 47072,
#  'emloyment': 39019,
#  'walled': 14597,
#  'alleging': 18169,
#  'contrary': 7107,
#  'bel': 23095,
#  'the_greatest_hits_compilation': 32065,
#  'the_house_of_lords_select_committee_on_communications': 16884,
#  'acceptors': 29421,
#  'caliphates': 47780,
#  'facto': 8496,
#  'the_marais-quarter': 28580,
#  'verdingkinder': 31508,
#  'october_of_1917': 35105,
#  'oswego': 23012,
#  'the_boys_in_blue': 39443,
#  'the_tümed_mongols': 43839,
#  'reload': 41739,
#  'mithraeum': 49110,
#  'diagnosed': 6124,
#  'artigas_central_station': 38026,
#  'the_aussa_sultanate': 23014,
#  "people's_committees": 48298,
#  '21st_and_22nd': 44180,
#  'reclassification': 15614,
#  'bhajan': 25730,
#  'envionment': 32367,
#  'miss_america': 40813,
#  'journal': 5181,
#  'stained-glass': 32617,
#  'strand': 12953,
#  'gregory': 12440,
#  'the_new_york_life_building': 17660,
#  'feudal': 7451,
#  'disdain': 22224,
#  'the_league': 18094,
#  'redeploy': 40844,
#  'brightman': 46055,
#  '10_in': 31387,
#  'legendary': 9765,
#  'bloomfield_hills': 34965,
#  'coastline': 4516,
#  'mixed-sex': 48805,
#  'anti-justificationist': 46988,
#  'strepsiptera': 22446,
#  '2nd-largest': 16013,
#  'impaired': 25836,
#  'sever': 9530,
#  'faulty': 12596,
#  'mosan_art': 51741,
#  'conflicts': 2923,
#  'korsakoff': 46105,
#  '40th': 8145,
#  'flatbed': 28406,
#  'cricket': 4728,
#  'classis': 32372,
#  'adjournment': 24937,
#  'dialect-speaking': 26288,
#  'epidermis': 12178,
#  'sidonius_apollinaris': 35476,
#  'afro-pop': 44209,
#  'latter-day': 19826,
#  'june_1909': 35898,
#  'devastation': 17073,
#  'superspeed': 14288,
#  '1951': 5511,
#  'blockade': 5230,
#  'non-rock': 16857,
#  'the_korean_communist_party': 25066,
#  'throne': 2353,
#  'accomidations': 34552,
#  'ribault': 16988,
#  'coldplay_and_beyoncé': 36785,
#  'loving': 42333,
#  'butts': 32430,
#  'budget': 1825,
#  'the_royal_titles_act': 49560,
#  'indymac': 3980,
#  'late_chinese': 47380,
#  'mixed': 1710,
#  ...}

# %%
tokenized_indexed_sentences[0]
# Out:
# [1, 3, 2206, 9, 388, 498, 93, 108, 5, 0]

# %%
tokenized_indexed_sentences = [np.array(sentence) + 1 for sentence in tokenized_indexed_sentences if len(sentence) > 0]

# %%
tokenized_indexed_sentences[0]
# Out:
# array([   2,    4, 2207,   10,  389,  499,   94,  109,    6,    1])

# %%
new_weights = np.zeros((1, word2vec_weights.shape[1]))

# %%
new_weights = np.append(new_weights, word2vec_weights, axis=0)

# %%
new_weights.shape
# Out:
# (52731, 300)

# %%
new_weights[52730]
# Out:
# array([ 0.35742188,  0.03369141, -0.03881836,  0.07666016, -0.06079102,
#         0.6328125 ,  0.05615234,  0.04345703,  0.00265503, -0.21582031,
#         0.40234375, -0.0559082 , -0.15820312,  0.21289062,  0.28710938,
#         0.54296875, -0.13085938,  0.14746094,  0.06738281, -0.171875  ,
#         0.07373047, -0.0006485 , -0.10986328, -0.13476562,  0.06152344,
#        -0.03833008, -0.07519531, -0.00221252,  0.09179688, -0.37890625,
#        -0.31054688, -0.07666016, -0.484375  , -0.0546875 , -0.13183594,
#        -0.33203125,  0.20996094,  0.25      ,  0.0534668 ,  0.08496094,
#        -0.1875    ,  0.09960938,  0.24902344, -0.07714844, -0.01123047,
#        -0.06787109,  0.21191406, -0.11865234, -0.01660156,  0.22265625,
#        -0.37695312,  0.36914062, -0.51171875,  0.06640625, -0.19726562,
#        -0.01818848,  0.0612793 , -0.21582031,  0.13574219, -0.08154297,
#         0.18652344,  0.3203125 ,  0.26367188,  0.24609375,  0.01208496,
#         0.04931641,  0.18652344,  0.29296875,  0.21289062,  0.06884766,
#         0.13476562, -0.17480469, -0.02246094,  0.25195312,  0.02380371,
#        -0.00354004,  0.09228516,  0.1953125 , -0.07763672, -0.13867188,
#         0.05175781,  0.17578125, -0.02124023, -0.38476562, -0.16992188,
#        -0.12597656, -0.11376953,  0.13671875, -0.06835938, -0.00921631,
#         0.04394531, -0.27148438, -0.45703125, -0.08837891,  0.04321289,
#         0.15332031,  0.1796875 , -0.02099609,  0.20507812, -0.05688477,
#         0.10839844, -0.12011719,  0.203125  , -0.31054688,  0.28125   ,
#        -0.23828125, -0.44921875, -0.02966309,  0.19628906, -0.36523438,
#         0.05761719,  0.15527344,  0.10742188,  0.23242188, -0.13085938,
#         0.14257812, -0.32617188,  0.09423828,  0.32421875,  0.00183868,
#         0.20703125,  0.203125  ,  0.07617188, -0.17285156, -0.10449219,
#         0.15136719, -0.06542969,  0.11083984,  0.04956055,  0.25585938,
#        -0.10302734, -0.08886719, -0.23925781,  0.11328125,  0.14941406,
#        -0.03833008,  0.12402344,  0.13085938,  0.19433594,  0.03613281,
#         0.0072937 , -0.0612793 , -0.20703125,  0.38867188,  0.12988281,
#         0.23925781, -0.36523438,  0.265625  , -0.50390625,  0.21679688,
#         0.26367188,  0.05566406, -0.26757812,  0.23632812, -0.171875  ,
#        -0.11181641,  0.16796875, -0.23925781, -0.02380371,  0.10400391,
#        -0.20117188,  0.12402344, -0.10546875,  0.02233887,  0.15234375,
#         0.31640625,  0.05322266, -0.20214844,  0.13769531,  0.00442505,
#         0.14550781, -0.0703125 ,  0.17382812, -0.18457031, -0.21191406,
#         0.07275391, -0.1640625 , -0.01660156, -0.0019989 ,  0.01361084,
#         0.04223633, -0.01116943,  0.05786133, -0.13378906, -0.24804688,
#        -0.38085938, -0.03100586, -0.10839844,  0.21386719,  0.03686523,
#        -0.11279297,  0.34765625,  0.20507812, -0.14941406,  0.05175781,
#        -0.06445312, -0.16210938, -0.15917969, -0.12792969, -0.18554688,
#        -0.08007812,  0.02526855, -0.17285156,  0.14550781,  0.1015625 ,
#         0.04321289, -0.19433594,  0.10107422,  0.11279297, -0.14453125,
#        -0.53125   , -0.21679688, -0.02258301, -0.09277344, -0.02612305,
#         0.14453125,  0.10839844, -0.23242188, -0.34765625, -0.09423828,
#         0.19726562,  0.06054688,  0.11230469, -0.16894531, -0.21972656,
#         0.12011719,  0.18164062, -0.0177002 , -0.18359375, -0.22070312,
#         0.09863281, -0.06787109, -0.36132812,  0.09423828, -0.00601196,
#         0.38085938,  0.2890625 , -0.02661133, -0.14550781,  0.02832031,
#         0.3984375 , -0.1328125 ,  0.09960938,  0.04882812,  0.03466797,
#        -0.05078125,  0.25390625,  0.09716797,  0.06152344, -0.16210938,
#        -0.11523438,  0.07861328,  0.47851562,  0.546875  ,  0.05859375,
#        -0.15039062, -0.08398438, -0.22070312,  0.25195312,  0.14355469,
#        -0.18457031, -0.22851562, -0.11767578,  0.21386719, -0.14746094,
#         0.02307129, -0.20019531, -0.09423828,  0.1015625 , -0.04589844,
#        -0.09472656,  0.03320312, -0.06835938,  0.05566406,  0.30273438,
#        -0.0456543 , -0.02111816,  0.18847656,  0.33007812,  0.3984375 ,
#         0.12695312, -0.03173828,  0.35742188, -0.12792969,  0.28320312,
#        -0.17773438, -0.29101562, -0.10839844, -0.13183594,  0.15527344,
#         0.20800781,  0.2734375 , -0.14355469, -0.11865234, -0.16699219,
#        -0.04101562, -0.03564453,  0.00174713, -0.0859375 , -0.17773438])

# %% [markdown]
# ### generating training data

# %%
window_size = 5
vocab_size = len(word2index)
print(vocab_size)
# Out:
# 52730

# %%
maxlen = max([len(sentence) for sentence in tokenized_indexed_sentences])

# %%
tokenized_indexed_sentences = sequence.pad_sequences(tokenized_indexed_sentences)

# %%
seq_in = []
seq_out = []
# generating dataset
tokenized_indexed_sentences = [sentence for sentence in tokenized_indexed_sentences if len(sentence) > 0]
for sentence in tokenized_indexed_sentences:
    x = sentence
    y = np.append(sentence[1:], np.array(sentence[len(sentence)-1]))
    seq_in.append(x)
    seq_out.append([new_weights[index] for index in y])

# converting seq_in and seq_out into numpy array
seq_in = np.array(seq_in)
seq_out = np.array(seq_out)
n_samples = len(seq_in)
print ("Number of samples : ", n_samples)
# Out:
# Number of samples :  97974

# %% [markdown]
# ## Defining model

# %%
# Changes to the model to be done here
model = Sequential()
model.add(Embedding(input_dim=new_weights.shape[0], output_dim=new_weights.shape[1], weights=[new_weights], mask_zero=True))
model.add(Bidirectional(LSTM(1024, return_sequences=True), merge_mode="ave"))
model.add(Bidirectional(LSTM(300, return_sequences=True), merge_mode="ave"))
model.compile(loss='cosine_proximity', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-8713d2c76bd3> in <module>()
#       2 model = Sequential()
#       3 model.add(Embedding(input_dim=new_weights.shape[0], output_dim=new_weights.shape[1], weights=[new_weights], mask_zero=True))
# ----> 4 model.add(Bidirectional(LSTM(1024, return_sequences=True), merge_mode="average"))
#       5 model.add(Bidirectional(LSTM(300, return_sequences=True), merge_mode="average"))
#       6 model.compile(loss='cosine_proximity', optimizer='adam',metrics=['accuracy'])
#
# /home/nishant/venvs/autofill/lib/python3.5/site-packages/keras/layers/wrappers.py in __init__(self, layer, merge_mode, weights, **kwargs)
#     217         super(Bidirectional, self).__init__(layer, **kwargs)
#     218         if merge_mode not in ['sum', 'mul', 'ave', 'concat', None]:
# --> 219             raise ValueError('Invalid merge mode. '
#     220                              'Merge mode should be one of '
#     221                              '{"sum", "mul", "ave", "concat", None}')
#
# ValueError: Invalid merge mode. Merge mode should be one of {"sum", "mul", "ave", "concat", None}

# %%
model_weights_path = "../weights/lstm-3-1024-1024-batchsize-256-epochs-30-Sequence"
if not os.path.exists(model_weights_path):
    os.makedirs(model_weights_path)
checkpoint_path = model_weights_path + '/weights.{epoch:02d}.hdf5'
checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_best_only=False, mode='max')

# %% [markdown]
# ## Train Model

# %%
model.fit(seq_in, seq_out, epochs=1, verbose=30, batch_size=256, callbacks=[checkpoint])
# Out:
# Epoch 1/30

# %% [markdown]
# ### model predict

# %%
start = 0
sentence_test = "In which regions in particular did"
indexed_sentences = embeddings.get_indexed_query(sentence_test)
print("indexed_sentences ",indexed_sentences)
sent = np.array(indexed_sentences)
#pattern = list(seq_in[start])
pattern = list(sent)
print("\"",' '.join(index2word[index] for index in pattern))
for i in range(10):
    prediction = model.predict(np.array([pattern]))
    pred_word = word2vec_model.similar_by_vector(prediction[0][prediction.shape[1] - 1])[0][0]
    sys.stdout.write(pred_word+" ")
    pattern.append(word2index[pred_word])
    pattern = pattern[:len(pattern)]
# Out:
# indexed_sentences  [1, 5, 17, 875, 5, 1707, 9]
# " squadstart in which regions in particular did
# the what egyptians not egyptians in egyptians cradling them the

# %%
#e_model = embeddings.get_model()

# %%
#e_model.similar_by_word("profitabl")

# %% [markdown]
# ## Accuracy

# %%
def accuracy():
    count = 0
    correct = 0
    for sub_sample_in, sub_sample_out in zip(seq_in, seq_out):
        ypred = model.predict_on_batch(np.expand_dims(sub_sample_in, axis=0))[0]
        ytrue = sub_sample_out
        pred_word = word2vec_model.similar_by_vector(ypred)[0][0]
        true_word = word2vec_model.similar_by_vector(ytrue)[0][0]
        similarity = word2vec_model.similarity(pred_word, true_word)
        if similarity == 1:
            correct += 1
        count += 1
    print("Accuracy {0}".format(correct/count))

# %%
#seq_out[0]

# %%
# accuracy()

# %%
#model_results = model_fit_summary.history

# %%
#model_results.update(model_fit_summary.params)

# %%
#model_results["train_accuracy"] = accuracy()

# %%
# n = no. of predictions
# accuracy = accuracy(400)
#print(model_results)

# %%
#text_file_path = "../weights/lstm-2-1024-512-batchsize-128-epochs-25/model_results.json"

# %%
#with open(text_file_path, "w") as f:
        #json.dump(model_results, f)
