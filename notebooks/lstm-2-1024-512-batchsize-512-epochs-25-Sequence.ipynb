# %% [markdown]
# ### importing require packages

# %%
from __future__ import print_function

import json
import os
import numpy as np
import sys
import h5py

from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from keras.engine import Input
from keras.layers import Embedding, merge
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.preprocessing import sequence
from intersect_embeddings import Embeddings
from keras.callbacks import ModelCheckpoint

from nltk.tokenize import word_tokenize
import random
from itertools import groupby
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Instantiate Embeddings

# %%
embeddings = Embeddings(300, 4, 1, 4)

# %% [markdown]
# ### Getting data from preprocessing

# %%
word2vec_model = embeddings.get_intersected_model()
word2index, index2word = embeddings.get_vocabulary()
word2vec_weights = word2vec_model.wv.syn0
tokenized_indexed_sentences = embeddings.get_indexed_sentences()
# Out:
# Loading Indexed Sentences...

# %%
word2index = {word:index+1 for word, index in word2index.items()}
index2word = {index:word for word, index in word2index.items()}

# %%
word2index
# Out:
# {'nl': 21728,
#  'inspired': 1436,
#  'govenor': 28641,
#  'jennifer_lopez': 14649,
#  'assuage': 24783,
#  'sherman': 11362,
#  'downloaders': 26076,
#  'the_guinness_book_of_world_records_for': 51654,
#  'louis-phillipe': 30116,
#  'injections': 30049,
#  'the_executive_director': 34585,
#  'transmitted': 3781,
#  'arthur_ravenel_jr_bridge': 23742,
#  'liability': 10594,
#  'bumble': 35107,
#  'reportings': 44414,
#  'forty': 47129,
#  'the_county_palatine_of': 47361,
#  'the_great_fire_of_1835': 39035,
#  'psychoanalytic': 14244,
#  'stuart': 11858,
#  'departure': 8147,
#  'curbed': 20922,
#  'healer': 14564,
#  'that_14th_century': 28035,
#  'the_united_grand_lodge_of_england_formed': 28665,
#  'collects': 27471,
#  'the_rice_house': 52497,
#  'marrying': 9059,
#  'upthrusting': 31165,
#  'urbanization': 8814,
#  'andy_hertzfeld': 28646,
#  'edc': 17831,
#  'dinner_theater__good_company': 40028,
#  'slavonic-speaking': 40562,
#  'survivial': 50392,
#  'switzerland': 581,
#  'ritual': 4525,
#  'eventual': 9648,
#  'tachymetric': 29936,
#  'autoclavation': 43601,
#  'kentucky': 17495,
#  'the_american_association_for': 50543,
#  'dutch_east_indiamen': 27657,
#  'eritrean': 3091,
#  'distillation': 9043,
#  'attainment': 44770,
#  'mis': 31779,
#  'sky+': 41646,
#  'bjt': 35136,
#  'the_domus_aurea': 25385,
#  'the_sky+_box': 38591,
#  'wilhelm_wien': 41432,
#  'nazi_regime': 26613,
#  'texas_southern_university': 38122,
#  '700-megawatt': 32813,
#  'charles_towne': 22466,
#  'april_15': 20862,
#  'the_aboriginal_protection_boards': 39620,
#  'cephalopods': 30817,
#  'the_detroit_medical_center': 25295,
#  'rapid': 2856,
#  'documents': 2415,
#  'sklábos': 34346,
#  'durham_cathedral': 36067,
#  'the_20_of': 42493,
#  'idealists': 11233,
#  'sacked': 6446,
#  'responses': 3955,
#  'differnet': 36558,
#  'coordinates': 10976,
#  'the_santa_monica_feast': 26524,
#  'the_rotten_tomatoes': 28515,
#  'srivijaya_kingdom': 26875,
#  'firefighters': 4612,
#  'mercer_county': 50207,
#  'torii': 52134,
#  'nuclei': 7921,
#  'contexts': 8514,
#  'grand_orients': 46119,
#  'aclu': 13299,
#  'detroit_piston': 27371,
#  '87': 22381,
#  'characterizing': 47169,
#  'clisson_et_eugénie': 40137,
#  'inspector': 25822,
#  'lawbreaking': 43895,
#  'gaurd': 44401,
#  'floats': 43450,
#  'reich': 44039,
#  'accordingly': 48559,
#  'reservati': 36963,
#  'nnon-slavic': 49554,
#  'parasite': 14311,
#  'price': 1238,
#  'static': 6406,
#  'wyoming': 35429,
#  'dicotyledons': 43983,
#  'between_100_and_150': 25070,
#  'farther': 17168,
#  'lithuania': 6034,
#  'more_than_10_million': 34620,
#  'anticircumvention': 47240,
#  'karmapa': 13994,
#  'advertised': 23968,
#  'firmly': 14748,
#  'equestrian': 19963,
#  "sant'ambrogio": 49715,
#  'noyce': 45663,
#  'insensitivity': 52016,
#  'prescriptive': 34721,
#  'pickoff': 45568,
#  'substandard': 9303,
#  'anthropolgists': 38866,
#  'tuberculosis': 1989,
#  "'whiteman": 48197,
#  'tethered': 45120,
#  'northwestern_dance_marathon': 43042,
#  '68mcu': 36957,
#  'forepaws': 28861,
#  'anti-infective': 23427,
#  'drosophila': 14209,
#  'retaliations': 29276,
#  'huxley': 10326,
#  'generations': 5741,
#  'voltages': 18843,
#  're-invention': 35760,
#  '1826': 19780,
#  'rolpe_dorje': 29392,
#  'noxious': 41964,
#  'the_boardwalk_hall': 48113,
#  'copyrights': 12061,
#  'metaphysician': 42979,
#  'monetary': 4727,
#  'saliva': 10598,
#  'the_principles_of_geology': 32412,
#  'demands': 6959,
#  '723000': 29877,
#  'slovo': 18513,
#  'william_howard_russell': 18351,
#  'bake': 36049,
#  'bury': 19478,
#  'braver': 44174,
#  'overlap': 6646,
#  'inpatients': 43480,
#  'w-vhs': 17954,
#  'primary': 356,
#  'the_center_city': 43653,
#  'nonfactor': 36741,
#  'homicides': 10904,
#  'the_london_weekend_television': 51080,
#  'the_hanover_cabaret_festival': 43720,
#  'die_roten': 38952,
#  'phosphorylation': 22033,
#  'realart_pictures': 50133,
#  'facilities': 2953,
#  'crust': 5928,
#  'appliances': 45784,
#  'scramble': 41115,
#  'sts': 39531,
#  "the_standing_committee_of_the_national_people's_congress": 31993,
#  'sears_mexico': 41181,
#  'the_second_boer_war': 31982,
#  'barka': 46801,
#  'lebanese': 6469,
#  'the_hudson_bay': 45527,
#  'alta_california': 46619,
#  'ceramic': 6479,
#  'dormition': 35177,
#  'neuronal': 25798,
#  '47': 23122,
#  'stairstep': 34823,
#  'vauban': 41728,
#  'transmutation': 18942,
#  'veterinary': 37486,
#  'steve_fossett': 39509,
#  'royalist': 21944,
#  'mandatory_palestine': 35977,
#  'the_central_cemetery': 20475,
#  'the_tsangpa_dynasty_of_shigatse': 24496,
#  'gupta': 8031,
#  'ramirez': 31632,
#  'gong': 33836,
#  '1702-1709': 26838,
#  'unesco_world_heritage': 13755,
#  'recognizes': 4577,
#  'tanks': 9600,
#  '105': 11691,
#  'qing': 1966,
#  'expatriates': 47407,
#  'boganda': 12136,
#  'the_vatican': 50652,
#  'two-field': 43972,
#  'rumored': 4012,
#  'hymnal': 16508,
#  'vibration-sensitive': 27525,
#  'münzkabinett': 51902,
#  'trombones': 23155,
#  'richard_nixon': 44396,
#  'franklin_pierce_adams': 26178,
#  'mukden': 49630,
#  'bigotry': 39947,
#  'neutralizing': 40235,
#  'queen_victorias': 7860,
#  'portion': 1021,
#  'develping': 28336,
#  'impeded': 51006,
#  'signaling': 11003,
#  'betray': 32557,
#  'jug_band': 24996,
#  'ups_freight': 48481,
#  'close': 825,
#  'anus': 37079,
#  'programme': 6138,
#  'william_eaton': 27332,
#  'expained': 29152,
#  'hamshenis': 27577,
#  'attendants': 13903,
#  'fraternaties': 34229,
#  'high-fat': 31838,
#  'commanders': 8973,
#  'manor': 15269,
#  'disney-abc': 13098,
#  'oxytocin': 40289,
#  'two-byte': 32216,
#  'beret': 15644,
#  'torbay': 18401,
#  'sir_conroy': 45893,
#  'henri_herz': 51096,
#  'the_cambridge_rules': 22177,
#  'cleanly': 29316,
#  'arab_images_on_film': 41683,
#  'leukocytes': 35049,
#  'indoors': 32110,
#  'british': 133,
#  'previous': 1198,
#  'ugle': 13047,
#  'judaicus': 44252,
#  'islets': 21457,
#  'fury': 17472,
#  'iucn': 15760,
#  'elongatus': 34764,
#  'rider': 16373,
#  'julius_caesar': 6192,
#  '45-yard': 39543,
#  'served': 1164,
#  'precept': 28690,
#  'ha': 21751,
#  'ppp': 19066,
#  'idlo': 18131,
#  'john_harris': 33286,
#  'merged': 2999,
#  'the_new_haven_free_public_library': 52474,
#  '2011-12': 9187,
#  '282': 34071,
#  'modern_estonian': 51682,
#  'history': 357,
#  'mordaunt': 26547,
#  'nada': 19930,
#  'zip': 11641,
#  'kilogram': 6894,
#  'baltic_assembly': 24389,
#  'haemophiliacs': 45845,
#  'suffering': 3079,
#  'fluorescent': 7741,
#  'johnson_city': 38277,
#  'resented': 22437,
#  'north_american_french': 29422,
#  'hawala': 49169,
#  'importance': 1380,
#  'salafi': 40230,
#  'august_4th': 46314,
#  'martin_luther': 2437,
#  'coleoptera': 15250,
#  'devloped': 20104,
#  'hesse': 10314,
#  'organizing': 9604,
#  'the_boston_school_for_deaf_mutes': 22897,
#  'strung': 47206,
#  'co': 12821,
#  'mctaggart': 8816,
#  'antiochus_vii_sidetes': 43088,
#  'unitised': 33200,
#  'pros': 29253,
#  'the_himachal_pradesh': 30737,
#  'javier_glickman': 26804,
#  'dar_es_salaam': 19188,
#  'spaceship': 8021,
#  'demanding': 17322,
#  'bouches-du-rhône': 33997,
#  'pursuit': 6413,
#  'east-central': 31415,
#  'aslo': 32124,
#  'prominant': 41402,
#  'the_seattle_art_museum': 30290,
#  'earl_of': 28280,
#  'clarity': 20766,
#  'motives': 12240,
#  'southeast_asia': 3019,
#  'ultra': 19801,
#  'the_plebeian_council': 22350,
#  'contorl': 44340,
#  'north_and_south': 16359,
#  'cyclist': 19482,
#  'olulal': 27896,
#  'invited': 3246,
#  'amass': 12591,
#  'recklessly': 27488,
#  'π2': 38901,
#  'gadstone': 38904,
#  'commissar': 41461,
#  'henry_cole_wing': 22481,
#  'orderly': 16473,
#  'tamworth': 22138,
#  'boarder': 17162,
#  'paul_morley': 43052,
#  'the_fall_quarter_of_2014': 12658,
#  'lockout': 8309,
#  'trudeau': 43780,
#  'rebelled': 13370,
#  'bubblebath': 30036,
#  'the_revolution': 43141,
#  'pioneer_square': 23659,
#  'the_wanli_emperor': 19714,
#  'cast_courts': 32784,
#  'whatwasoneoftheconclusionsoftheusfinancialcrisisinquirycommissionregardingthefinancialcrisisof2007': 46747,
#  'judas': 23411,
#  'victom': 50781,
#  'emp': 49010,
#  'conceptualization': 14350,
#  'world_university_rankings': 47300,
#  'swallowed': 16059,
#  'schwarzenegger_co-starred': 38190,
#  'comandante': 32496,
#  'bureau': 6629,
#  'accomplishing': 46456,
#  'weston_mill': 47167,
#  'heer_ranjha': 26713,
#  'prisioner': 43084,
#  'horseshoe_bay': 37638,
#  'ptolemaic_kingdom': 24101,
#  'cylindrical': 19115,
#  'six-year': 52515,
#  'kpelle': 20502,
#  'the_arizona_rattlers': 27888,
#  '617': 31471,
#  'karachi': 34362,
#  'nutrition': 6290,
#  'hispano-moresque': 45426,
#  'astron_belt': 42703,
#  'muse': 5935,
#  'blowing': 24119,
#  'shirly': 46345,
#  'the_chernobyl_disaster': 41916,
#  'lusignan': 32173,
#  'the_cathedral_of': 50738,
#  'recent_decade': 47883,
#  'honours': 13827,
#  'ramon_y_cajal': 44063,
#  'americas': 2156,
#  'sir_walter_raleigh': 36986,
#  'fought': 1225,
#  'taxila': 23480,
#  'kernel': 30724,
#  'impliment': 35120,
#  'inaugurate': 44314,
#  'exile': 6159,
#  'dec_7_1948': 30839,
#  'occupied': 1651,
#  'the_last_season': 29258,
#  'the_red_cross': 8787,
#  'reach': 635,
#  'earnings': 4534,
#  'foundations': 8071,
#  'barbary_war': 38059,
#  'william_whitney': 27159,
#  'the_society': 36438,
#  'prescription': 11385,
#  'greek_cypriots': 18177,
#  'aggressors': 49729,
#  'wen_jiabao': 16019,
#  'label': 1438,
#  'rt_gunther': 52320,
#  'regulars': 12116,
#  'wrte': 44275,
#  'nothing': 4579,
#  'reroute': 21294,
#  'burke': 801,
#  'westinghouse_electric': 18097,
#  'emilia': 17596,
#  'saloon': 18715,
#  'speaking': 1612,
#  'indigenous_australians': 17148,
#  'the_congregational_union_of_australia': 52090,
#  'bordered': 9944,
#  'nazarene': 26422,
#  'the_paris_convention': 34600,
#  'the_dd_national': 46718,
#  'faith_hill': 39645,
#  'super_bowl_ii': 44187,
#  'hrf': 15565,
#  'shortages': 20760,
#  'winter_semester_end_earlier': 47219,
#  'action_plans': 31695,
#  '4_aluminium_mixed': 31777,
#  'at_least': 38028,
#  'eisele': 24201,
#  'department_of_cultural_affairs': 37197,
#  'paul_maunder': 26485,
#  'hyder_ali': 29164,
#  'cyp27b1': 49056,
#  'dikes': 13359,
#  'grim': 19876,
#  'reannexation': 21465,
#  'daleks': 10414,
#  'pannier_market': 25833,
#  'the_brazilian_federal_supreme_court': 47191,
#  'bronkhorst': 18348,
#  'voyska': 51398,
#  'cantabile': 29011,
#  'convolutions': 45604,
#  'trophy': 2227,
#  'neoclassical_empire': 43221,
#  'leek': 41444,
#  'the_antwerp_city_hall': 18187,
#  'inception': 4908,
#  'whichmaterialwasmoredurableshellacorvinyl': 26882,
#  'differenet': 42511,
#  'bonnie_tyler': 30606,
#  'bbq': 20293,
#  'present': 438,
#  'the_blackstone_group': 40012,
#  'car-dominated': 21268,
#  'greek_mediterranean': 46462,
#  'oct_2004': 51563,
#  'fine-grained': 24941,
#  'posting': 7738,
#  'transcendental': 51134,
#  'radio_tyneside': 25022,
#  'harboring': 50448,
#  'about_90_million': 33050,
#  'shop': 7041,
#  'coffeehouse': 45258,
#  'sneered': 52416,
#  'news': 1839,
#  'jp_1-02': 41765,
#  'the_zoo_los_coyotes': 40201,
#  'supremely': 25388,
#  'abolition': 11924,
#  'century_city': 40713,
#  'stratigraphic': 10804,
#  'weddell': 18127,
#  'between_1983_and_1992': 47173,
#  'loving': 42333,
#  'avoid': 1226,
#  'barrino': 42337,
#  'southwest_airlines': 17490,
#  'propoerty': 32337,
#  'eec': 31095,
#  'henry_purcell': 24543,
#  'famiyl': 33600,
#  'branches': 2586,
#  'beijing': 2806,
#  'the_last': 9526,
#  'nightingale': 29487,
#  'interieur': 27179,
#  'republican': 2067,
#  'complaining': 13301,
#  'percy': 41545,
#  'anthony_burns': 27477,
#  'st_cuthbert': 32499,
#  'revive': 9339,
#  '58': 11571,
#  'jurisprudence': 10202,
#  'kam': 42662,
#  'suns': 15784,
#  "'alciphron": 27648,
#  'the_esteve_pharmacy': 27752,
#  'pancreas': 32597,
#  'transverse': 12694,
#  'vesey': 15903,
#  'schism': 9384,
#  'liverpool_fc': 40788,
#  'the_mississippi_delta': 15421,
#  'carvings': 28326,
#  'alexandria_university': 47860,
#  'dc_statehood_party': 26786,
#  'moorland': 39476,
#  'londinium': 24026,
#  '5th': 3989,
#  'the_aeromedical_evacuation': 28453,
#  'cheerwine': 24652,
#  'undecided': 35189,
#  'hammon-harwood_house': 50344,
#  'parthenos': 20305,
#  'the_beijing_military': 47503,
#  'berlin_huguenots': 45352,
#  'gifted': 12027,
#  'ejactulation': 36918,
#  'awarded': 1241,
#  'tomas_taveira': 36778,
#  'the_city_landmark': 32926,
#  'cells': 630,
#  'eighth': 6147,
#  'evolutionism': 45636,
#  'hardiness': 20685,
#  'the_operations_division': 35961,
#  'spiral_scratch': 33934,
#  'rome': 513,
#  'donauwörth': 47132,
#  'pope_pius_xii': 46808,
#  'upper_rind': 36133,
#  'identiries': 44005,
#  'meatpacking_district': 18681,
#  'fairly': 12405,
#  'enumeration': 14802,
#  'serbian': 5214,
#  'kmc': 21455,
#  'the_little_island_railway_station': 26087,
#  'make': 106,
#  'the_city_of_charleston_fire_department': 41491,
#  'hugh_downs': 38762,
#  'pecks': 47865,
#  'nagumo': 14300,
#  'macron': 51768,
#  'breached': 10419,
#  'heretics': 7105,
#  'huracan': 51084,
#  'sfoe': 46902,
#  'blended': 9618,
#  'british_gas': 38986,
#  'exchequer': 20602,
#  'scots': 9060,
#  'the_revolutionary_wars': 51767,
#  "'génos": 40837,
#  'fixed-wing': 23744,
#  'notebooks': 9927,
#  'giving': 2638,
#  'blue_shield': 36059,
#  'edward': 4334,
#  'depicting': 8581,
#  'paula_abdul': 10776,
#  'videogames': 25402,
#  'outsourcing': 28945,
#  'eyesight': 39667,
#  'gains': 9423,
#  'the_phoenix_city': 25282,
#  'immigrate': 7430,
#  'whales': 14417,
#  'plants': 371,
#  'urs': 16066,
#  'mogadishu': 8318,
#  'nuclear_weapons_states': 48042,
#  'less': 428,
#  'american_style': 43526,
#  'loudoun': 10347,
#  'criticizes': 19776,
#  'sufficiently': 40129,
#  'recreational': 9678,
#  'euplokamis': 9983,
#  'rendering': 8290,
#  'communes': 27537,
#  'the_armenian_republic': 30879,
#  'taxman': 44993,
#  'contributing': 4404,
#  'between_1353_to_1481': 37143,
#  'hudson_river': 44417,
#  'constuct': 24913,
#  'east_asia': 10518,
#  'pigmented': 37727,
#  'judgments': 21296,
#  'rapping': 46607,
#  'the_provincial_ministers': 51148,
#  'mayor_de_blasio': 39438,
#  'southern_hills': 45077,
#  'shrill': 30205,
#  'toxic': 3816,
#  'january_of_2008': 27933,
#  'fraction': 2808,
#  'stored-program': 14515,
#  'administrations': 10283,
#  'sphere': 4171,
#  'riba_publishing': 38339,
#  'discourse': 10168,
#  'citi': 21688,
#  'ghengis_khan': 16043,
#  'philological': 42642,
#  'sutras': 3873,
#  'drake_circus_shopping_centre': 21846,
#  'strobe': 25848,
#  'denied': 3292,
#  'steppenwolf': 20941,
#  'bar': 4358,
#  'modes': 8088,
#  'super_bowl_opening_night': 14134,
#  'pontian': 29247,
#  'chelsea_barracks': 22563,
#  'compulsary': 35979,
#  'interrupts': 12168,
#  'colossus': 16118,
#  'annette_island': 41971,
#  'moderation': 14723,
#  'holy_cross': 20557,
#  'mamluks': 23039,
#  'the_past_few_years': 31284,
#  'administrative': 2289,
#  'the_farmington_canal_trail': 18988,
#  'the_extension_centre': 25055,
#  'january_2006': 10572,
#  'waive': 20468,
#  'politics__policy': 17526,
#  'the_central_board_of': 35649,
#  'the_kievan_rus': 21179,
#  'saho': 34614,
#  'the_great_plains': 47573,
#  'throbs': 28010,
#  'agreements': 2347,
#  'the_pro_pack': 49723,
#  '117_of': 44621,
#  'evaded': 38396,
#  'b=17': 51112,
#  'qaramel': 50084,
#  'carving': 14075,
#  '1928': 5088,
#  'decrypt': 36779,
#  'commision': 26412,
#  'ohms': 28117,
#  'wester': 17053,
#  'y_ordonez': 50185,
#  'guests': 5989,
#  'the_graduation_album': 26329,
#  'universal_postal_union': 33915,
#  'serbia': 9969,
#  'loosening': 40371,
#  'sideload': 26089,
#  'buddha': 1897,
#  'harvard_stadium': 41318,
#  'alice_polka': 51279,
#  'non-dominant': 33171,
#  'precursors': 10521,
#  'reasonable': 16342,
#  '3g': 12042,
#  'seceded': 46881,
#  'the_prussian_general_staff': 51770,
#  'the_african_great_lakes': 25680,
#  'rex': 13847,
#  'akadémia': 44272,
#  'the_royal_navy': 12370,
#  '1544': 22146,
#  'botanic': 51906,
#  'albe': 41326,
#  'parque_battle': 46645,
#  'dragons': 43258,
#  'promise': 5128,
#  'sinagapore': 31503,
#  '5_august_1858': 36783,
#  'smile': 12850,
#  'congested': 18072,
#  'mlolongo': 21821,
#  'zoology': 15742,
#  'allegiance': 9330,
#  'asset-backed': 52141,
#  'usefully': 24956,
#  'embellishment': 42737,
#  'stronger': 4108,
#  'anti-semitic': 7278,
#  'sperling': 19233,
#  'three_hours': 26742,
#  'kilometer': 9692,
#  'bidirectional': 23854,
#  'between_1996_and_2006': 32005,
#  'zwingli': 33791,
#  'chick': 21142,
#  'reparations': 19324,
#  'us-buils': 34420,
#  'legitimacy': 7363,
#  'the_study_of_globalization': 40053,
#  'reintroduce': 21238,
#  'contructed': 46423,
#  'riot': 6518,
#  'batters': 15947,
#  'inflated': 18662,
#  'zhang_heng': 23523,
#  'eliminations': 32147,
#  'tents': 10190,
#  'atypical': 20532,
#  'two-month': 44308,
#  'keith_sweat': 29641,
#  'option': 3500,
#  'arrangent': 46425,
#  'favour': 26108,
#  'chattanooga': 16609,
#  'territory': 661,
#  'doesnt': 22143,
#  'aroused': 19299,
#  'february_2014': 33959,
#  'reorganised': 19672,
#  'grabbed': 43799,
#  'summarized': 16875,
#  'humanist_laureate_award': 25342,
#  'expires': 17080,
#  'fire-recall': 27188,
#  'matter': 1204,
#  'associated': 393,
#  'flac': 31130,
#  'tribhuvan': 26003,
#  'intermediary': 19222,
#  'mhc-antigen': 39987,
#  'outskirts': 21084,
#  'spalding_sporting_goods': 31607,
#  'ile': 27824,
#  'floridean': 50241,
#  'glasswork': 42825,
#  'brigham_young_acadamy': 13369,
#  'commons': 19596,
#  'evangelical_presbyterian': 37610,
#  'spare': 19934,
#  'exempted': 40086,
#  'the_national_review': 17375,
#  'cabrini_boulevard': 18923,
#  'behave': 6221,
#  'autumn_and_summer': 43960,
#  'ethninticy': 28094,
#  'the_general_slocum': 38900,
#  'fishermen': 16229,
#  'james_zabiela': 35051,
#  'mantis': 16865,
#  '1_of_people': 41697,
#  'maria_wodziński': 51857,
#  'guzman': 41068,
#  'the_tennessee_general_assembly': 34708,
#  'headed': 3570,
#  'institues': 28429,
#  'sewall_wright': 16968,
#  'explicit': 10652,
#  'nets': 35270,
#  'concerning': 2270,
#  'the_great_lakes': 18047,
#  '244_yards': 48935,
#  'criterion': 38202,
#  'resolves': 14930,
#  'scottish_parliament': 44353,
#  'christoph_waltz': 20714,
#  'hideyoshi': 17332,
#  'the_years_of_1833_to_1841': 31787,
#  'proposition': 16553,
#  'pannonia': 39968,
#  'cdos': 7762,
#  'furs': 34818,
#  'lebanon': 5133,
#  'omov': 50805,
#  'scholastic': 19639,
#  'the_high_llamas': 31450,
#  'craft': 6440,
#  'condense': 23300,
#  'deuterostome': 37119,
#  '22_percent': 29237,
#  'annelida': 19808,
#  'jay_cross': 48820,
#  'founders': 5535,
#  'ripper': 45589,
#  'diventer': 26999,
#  'distaste': 51411,
#  'kevin_keegan': 48381,
#  'uploader': 27953,
#  'the_non-aligned_movment': 42967,
#  'clears': 29195,
#  'between_1638_and_1648_what_street': 49967,
#  '61-yard': 49183,
#  'first_45_days': 44929,
#  'the_7th_inning': 27792,
#  'schweizer': 33960,
#  '3_june': 36677,
#  'rescue_the_french_republic': 32047,
#  '25': 7850,
#  'quarried': 40585,
#  'larson': 29851,
#  'date': 120,
#  'the_fifth_coalition': 23679,
#  'the_veterans_affairs_hospital': 47532,
#  'st_helena': 22193,
#  'the_egg_of_columbus': 47204,
#  'touchdown': 6625,
#  'blossoms': 50660,
#  'the_middle_of_the_night': 22449,
#  'essere': 34364,
#  '1294-96': 39823,
#  'mlk': 10097,
#  'hima': 25563,
#  'sells': 10597,
#  'late_2008': 12415,
#  'beleive': 27163,
#  'the_end_of_2008': 20728,
#  'the_russian_federation': 7485,
#  'nicaragua': 9950,
#  'conversation': 9453,
#  'tirat_zvi': 47762,
#  'grandchild': 11799,
#  'continued': 1885,
#  'foreclosures': 40227,
#  'tenants': 15211,
#  'household': 2861,
#  'obstruction': 10828,
#  'alister_mcgrath': 39662,
#  'sneak': 19262,
#  'between_2014_and_2015': 49494,
#  'discharged': 22583,
#  'engages': 36831,
#  'april_26': 26231,
#  'minoan': 33539,
#  'parades': 12745,
#  'visit': 659,
#  '1441': 36841,
#  'sample': 5899,
#  'jewelry': 7781,
#  'raffles_millennium_international': 39510,
#  'offline': 16459,
#  '17_july_1505': 50894,
#  'motivates': 19257,
#  'florence_lawrence': 29965,
#  'mutually': 6368,
#  'beinn_bhreagh': 35245,
#  'the_vietnam_war': 8094,
#  '1910': 3934,
#  'eaier': 33170,
#  'the_yale_record': 34893,
#  'cancellations': 28740,
#  'persecuted': 6054,
#  'the_summer_of_1932': 33567,
#  'remotely': 47162,
#  'indicat': 39669,
#  'cabooses': 32070,
#  'interdenominational': 42909,
#  'authorized': 4671,
#  'phones': 7319,
#  'the_imperial_college_london': 14258,
#  'isolated': 4087,
#  'western_regions': 46986,
#  '4th': 4893,
#  'ncd': 14248,
#  'costume': 8048,
#  'the_ottoman_empire': 2111,
#  'united_states_census': 12762,
#  'john_charles_thring': 32761,
#  'geocentric': 19201,
#  'screw': 34848,
#  'huguenot_society': 24953,
#  'arab-israeli': 13570,
#  'resupplied': 36940,
#  'schinzel': 36977,
#  'violinists': 36569,
#  'the_secret_life_of': 19591,
#  'bulletin': 31743,
#  'the_national_shrine': 28790,
#  'copyist': 36416,
#  'non-believers': 35812,
#  'populatized': 29591,
#  'describing': 4619,
#  'wandered': 40619,
#  'ideally': 46798,
#  'sunny': 14755,
#  'the_cambridge_platonist': 40681,
#  '1066': 36689,
#  'intergender': 48427,
#  'tb_reach_half': 32036,
#  'diphthong': 23504,
#  'bessarabia': 33641,
#  'chip_e': 43569,
#  'al-qarawiyin': 36482,
#  '5th-generation': 48876,
#  'pacific_standard_time': 32782,
#  'presage': 36408,
#  "'south": 51103,
#  'literacy': 2857,
#  'izborsk': 48589,
#  'sand_bernardino_-_riverside': 45051,
#  'state-established': 35368,
#  'but': 429,
#  'tsar': 14386,
#  'training': 1684,
#  'norman_art': 42108,
#  'the_presbyterian_church_of_australia': 26649,
#  'national_league': 34358,
#  'liquidation': 14655,
#  'reindeer': 16971,
#  'the_feynman_lectures_on_physics': 27291,
#  'classic_queen': 20835,
#  'hostage': 18265,
#  'reprinted': 21615,
#  'manzikert': 23618,
#  'deers': 40979,
#  'melburnians': 25213,
#  'monsters__men': 25397,
#  'unwelcome': 41038,
#  'overprinted': 49769,
#  'songhai': 18583,
#  'igor': 20426,
#  'dietray': 37118,
#  'michael_rostovtzeff': 44740,
#  'inshore': 31333,
#  'compression': 2146,
#  'abbasid': 9653,
#  'decedents': 31917,
#  'newly': 3094,
#  'the_general_grant_national_memorial': 42140,
#  'pradox': 46070,
#  'the_red_army_faction': 49728,
#  'tu': 42450,
#  'omb': 9409,
#  'inheriting': 37958,
#  'no_boundaries': 46312,
#  'tectonic': 8527,
#  'theism': 10630,
#  'university_of_wyoming': 31003,
#  'dolby_theatre': 26518,
#  'fortuitous': 50800,
#  'south_africa': 2149,
#  'june_12_1880': 34496,
#  'utensils': 29181,
#  'the_draft_riots': 20618,
#  'footsteps': 29931,
#  '27th': 11747,
#  'dividing': 5225,
#  'quadratic': 11340,
#  'copying': 10497,
#  'monitor': 4654,
#  '1603': 24283,
#  'confessions': 10898,
#  'suspend': 11341,
#  '1735': 14001,
#  'interfering': 29692,
#  '1150': 13632,
#  "2's_second": 45074,
#  '2009-2010_school_year': 45009,
#  'renumbered': 29636,
#  'effervescence': 11448,
#  'antikythera': 7735,
#  'pretend': 15582,
#  'areas': 204,
#  'gaixia': 49210,
#  'lenape_native_american': 30528,
#  'dasharatha': 48664,
#  'positives': 20635,
#  '95': 5432,
#  'explores': 13411,
#  'shorter': 4010,
#  'offenders': 15650,
#  'endorsements': 44432,
#  'netorking': 40802,
#  'stefan_schmid': 26249,
#  'homens': 42918,
#  'parliaments': 24526,
#  'ccomcast': 35262,
#  'tripolitsa': 42503,
#  'pedro_ii': 40391,
#  'tyrian': 25119,
#  'financed': 9046,
#  'the_xiang_army': 18079,
#  '8100_acres': 28860,
#  'russian_estonians': 28107,
#  'blending': 11555,
#  'monuments': 4932,
#  'art_deco_architecture': 44927,
#  'the_fresno_fairgrounds': 39577,
#  'workshops': 42379,
#  'the_warsaw_ghetto': 21588,
#  'bailey': 23309,
#  'axes': 32155,
#  'the_natural_history_of_selborne': 29362,
#  'adversary': 43761,
#  'washizawa': 42347,
#  'telecomunications': 49195,
#  'olivier_messiaen': 16872,
#  'lumieres': 11068,
#  'sunburn': 26161,
#  'michael_sells': 30279,
#  'columbian_exposition': 9886,
#  'non-linguistic': 34411,
#  'vline': 27662,
#  'yarolav': 51230,
#  'flammable': 45288,
#  'rugby_league': 27193,
#  'denying': 11803,
#  'e2': 45733,
#  'dynasties': 3959,
#  'mount_whitney': 17453,
#  'correspondant': 17388,
#  'regiments': 14902,
#  'albert_memorial': 42748,
#  'insular_celtic': 19961,
#  'article_12': 19688,
#  'the_three_kingdoms_era': 30551,
#  'dialectic': 39244,
#  'broadway': 3620,
#  'atonal': 43133,
#  'ability': 1262,
#  'dbase': 11294,
#  'sepulchre': 49671,
#  'the_american_physocological_association': 46615,
#  'norman': 3121,
#  ...}

# %%
tokenized_indexed_sentences[0]
# Out:
# [1, 3, 2206, 9, 388, 498, 93, 108, 5, 0]

# %%
tokenized_indexed_sentences = [np.array(sentence) + 1 for sentence in tokenized_indexed_sentences if len(sentence) > 0]

# %%
tokenized_indexed_sentences[0]
# Out:
# array([   2,    4, 2207,   10,  389,  499,   94,  109,    6,    1])

# %%
new_weights = np.zeros((1, word2vec_weights.shape[1]))

# %%
new_weights = np.append(new_weights, word2vec_weights, axis=0)

# %%
new_weights.shape
# Out:
# (52731, 300)

# %%
new_weights[52730]
# Out:
# array([ 0.35742188,  0.03369141, -0.03881836,  0.07666016, -0.06079102,
#         0.6328125 ,  0.05615234,  0.04345703,  0.00265503, -0.21582031,
#         0.40234375, -0.0559082 , -0.15820312,  0.21289062,  0.28710938,
#         0.54296875, -0.13085938,  0.14746094,  0.06738281, -0.171875  ,
#         0.07373047, -0.0006485 , -0.10986328, -0.13476562,  0.06152344,
#        -0.03833008, -0.07519531, -0.00221252,  0.09179688, -0.37890625,
#        -0.31054688, -0.07666016, -0.484375  , -0.0546875 , -0.13183594,
#        -0.33203125,  0.20996094,  0.25      ,  0.0534668 ,  0.08496094,
#        -0.1875    ,  0.09960938,  0.24902344, -0.07714844, -0.01123047,
#        -0.06787109,  0.21191406, -0.11865234, -0.01660156,  0.22265625,
#        -0.37695312,  0.36914062, -0.51171875,  0.06640625, -0.19726562,
#        -0.01818848,  0.0612793 , -0.21582031,  0.13574219, -0.08154297,
#         0.18652344,  0.3203125 ,  0.26367188,  0.24609375,  0.01208496,
#         0.04931641,  0.18652344,  0.29296875,  0.21289062,  0.06884766,
#         0.13476562, -0.17480469, -0.02246094,  0.25195312,  0.02380371,
#        -0.00354004,  0.09228516,  0.1953125 , -0.07763672, -0.13867188,
#         0.05175781,  0.17578125, -0.02124023, -0.38476562, -0.16992188,
#        -0.12597656, -0.11376953,  0.13671875, -0.06835938, -0.00921631,
#         0.04394531, -0.27148438, -0.45703125, -0.08837891,  0.04321289,
#         0.15332031,  0.1796875 , -0.02099609,  0.20507812, -0.05688477,
#         0.10839844, -0.12011719,  0.203125  , -0.31054688,  0.28125   ,
#        -0.23828125, -0.44921875, -0.02966309,  0.19628906, -0.36523438,
#         0.05761719,  0.15527344,  0.10742188,  0.23242188, -0.13085938,
#         0.14257812, -0.32617188,  0.09423828,  0.32421875,  0.00183868,
#         0.20703125,  0.203125  ,  0.07617188, -0.17285156, -0.10449219,
#         0.15136719, -0.06542969,  0.11083984,  0.04956055,  0.25585938,
#        -0.10302734, -0.08886719, -0.23925781,  0.11328125,  0.14941406,
#        -0.03833008,  0.12402344,  0.13085938,  0.19433594,  0.03613281,
#         0.0072937 , -0.0612793 , -0.20703125,  0.38867188,  0.12988281,
#         0.23925781, -0.36523438,  0.265625  , -0.50390625,  0.21679688,
#         0.26367188,  0.05566406, -0.26757812,  0.23632812, -0.171875  ,
#        -0.11181641,  0.16796875, -0.23925781, -0.02380371,  0.10400391,
#        -0.20117188,  0.12402344, -0.10546875,  0.02233887,  0.15234375,
#         0.31640625,  0.05322266, -0.20214844,  0.13769531,  0.00442505,
#         0.14550781, -0.0703125 ,  0.17382812, -0.18457031, -0.21191406,
#         0.07275391, -0.1640625 , -0.01660156, -0.0019989 ,  0.01361084,
#         0.04223633, -0.01116943,  0.05786133, -0.13378906, -0.24804688,
#        -0.38085938, -0.03100586, -0.10839844,  0.21386719,  0.03686523,
#        -0.11279297,  0.34765625,  0.20507812, -0.14941406,  0.05175781,
#        -0.06445312, -0.16210938, -0.15917969, -0.12792969, -0.18554688,
#        -0.08007812,  0.02526855, -0.17285156,  0.14550781,  0.1015625 ,
#         0.04321289, -0.19433594,  0.10107422,  0.11279297, -0.14453125,
#        -0.53125   , -0.21679688, -0.02258301, -0.09277344, -0.02612305,
#         0.14453125,  0.10839844, -0.23242188, -0.34765625, -0.09423828,
#         0.19726562,  0.06054688,  0.11230469, -0.16894531, -0.21972656,
#         0.12011719,  0.18164062, -0.0177002 , -0.18359375, -0.22070312,
#         0.09863281, -0.06787109, -0.36132812,  0.09423828, -0.00601196,
#         0.38085938,  0.2890625 , -0.02661133, -0.14550781,  0.02832031,
#         0.3984375 , -0.1328125 ,  0.09960938,  0.04882812,  0.03466797,
#        -0.05078125,  0.25390625,  0.09716797,  0.06152344, -0.16210938,
#        -0.11523438,  0.07861328,  0.47851562,  0.546875  ,  0.05859375,
#        -0.15039062, -0.08398438, -0.22070312,  0.25195312,  0.14355469,
#        -0.18457031, -0.22851562, -0.11767578,  0.21386719, -0.14746094,
#         0.02307129, -0.20019531, -0.09423828,  0.1015625 , -0.04589844,
#        -0.09472656,  0.03320312, -0.06835938,  0.05566406,  0.30273438,
#        -0.0456543 , -0.02111816,  0.18847656,  0.33007812,  0.3984375 ,
#         0.12695312, -0.03173828,  0.35742188, -0.12792969,  0.28320312,
#        -0.17773438, -0.29101562, -0.10839844, -0.13183594,  0.15527344,
#         0.20800781,  0.2734375 , -0.14355469, -0.11865234, -0.16699219,
#        -0.04101562, -0.03564453,  0.00174713, -0.0859375 , -0.17773438])

# %% [markdown]
# ### generating training data

# %%
window_size = 5
vocab_size = len(word2index)
print(vocab_size)
# Out:
# 52730

# %%
maxlen = max([len(sentence) for sentence in tokenized_indexed_sentences])

# %%
tokenized_indexed_sentences = sequence.pad_sequences(tokenized_indexed_sentences)

# %%
seq_in = []
seq_out = []
# generating dataset
tokenized_indexed_sentences = [sentence for sentence in tokenized_indexed_sentences if len(sentence) > 0]
for sentence in tokenized_indexed_sentences:
    x = sentence
    y = np.append(sentence[1:], np.array(sentence[len(sentence)-1]))
    seq_in.append(x)
    seq_out.append([new_weights[index] for index in y])

# converting seq_in and seq_out into numpy array
seq_in = np.array(seq_in)
seq_out = np.array(seq_out)
n_samples = len(seq_in)
print ("Number of samples : ", n_samples)
# Out:
# Number of samples :  97974

# %% [markdown]
# ## Defining model

# %%
# Changes to the model to be done here
model = Sequential()
model.add(Embedding(input_dim=new_weights.shapslae[0], output_dim=new_weights.shape[1], weights=[new_weights], mask_zero=True))
model.add(LSTM(1024,return_sequences=True))
model.add(Dropout(0.2))sla
model.add(LSTM(300, return_sequences=True))
model.load_weights("../weights/lstm-2-1024-512-batchsize-512-epochs-25-Sequence/weights.24.hdf5")
model.compile(loss='mse', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 300)         15819300
# _________________________________________________________________
# lstm_8 (LSTM)                (None, None, 1024)        5427200
# _________________________________________________________________
# lstm_9 (LSTM)                (None, None, 1024)        8392704
# _________________________________________________________________
# lstm_10 (LSTM)               (None, None, 300)         1590000
# =================================================================
# Total params: 31,229,204
# Trainable params: 31,229,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_weights_path = "../weights/lstm-2-1024-512-batchsize-512-epochs-25-Sequence"
if not os.path.exists(model_weights_path):
    os.makedirs(model_weights_path)
checkpoint_path = model_weights_path + '/weights.{epoch:02d}.hdf5'
checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_best_only=False, mode='max')

# %% [markdown]
# ## Train Model

# %%
#model.fit(seq_in, seq_out, epochs=25, verbose=1, batch_size=512, callbacks=[checkpoint])

# %% [markdown]
# ### model predict

# %%
start = 0
sentence_test = "In which regions in particular did"
indexed_sentences = embeddings.get_indexed_query(sentence_test)
print("indexed_sentences ",indexed_sentences)
sent = np.array(indexed_sentences)
#pattern = list(seq_in[start])
pattern = list(sent)
print("\"",' '.join(index2word[index] for index in pattern))
for i in range(10):
    prediction = model.predict(np.array([pattern]))
    pred_word = word2vec_model.similar_by_vector(prediction[0][prediction.shape[1] - 1])[0][0]
    sys.stdout.write(pred_word+" ")
    pattern.append(word2index[pred_word])
    pattern = pattern[:len(pattern)]
# Out:
# indexed_sentences  [1, 5, 17, 875, 5, 1707, 9]
# " squadstart in which regions in particular did
# the what egyptians not egyptians in egyptians cradling them the

# %%
#e_model = embeddings.get_model()

# %%
#e_model.similar_by_word("profitabl")

# %% [markdown]
# ## Accuracy

# %%
def accuracy():
    count = 0
    correct = 0
    for sub_sample_in, sub_sample_out in zip(seq_in, seq_out):
        ypred = model.predict_on_batch(np.expand_dims(sub_sample_in, axis=0))[0]
        ytrue = sub_sample_out
        pred_word = word2vec_model.similar_by_vector(ypred)[0][0]
        true_word = word2vec_model.similar_by_vector(ytrue)[0][0]
        similarity = word2vec_model.similarity(pred_word, true_word)
        if similarity == 1:
            correct += 1
        count += 1
    print("Accuracy {0}".format(correct/count))

# %%
#seq_out[0]

# %%
# accuracy()

# %%
#model_results = model_fit_summary.history

# %%
#model_results.update(model_fit_summary.params)

# %%
#model_results["train_accuracy"] = accuracy()

# %%
# n = no. of predictions
# accuracy = accuracy(400)
#print(model_results)

# %%
#text_file_path = "../weights/lstm-2-1024-512-batchsize-128-epochs-25/model_results.json"

# %%
#with open(text_file_path, "w") as f:
        #json.dump(model_results, f)
