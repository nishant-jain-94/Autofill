# %% [markdown]
# # Statistical Approach

# %% [markdown]
# ### importing require packages

# %%
import nltk
from nltk.tokenize import word_tokenize
import re
from nltk.util import ngrams
from nltk.probability import ConditionalFreqDist, ConditionalProbDist, MLEProbDist
import json

# %% [markdown]
# ### Loading Data

# %%
with open("../data/squad_wiki_data.json","r") as outfile:
    dataset = json.load(outfile)

# %%
questions = dataset[0]['Question']
questions = ' '.join(questions)

# %% [markdown]
# ### Generatng n_grams-bigrams

# %%
def cpdist_training_n_plus_1_grams(training_passage, n_plus_one):
    
    ## removing special character and symbols and converting to lower case
    training_passage = re.sub(r"(^\w|\')", ' ', training_passage).lower()
    
    ## tokenizing the sanitized passage
    words = nltk.word_tokenize(training_passage)
    
    cfdist_list = []
    cpdist_list = []
    
    ## generating cpdist and n_grams for n_plus_one to bigrams
    for n in range(n_plus_one,1,-1):
        ## generating n_plus_one_grams and converting into list
        n_grams_generated = list(ngrams(words, n))
        ## converting into (n_gram, n+1 words) for prediction
        n_grams_for_predict = [(n_gram[:-1],n_gram[-1]) for n_gram in n_grams_generated] 
        
        ## calculating conditionalfrequency for all n_grams
        cfdist = ConditionalFreqDist(n_grams_for_predict)
        
        ## calculating conditional probablitlity of next word for all n_grams
        cpdist = ConditionalProbDist(cfdist,MLEProbDist)
        
        cfdist_list.append(cfdist)
        cpdist_list.append(cpdist)
    
    return cpdist_list

# %%
cp_list = cpdist_training_n_plus_1_grams(questions, 5)

# %%
len(cp_list)
# Out:
# 4

# %% [markdown]
# ### Predict the next word function

# %%
def predict_next_using_n_grams(n_grams, cpdist_list, mode="nsent"):
    # n_gram = tuple of n_words #input to the function
    
    len_n_grams = len(n_grams)
    
    # to end the recursion
    if(len_n_grams==0):return #no prediction available
    
    #handlind sentence with length more than the n_grams generated
    if len_n_grams > len(cpdist_list): 
        n_grams = n_grams[-len(cpdist_list):]
        len_n_grams = len(n_grams)
    
    # possible predictions
    possible_pred = list(cpdist_list[len(cpdist_list)-len_n_grams][n_grams].samples())
    # number of possible prediciton for the provided n_grams
    n_possible_pred = len(possible_pred)
    
    if n_possible_pred!=0:
        
        if(mode == 'nword'):
            if(n_possible_pred == 1):
            #pred = possible_pred[0]
            #tuple(list(n_grams).append(pred)[1:])
                print(possible_pred[0])
            else:
            ## trying combining multiple probability
                print(possible_pred[0:5])
            
            
        if(mode == 'nsent'):
            if(n_possible_pred == 1):
                pred_words = []
                n_grams_list = list(n_grams)
                while(possible_pred[0]!='?'):
                    pred_words.append(possible_pred[0])
                    n_grams_list.append(possible_pred[0])                
                    n_grams_list = n_grams_list[1:]
                    possible_pred = list(cpdist_list[len(cpdist_list)-len_n_grams][tuple(n_grams_list)].samples())
                pred_words.append('?')
                print(' '.join(pred_words))
                return
            
            else:
            ## returning 2 sentence
                pred1, pred2 = [],[]
                n_grams_list1, n_grams_list2 = list(n_grams), list(n_grams)
                
                possible_pred1 = possible_pred[0]
                possible_pred2 = possible_pred[1]
                
                while(possible_pred1!='?'):
                    pred1.append(possible_pred1)
                    n_grams_list1.append(possible_pred1)                
                    n_grams_list1 = n_grams_list1[1:]
                    possible_pred1 = list(cpdist_list[len(cpdist_list)-len_n_grams][tuple(n_grams_list1)].samples())[0]
                    
                pred1.append('?')
                print(' '.join(pred1))
                
                while(possible_pred2!='?'):
                    pred2.append(possible_pred2)
                    n_grams_list2.append(possible_pred2)                
                    n_grams_list2 = n_grams_list2[1:]
                    possible_pred2 = list(cpdist_list[len(cpdist_list)-len_n_grams][tuple(n_grams_list2)].samples())[0]
                    
                pred2.append('?')
                print(' '.join(pred2))
                
                return
    
    else:
        #if prediciton is not available for the provided n_grams backoff
        n_grams = n_grams[1:]
        predict_next_using_n_grams(n_grams, cpdist_list,mode)

# %%
predict_next_using_n_grams(("who","is","the"),cp_list,'nsent')
# Out:
# quarterback for the panthers ?
# commissioner of the national football league ?

# %%
"who","is","the","oldest","quarterback","to","play","in","a","super","bowl","by","the","time","they","reached","super","bowl","50"

# %%
t =("who","is","the","oldest","quarterback")
## check why this is still predicting

'super', 'bowl', '50', '?']
13

# %%
t = list(t)
t.append('a')
t
# Out:
# ['who', 'is', 'the', 'oldest', 'quarterback', 'a']

# %%
type(t)
# Out:
# NoneType

# %% [markdown]
# ### keeping only a-z and 0-9

# %%
questions = re.sub(r"(^\w|\')", ' ', questions)

# %%
questions = questions.lower()

# %%
words = nltk.word_tokenize(questions)

# %% [markdown]
# ### n-grams : 4 grams

# %%
_4grams = ngrams(words,4)

# %%
_4grams = list(_4grams)

# %%
_4grams
# Out:
# [('what', 'city', 'did', 'super'),
#  ('city', 'did', 'super', 'bowl'),
#  ('did', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'take'),
#  ('bowl', '50', 'take', 'place'),
#  ('50', 'take', 'place', 'in'),
#  ('take', 'place', 'in', 'what'),
#  ('place', 'in', 'what', 'venue'),
#  ('in', 'what', 'venue', 'did'),
#  ('what', 'venue', 'did', 'super'),
#  ('venue', 'did', 'super', 'bowl'),
#  ('did', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'take'),
#  ('bowl', '50', 'take', 'place'),
#  ('50', 'take', 'place', 'in'),
#  ('take', 'place', 'in', 'what'),
#  ('place', 'in', 'what', 'was'),
#  ('in', 'what', 'was', 'the'),
#  ('what', 'was', 'the', 'theme'),
#  ('was', 'the', 'theme', 'of'),
#  ('the', 'theme', 'of', 'super'),
#  ('theme', 'of', 'super', 'bowl'),
#  ('of', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'super'),
#  ('bowl', '50', 'super', 'bowl'),
#  ('50', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'decided'),
#  ('bowl', '50', 'decided', 'the'),
#  ('50', 'decided', 'the', 'nfl'),
#  ('decided', 'the', 'nfl', 'champion'),
#  ('the', 'nfl', 'champion', 'for'),
#  ('nfl', 'champion', 'for', 'what'),
#  ('champion', 'for', 'what', 'season'),
#  ('for', 'what', 'season', 'what'),
#  ('what', 'season', 'what', 'team'),
#  ('season', 'what', 'team', 'was'),
#  ('what', 'team', 'was', 'the'),
#  ('team', 'was', 'the', 'nfc'),
#  ('was', 'the', 'nfc', 'champion'),
#  ('the', 'nfc', 'champion', 'super'),
#  ('nfc', 'champion', 'super', 'bowl'),
#  ('champion', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 
#  ('points', 'for', 'denver', 'how'),
#  ('for', 'denver', 'how', 'many'),
#  ('denver', 'how', 'many', 'times'),
#  ('how', 'many', 'times', 'did'),
#  ('many', 'times', 'did', 'the'),
#  ('times', 'did', 'the', 'broncos'),
#  ('did', 'the', 'broncos', 'cause'),
#  ('the', 'broncos', 'cause', 'turnovers'),
#  ('broncos', 'cause', 'turnovers', 'in'),
#  ('cause', 'turnovers', 'in', 'the'),
#  ('turnovers', 'in', 'the', 'game'),
#  ('in', 'the', 'game', 'what'),
#  ('the', 'game', 'what', 'denver'),
#  ('game', 'what', 'denver', 'player'),
#  ('what', 'denver', 'player', 'caused'),
#  ('denver', 'player', 'caused', 'two'),
#  ('player', 'caused', 'two', 'fumbles'),
#  ('caused', 'two', 'fumbles', 'for'),
#  ('two', 'fumbles', 'for', 'the'),
#  ('fumbles', 'for', 'the', 'panthers'),
#  ('for', 'the', 'panthers', 'how'),
#  ('the', 'panthers', 'how', 'many'),
#  ('panthers', 'how', 'many', 'times'),
#  ('how', 'many', 'times', 'did'),
#  ('many', 'times', 'did', 'the'),
#  ('times', 'did', 'the', 'denver'),
#  ('did', 'the', 'denver', 'defense'),
#  ('the', 'denver', 'defense', 'force'),
#  ('denver', 'defense', 'force', 'newton'),
#  ('defense', 'force', 'newton', 'into'),
#  ('force', 'newton', 'into', 'turnovers'),
#  ('newton', 'into', 'turnovers', 'how'),
#  ('into', 'turnovers', 'how', 'many'),
#  ('turnovers', 'how', 'many', 'fumbles'),
#  ('how', 'many', 'fumbles', 'did'),
#  ('many', 'fumbles', 'did', 'von'),
#  ('fumbles', 'did', 'von', 'miller'),
#  ('did', 'von', 'miller', 'force'),
#  ('von', 'miller', 'force', 'in'),
#  ('miller', 'force', 'in', 'super'),
#  ('force', 'in', 'super', 'bowl'),
#  ('in', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'which'),
#  ('bowl', '50', 'which', 'team'),
#  ('50', 'which', 'team', 'held'),
#  ('which', 'team', 'held', 'the'),
#  ('team', 'held', 'the', 'scoring'),
#  ('held', 'the', 'scoring', 'lead'),
#  ('the', 'scoring', 'lead', 'throughout'),
#  ('scoring', 'lead', 'throughout', 'the'),
#  ('lead', 'throughout', 'the', 'entire'),
#  ('throughout', 'the', 'entire', 'game'),
#  ('the', 'entire', 'game', 'how'),
#  ('entire', 'game', 'how', 'many'),
#  ('game', 'how', 'many', 'times'),
#  ('how', 'many', 'times', 'was'),
#  ('many', 'times', 'was', 'cam'),
#  ('times', 'was', 'cam', 'newton'),
#  ('was', 'cam', 'newton', 'sacked'),
#  ('cam', 'newton', 'sacked', 'how'),
#  ('newton', 'sacked', 'how', 'many'),
#  ('sacked', 'how', 'many', 'forced'),
#  ('how', 'many', 'forced', 'fumbles'),
#  ('many', 'forced', 'fumbles', 'did'),
#  ('forced', 'fumbles', 'did', 'von'),
#  ('fumbles', 'did', 'von', 'miller'),
#  ('did', 'von', 'miller', 'have'),
#  ('von', 'miller', 'have', 'during'),
#  ('miller', 'have', 'during', 'the'),
#  ('have', 'during', 'the', 'super'),
#  ('during', 'the', 'super', 'bowl'),
#  ('the', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'game'),
#  ('bowl', '50', 'game', 'how'),
#  ('50', 'game', 'how', 'many'),
#  ('game', 'how', 'many', 'tackles'),
#  ('how', 'many', 'tackles', 'did'),
#  ('many', 'tackles', 'did', 'von'),
#  ('tackles', 'did', 'von', 'miller'),
#  ('did', 'von', 'miller', 'get'),
#  ('von', 'miller', 'get', 'during'),
#  ('miller', 'get', 'during', 'the'),
#  ('get', 'during', 'the', 'game'),
#  ('during', 'the', 'game', 'what'),
#  ('the', 'game', 'what', 'position'),
#  ('game', 'what', 'position', 'does'),
#  ('what', 'position', 'does', 'von'),
#  ('position', 'does', 'von', 'miller'),
#  ('does', 'von', 'miller', 'play'),
#  ('von', 'miller', 'play', 'for'),
#  ('miller', 'play', 'for', 'the'),
#  ('play', 'for', 'the', 'denver'),
#  ('for', 'the', 'denver', 'broncos'),
#  ('the', 'denver', 'broncos', 'who'),
#  ('denver', 'broncos', 'who', 'was'),
#  ('broncos', 'who', 'was', 'the'),
#  ('who', 'was', 'the', 'most'),
#  ('was', 'the', 'most', 'valuable'),
#  ('the', 'most', 'valuable', 'player'),
#  ('most', 'valuable', 'player', 'of'),
#  ('valuable', 'player', 'of', 'super'),
#  ('player', 'of', 'super', 'bowl'),
#  ('of', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'who'),
#  ('bowl', '50', 'who', 'was'),
#  ('50', 'who', 'was', 'the'),
#  ('who', 'was', 'the', 'super'),
#  ('was', 'the', 'super', 'bowl'),
#  ('the', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'mvp'),
#  ('bowl', '50', 'mvp', 'who'),
#  ('50', 'mvp', 'who', 'won'),
#  ('mvp', 'who', 'won', 'the'),
#  ('who', 'won', 'the', 'mvp'),
#  ('won', 'the', 'mvp', 'for'),
#  ('the', 'mvp', 'for', 'the'),
#  ('mvp', 'for', 'the', 'super'),
#  ('for', 'the', 'super', 'bowl'),
#  ('the', 'super', 'bowl', 'how'),
#  ('super', 'bowl', 'how', 'many'),
#  ('bowl', 'how', 'many', 'fumbles'),
#  ('how', 'many', 'fumbles', 'did'),
#  ('many', 'fumbles', 'did', 'von'),
#  ('fumbles', 'did', 'von', 'miller'),
#  ('did', 'von', 'miller', 'force'),
#  ('von', 'miller', 'force', 'how'),
#  ('miller', 'force', 'how', 'many'),
#  ('force', 'how', 'many', 'times'),
#  ('how', 'many', 'times', 'was'),
#  ('many', 'times', 'was', 'cam'),
#  ('times', 'was', 'cam', 'newton'),
#  ('was', 'cam', 'newton', 'sacked'),
#  ('cam', 'newton', 'sacked', 'in'),
#  ('newton', 'sacked', 'in', 'super'),
#  ('sacked', 'in', 'super', 'bowl'),
#  ('in', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'how'),
#  ('bowl', '50', 'how', 'many'),
#  ('50', 'how', 'many', 'tackles'),
#  ('how', 'many', 'tackles', 'did'),
#  ('many', 'tackles', 'did', 'von'),
#  ('tackles', 'did', 'von', 'miller'),
#  ('did', 'von', 'miller', 'accomlish'),
#  ('von', 'miller', 'accomlish', 'by'),
#  ('miller', 'accomlish', 'by', 'himself'),
#  ('accomlish', 'by', 'himself', 'in'),
#  ('by', 'himself', 'in', 'the'),
#  ('himself', 'in', 'the', 'game'),
#  ('in', 'the', 'game', 'who'),
#  ('the', 'game', 'who', 'was'),
#  ('game', 'who', 'was', 'given'),
#  ('who', 'was', 'given', 'the'),
#  ('was', 'given', 'the', 'esteemed'),
#  ('given', 'the', 'esteemed', 'status'),
#  ('the', 'esteemed', 'status', 'of'),
#  ('esteemed', 'status', 'of', 'mvp'),
#  ('status', 'of', 'mvp', 'for'),
#  ('of', 'mvp', 'for', 'super'),
#  ('mvp', 'for', 'super', 'bowl'),
#  ('for', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'who'),
#  ('bowl', '50', 'who', 'won'),
#  ('50', 'who', 'won', 'the'),
#  ('who', 'won', 'the', 'super'),
#  ('won', 'the', 'super', 'bowl'),
#  ('the', 'super', 'bowl', 'mvp'),
#  ('super', 'bowl', 'mvp', 'which'),
#  ('bowl', 'mvp', 'which', 'denver'),
#  ('mvp', 'which', 'denver', 'linebacker'),
#  ('which', 'denver', 'linebacker', 'was'),
#  ('denver', 'linebacker', 'was', 'named'),
#  ('linebacker', 'was', 'named', 'super'),
#  ('was', 'named', 'super', 'bowl'),
#  ('named', 'super', 'bowl', 'mvp'),
#  ('super', 'bowl', 'mvp', 'who'),
#  ('bowl', 'mvp', 'who', 'was'),
#  ('mvp', 'who', 'was', 'limited'),
#  ('who', 'was', 'limited', 'by'),
#  ('was', 'limited', 'by', 'denver'),
#  ('limited', 'by', 'denver', 's'),
#  ('by', 'denver', 's', 'defense'),
#  ('denver', 's', 'defense', 'what'),
#  ('s', 'defense', 'what', 'position'),
#  ('defense', 'what', 'position', 'does'),
#  ('what', 'position', 'does', 'von'),
#  ('position', 'does', 'von', 'miller'),
#  ('does', 'von', 'miller', 'play'),
#  ('von', 'miller', 'play', 'what'),
#  ('miller', 'play', 'what', 'was'),
#  ('play', 'what', 'was', 'the'),
#  ('what', 'was', 'the', 'number'),
#  ('was', 'the', 'number', 'of'),
#  ('the', 'number', 'of', 'solo'),
#  ('number', 'of', 'solo', 'tackles'),
#  ('of', 'solo', 'tackles', 'that'),
#  ('solo', 'tackles', 'that', 'von'),
#  ('tackles', 'that', 'von', 'miller'),
#  ('that', 'von', 'miller', 'had'),
#  ('von', 'miller', 'had', 'in'),
#  ('miller', 'had', 'in', 'super'),
#  ('had', 'in', 'super', 'bowl'),
#  ('in', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'how'),
#  ('bowl', '50', 'how', 'many'),
#  ('50', 'how', 'many', 'solo'),
#  ('how', 'many', 'solo', 'tackles'),
#  ('many', 'solo', 'tackles', 'did'),
#  ('solo', 'tackles', 'did', 'von'),
#  ('tackles', 'did', 'von', 'miller'),
#  ('did', 'von', 'miller', 'make'),
#  ('von', 'miller', 'make', 'at'),
#  ('miller', 'make', 'at', 'super'),
#  ('make', 'at', 'super', 'bowl'),
#  ('at', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'how'),
#  ('bowl', '50', 'how', 'many'),
#  ('50', 'how', 'many', 'times'),
#  ('how', 'many', 'times', 'was'),
#  ('many', 'times', 'was', 'the'),
#  ('times', 'was', 'the', 'panthers'),
#  ('was', 'the', 'panthers', 'quarterback'),
#  ('the', 'panthers', 'quarterback', 'sacked'),
#  ('panthers', 'quarterback', 'sacked', 'how'),
#  ('quarterback', 'sacked', 'how', 'many'),
 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'which'),
#  ('bowl', '50', 'which', 'network'),
#  ('50', 'which', 'network', 'broadcasted'),
#  ('which', 'network', 'broadcasted', 'super'),
#  ('network', 'broadcasted', 'super', 'bowl'),
#  ('broadcasted', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'in'),
#  ('bowl', '50', 'in', 'the'),
#  ('50', 'in', 'the', 'u'),
#  ('in', 'the', 'u', 's'),
#  ('the', 'u', 's', 'at'),
#  ('u', 's', 'at', 'which'),
#  ('s', 'at', 'which', 'super'),
#  ('at', 'which', 'super', 'bowl'),
#  ('which', 'super', 'bowl', 'did'),
#  ('super', 'bowl', 'did', 'beyonce'),
#  ('bowl', 'did', 'beyonce', 'headline'),
#  ('did', 'beyonce', 'headline', 'the'),
#  ('beyonce', 'headline', 'the', 'halftime'),
#  ('headline', 'the', 'halftime', 'show'),
#  ('the', 'halftime', 'show', 'what'),
#  ('halftime', 'show', 'what', 'band'),
#  ('show', 'what', 'band', 'headlined'),
#  ('what', 'band', 'headlined', 'half'),
#  ('band', 'headlined', 'half', 'time'),
#  ('headlined', 'half', 'time', 'during'),
#  ('half', 'time', 'during', 'super'),
#  ('time', 'during', 'super', 'bowl'),
#  ('during', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'how'),
#  ('bowl', '50', 'how', 'much'),
#  ('50', 'how', 'much', 'money'),
#  ('how', 'much', 'money', 'did'),
#  ('much', 'money', 'did', 'a'),
#  ('money', 'did', 'a', '1'),
#  ('did', 'a', '1', '2'),
#  ('a', '1', '2', 'minute'),
#  ('1', '2', 'minute', 'commercial'),
#  ('2', 'minute', 'commercial', 'cost'),
#  ('minute', 'commercial', 'cost', 'what'),
#  ('commercial', 'cost', 'what', 'ranking'),
#  ('cost', 'what', 'ranking', 'does'),
#  ('what', 'ranking', 'does', 'the'),
#  ('ranking', 'does', 'the', 'super'),
#  ('does', 'the', 'super', 'bowl'),
#  ('the', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'halftime'),
#  ('bowl', '50', 'halftime', 'show'),
#  ('50', 'halftime', 'show', 'have'),
#  ('halftime', 'show', 'have', 'on'),
#  ('show', 'have', 'on', 'the'),
#  ('have', 'on', 'the', 'list'),
#  ('on', 'the', 'list', 'of'),
#  ('the', 'list', 'of', 'most'),
#  ('list', 'of', 'most', 'watched'),
#  ('of', 'most', 'watched', 'tv'),
#  ('most', 'watched', 'tv', 'broadcasts'),
#  ('watched', 'tv', 'broadcasts', 'which'),
#  ('tv', 'broadcasts', 'which', 'network'),
#  ('broadcasts', 'which', 'network', 'broadcasted'),
#  ('which', 'network', 'broadcasted', 'the'),
#  ('network', 'broadcasted', 'the', '50th'),
#  ('broadcasted', 'the', '50th', 'super'),
#  ('the', '50th', 'super', 'bowl'),
#  ('50th', 'super', 'bowl', 'game'),
#  ('super', 'bowl', 'game', 'what'),
#  ('bowl', 'game', 'what', 'halftime'),
#  ('game', 'what', 'halftime', 'performer'),
#  ('what', 'halftime', 'performer', 'previously'),
#  ('halftime', 'performer', 'previously', 'headlined'),
#  ('performer', 'previously', 'headlined', 'super'),
#  ('previously', 'headlined', 'super', 'bowl'),
#  ('headlined', 'super', 'bowl', 'xlviii'),
#  ('super', 'bowl', 'xlviii', 'which'),
#  ('bowl', 'xlviii', 'which', 'super'),
#  ('xlviii', 'which', 'super', 'bowl'),
#  ('which', 'super', 'bowl', 'halftime'),
#  ('super', 'bowl', 'halftime', 'show'),
#  ('bowl', 'halftime', 'show', 'did'),
#  ('halftime', 'show', 'did', 'beyoncé'),
#  ('show', 'did', 'beyoncé', 'headline'),
#  ('did', 'beyoncé', 'headline', 'what'),
#  ('beyoncé', 'headline', 'what', 'halftime'),
#  ('headline', 'what', 'halftime', 'performer'),
#  ('what', 'halftime', 'performer', 'previously'),
#  ('halftime', 'performer', 'previously', 'headlined'),
#  ('performer', 'previously', 'headlined', 'super'),
#  ('previously', 'headlined', 'super', 'bowl'),
#  ('headlined', 'super', 'bowl', 'xlvii'),
#  ('super', 'bowl', 'xlvii', 'what'),
#  ('bowl', 'xlvii', 'what', 'was'),
#  ('xlvii', 'what', 'was', 'the'),
#  ('what', 'was', 'the', 'average'),
#  ('was', 'the', 'average', 'cost'),
#  ('the', 'average', 'cost', 'for'),
#  ('average', 'cost', 'for', 'a'),
#  ('cost', 'for', 'a', 'tv'),
#  ('for', 'a', 'tv', 'ad'),
#  ('a', 'tv', 'ad', 'lasting'),
#  ('tv', 'ad', 'lasting', '30'),
#  ('ad', 'lasting', '30', 'seconds'),
#  ('lasting', '30', 'seconds', 'during'),
#  ('30', 'seconds', 'during', 'super'),
#  ('seconds', 'during', 'super', 'bowl'),
#  ('during', 'super', 'bowl', '50'),
#  ('super', 'bowl', '50', 'who'),
#  ('bowl', '50', 'who', 'were'),
#  ('50', 'who', 'were', 'special'),
#  ('who', 'were', 'special', 'guests'),
#  ('were', 'special', 'guests', 'for'),
#  ('special', 'guests', 'for', 'the'),
#  ('guests', 'for', 'the', 'super'),
#  ('for', 'the', 'super', 'bowl'),
#  ('the', 'super', 'bowl', 'halftime'),
#  ('super', 'bowl', 'halftime', 'show'),
#  ('bowl', 'halftime', 'show', 'who'),
#  ('halftime', 'show', 'who', 'is'),
#  ('show', 'who', 'is', 'the'),
#  ('who', 'is', 'the', 'commissioner'),
#  ('is', 'the', 'commissioner', 'of'),
#  ('the', 'commissioner', 'of', 'the'),
#  ('commissioner', 'of', 'the', 'national'),
#  ('of', 'the', 'national', 'football'),
#  ('the', 'national', 'football', 'league'),
#  ('national', 'football', 'league', 'who'),
#  ('football', 'league', 'who', 'was'),
#  ...]

# %%
cfdist = ConditionalFreqDist()

# %%
_4grams_to_predict_3grams =  [(_4gram[:-1],_4gram[-1]) for _4gram in _4grams]

# %%
#_4grams_to_predict_3grams

# %%
cfdist = ConditionalFreqDist(_4grams_to_predict_3grams)

# %%
cfdist
# ('able',): FreqDist({'to': 1}),
# Out:
# ConditionalFreqDist(nltk.probability.FreqDist,
#                     {('who', 'did', 'junipero'): FreqDist({'serra': 1}),
#                      ('grimm', 'found', 'dead'): FreqDist({'what': 1}),
#                      ('claridge', 'acquire', 'patents'): FreqDist({'for': 1}),
#                      ('a', 'valid', 'concept'): FreqDist({'since': 1}),
#                      ('penn', 'square', 'bank'): FreqDist({'go': 1}),
#                      ('recognition', 'what', 'did'): FreqDist({'yale': 1}),
#                      ('resupply', 'attempts', 'by'): FreqDist({'the': 1}),
#                      ('the', 'company', 'when'): FreqDist({'was': 1}),
#                      ('july', '31', 'where'): FreqDist({'was': 1}),
#                      ('does', 'the', 'kinetic'): FreqDist({'energy': 1}),
#                      ('next', 'best', 'outcome'): FreqDist({'how': 1}),
#                      ('carrier', 'and', 'a'): FreqDist({'land': 1}),
#                      ('society', 'was', 'studied'): FreqDist({'to': 1}),
#                      ('did', 'august', 'von'): FreqDist({'hayek': 2}),
#                      ('melbourne', 'named', 'in'): FreqDist({'honor': 1}),
#                      ('9th',
#                       'century',
#                       'documents'): FreqDist({'describing': 1}),
#                      ('long', 'should', 'the'): FreqDist({'plastic': 1}),
#                      ('same', 'status', 'what'): FreqDist({'is': 1}),
#                      ('against', 'muawiyah', 'who'): FreqDist({'was': 1}),
#                      ('french', 'victory', 'at'): FreqDist({'rivoli': 1}),
#                      ('valencian', 'when', 'did'): FreqDist({'valencian': 1}),
#                      ('parliament', 'had', 'meetings'): FreqDist({'in': 1}),
#                      ('rapid', 'decompression', 'do'): FreqDist({'to': 1}),
#                      ('district', 'did', 'the'): FreqDist({'roman': 1}),
#                      ('us', 'what', 'rate'): FreqDist({'of': 1}),
#                      ('by', 'whom', 'did'): FreqDist({'st': 1}),
#                      ('in', 'the', 'inaugural'): FreqDist({'year': 1}),
#                      ('for', 'red', 'being'): FreqDist({'worn': 1}),
#                      ('did', 'kanye', 'open'): FreqDist({'when': 1}),
#                      ('year', 'award', 'to'): FreqDist({'which': 1}),
#                      ('kerry', 'earn', 'his'): FreqDist({'2nd': 2}),
#                      ('vault', 'before', 'landing'): FreqDist({'in': 1}),
#                      ('attacked', 'burke', 'for'): FreqDist({'receiving': 1}),
#                      ('beside', 'to', 'which'): FreqDist({'structure': 1}),
#                      ('plays', 'was', 'denver'): FreqDist({'kept': 1}),
#                      ('gregorian', 'calendar', 'not'): FreqDist({'simple': 1}),
#                      ('gives', 'the', 'president'): FreqDist({'advice': 1}),
#                      ('gaza', 'strip', 'after'): FreqDist({'1967': 1}),
#                      ('published',
#                       'an',
#                       'influential'): FreqDist({'reclassification': 1}),
#                      ('using', 'what', 'muscular'): FreqDist({'chamber': 1}),
#                      ('the', 'riches', 'of'): FreqDist({'the': 1}),
#                      ('perception', 'is', 'not'): FreqDist({'limited': 1}),
#                      ('private', 'law', 'school'): FreqDist({'is': 1}),
#                      ('upgrade',
#                       'transmission',
#                       'equipment'): FreqDist({'from': 1}),
#                      ('a', 'polynomial', 'in'): FreqDist({'t': 1}),
#                      ('did', 'a', 'few'): FreqDist({'scholars': 1}),
#                      ('s', 'natural', 'history'): FreqDist({'lectures': 1}),
#                      ('than', 'metal', 'why'): FreqDist({'isn': 1}),
#                      ('did', 'the', 'author'): FreqDist({'of': 2}),
#                      ('beijing', 'how', 'many'): FreqDist({'died': 1}),
#                      ('how', 'books', 'did'): FreqDist({'alexander': 1}),
#                      ('slang', 'term', 'from'): FreqDist({'a': 1}),
#                      ('gothic', 'construction', 'that'): FreqDist({'is': 2}),
#                      ('a', 'time', 'machine'): FreqDist({'is': 1}),
#                      ('a', 'straw', 'why'): FreqDist({'are': 1}),
#                      ('newspaper', 'offices', 'are'): FreqDist({'located': 1}),
#                      ('galician', 'during', 'what'): FreqDist({'era': 1}),
#                      ('national', 'gallery', 'of'): FreqDist({'art': 1}),
#                      ('johan', 'cruyff', 'join'): FreqDist({'barcelona': 1}),
#                      ('did', 'cbc', 'move'): FreqDist({'the': 1}),
#                      ('hotels', 'located', 'in'): FreqDist({'what': 1}),
#                      ('league', 'members', 'have'): FreqDist({'relations': 1}),
#                      ('2009', 'which', 'swiss'): FreqDist({'professional': 1}),
#                      ('spots', 'migrate', 'too'): FreqDist({'close': 1}),
#                      ('refused', 'to', 'adopt'): FreqDist({'a': 1, 'when': 1}),
#                      ('was', 'henry', 'hudson'): FreqDist({'working': 1}),
#                      ('gas',
#                       'contain',
#                       'what'): FreqDist({'percent': 1, 'state': 1}),
#                      ('for', 'the', 'relative'): FreqDist({'separating': 1}),
#                      ('western', 'hemisphere', 'the'): FreqDist({'court': 1}),
#                      ('don', 't', 'affect'): FreqDist({'what': 1}),
#                      ('is', 'receiving', 'a'): FreqDist({'crown': 1}),
#                      ('is', 'arthur', 'barnett'): FreqDist({'in': 1}),
#                      ('aztec', 'empire', 'conquered'): FreqDist({'how': 1}),
#                      ('out',
#                       'about',
#                       'the'): FreqDist({'importance': 1,
#                                'language': 1,
#                                'theory': 1}),
#                      ('the', 'anterior', 'section'): FreqDist({'is': 1}),
#                      ('is', 'britain', 's'): FreqDist({'busiest': 1}),
#                      ('was', 'inveted', 'in'): FreqDist({'san': 1}),
#                      ('poor', 'speaking', 'abilities'): FreqDist({'who': 1}),
#                      ('aristotle', 'defined', 'time'): FreqDist({'as': 1}),
#                      ('have', 'the', 'leeside'): FreqDist({'lions': 1}),
#                      ('determine', 'ritual', 'what'): FreqDist({'common': 1}),
#                      ('giving', 'what', 'is'): FreqDist({'another': 1}),
#                      ('were', 'they', 'preparing'): FreqDist({'food': 1}),
#                      ('what', 'a', '2010'): FreqDist({'leaked': 1}),
#                      ('west', 'how', 'old'): FreqDist({'was': 1}),
#                      ('satellite', 'dish', 'at'): FreqDist({'the': 1}),
#                      ('attended',
#                       'the',
#                       'funeral'): FreqDist({'of': 1, 'who': 1}),
#                      ('donate', 'passion', 'of'): FreqDist({'christ': 2}),
#                      ('what', 'was', 'tymnet'): FreqDist({'gateways': 1}),
#                      ('what',
#                       'was',
#                       'madonna'): FreqDist({'dressed': 1,
#                                's': 8,
#                                'wearing': 1}),
#                      ('are', 'short', 'range'): FreqDist({'bluetooth': 1}),
#                      ('well', 'as', 'getting'): FreqDist({'navigational': 1}),
#                      ('world', 'cup', 'able'): FreqDist({'to': 1}),
#                      ('cleopatra', 'arsinoe', 'or'): FreqDist({'berenice': 1}),
#                      ('to', 'find', 'southwest'): FreqDist({'airlines': 1}),
#                      ('st',
#                       'barts',
#                       'import'): FreqDist({'its': 1, 'most': 1}),
#                      ('to',
#                       'tigheten',
#                       'regulations'): FreqDist({'concerning': 1}),
#                      ('red', 'pigment', 'alizarin'): FreqDist({'what': 1}),
#                      ('his', '1952', 'book'): FreqDist({'that': 1, 'what': 1}),
#                      ('large', 'change', 'in'): FreqDist({'current': 1}),
#                      ('running', 'in', 'what'): FreqDist({'year': 1}),
#                      ('battle', 'for', 'mexico'): FreqDist({'city': 1}),
#                      ('end', 'the', 'monopoly'): FreqDist({'that': 1}),
#                      ('did',
#                       'ancient',
#                       'cultures'): FreqDist({'and': 1, 'consider': 1}),
#                      ('the', 'response', 'was'): FreqDist({'hostile': 1}),
#                      ('lines', 'out', 'of'): FreqDist({'union': 1}),
#                      ('which', 'war', 'played'): FreqDist({'a': 1}),
#                      ('five', 'great', 'powers'): FreqDist({'what': 1}),
#                      ('ballerinas', 'came', 'from'): FreqDist({'oklahoma': 1}),
#                      ('shaped', 'how', 'do'): FreqDist({'both': 1}),
#                      ('a', 'students', 'does'): FreqDist({'the': 1}),
#                      ('place', 'damaged', 'aircraft'): FreqDist({'can': 1}),
#                      ('machine', 'vision', 'system'): FreqDist({'leds': 1}),
#                      ('glass', 'ceramics', 'its'): FreqDist({'useful': 1}),
#                      ('relationship',
#                       'with',
#                       'alexis'): FreqDist({'phifer': 1}),
#                      ('amount',
#                       'of',
#                       'time'): FreqDist({'a': 1,
#                                'adolescents': 1,
#                                'before': 1,
#                                'dutch': 1,
#                                'his': 1,
#                                'men': 1,
#                                'on': 1,
#                                'that': 1,
#                                'under': 1,
#                                'was': 1,
#                                'what': 1}),
#                      ('in', 'nine', 'games'): FreqDist({'as': 1}),
#                      ('brown', 'school', 's'): FreqDist({'current': 1}),
#                      ('that', 'had', 'data'): FreqDist({'stored': 1}),
#                      ('when', 'did', 'greenland'): FreqDist({'sign': 1}),
#                      ('bring', 'to', 'eritrea'): FreqDist({'during': 1}),
#                      ('presbyterians', 'have', 'in'): FreqDist({'the': 1}),
#                      ('united',
#                       'kingdom',
#                       'and'): FreqDist({'france': 1, 'other': 1, 'the': 3}),
#                      ('the',
#                       'smallest',
#                       'administrative'): FreqDist({'unit': 1}),
#                      ('building', 'structure', 'what'): FreqDist({'was': 1}),
#                      ('itself', 'on', 'december'): FreqDist({'12': 1}),
#                      ('percentage', 'of', 'tb'): FreqDist({'cases': 1}),
#                      ('causes', 'more', 'deaths'): FreqDist({'than': 1}),
#                      ('shared', 'between', 'south'): FreqDist({'africa': 1}),
#                      ('at', 'salon', 'd'): FreqDist({'automne': 1}),
#                      ('litter', 'canines', 'called'): FreqDist({'canis': 1}),
#                      ('constructed', 'from', 'when'): FreqDist({'is': 1}),
#                      ('of', 'labels', 'youtube'): FreqDist({'had': 1}),
#                      ('the', 'pilgrims', 'go'): FreqDist({'to': 1}),
#                      ('ancestry', 'grouped', 'as'): FreqDist({'what': 1}),
#                      ('jewish', 'scorn', 'for'): FreqDist({'the': 1}),
#                      ('of', 'viewing', 'a'): FreqDist({'3d': 1}),
#                      ('from', 'antarctica', 'when'): FreqDist({'did': 1}),
#                      ('in', 'the', 'alternate'): FreqDist({'year': 1}),
#                      ('debated', 'as', 'a'): FreqDist({'possible': 1}),
#                      ('on', 'george', 'iv'): FreqDist({'bridge': 1}),
#                      ('and', 'cultural', 'prominence'): FreqDist({'for': 1}),
#                      ('position', 'of', 'what'): FreqDist({'is': 1}),
#                      ('of', 'the', 'walt'): FreqDist({'disney': 1}),
#                      ('team', 'in', '1938'): FreqDist({'used': 1}),
#                      ('were', 'recorded', 'at'): FreqDist({'the': 1}),
#                      ('theater', 'companies', 'are'): FreqDist({'there': 1}),
#                      ('efficient', 'whose', 'idea'): FreqDist({'was': 1}),
#                      ('form', 'dioxygen', 'what'): FreqDist({'is': 1}),
#                      ('the',
#                       'yuan',
#                       's'): FreqDist({'increase': 1,
#                                'paper': 1,
#                                'persian': 1,
#                                'social': 1,
#                                'unofficial': 1}),
#                      ('pope', 's', 'confessor'): FreqDist({'a': 1}),
#                      ('otto', 'robert', 'frisch'): FreqDist({'what': 1}),
#                      ('minister', 'to', 'resign'): FreqDist({'in': 1}),
#                      ('recognized', 'as', 'permitting'): FreqDist({'no': 1}),
#                      ('lobes', 'are', 'based'): FreqDist({'on': 1}),
#                      ('distinction',
#                       'has',
#                       'comcast'): FreqDist({'earned': 1}),
#                      ('lengthed', 'the', 'antenna'): FreqDist({'to': 1}),
#                      ('what',
#                       'property',
#                       'does'): FreqDist({'combining': 1,
#                                'copper': 1,
#                                'the': 1}),
#                      ('initialism', 'of', 'in'): FreqDist({'what': 1}),
#                      ('reform', 'leader', 'teach'): FreqDist({'when': 1}),
#                      ('year', 'did', 'color'): FreqDist({'broadcasts': 1}),
#                      ('even',
#                       'translations',
#                       'completely'): FreqDist({'done': 1}),
#                      ('combat',
#                       'information',
#                       'centers'): FreqDist({'where': 1}),
#                      ('how', 'do', 'polytheistic'): FreqDist({'religions': 1}),
#                      ('nigerian', 'political', 'party'): FreqDist({'was': 3}),
#                      ('of', 'dogs', 'and'): FreqDist({'existing': 1}),
#                      ('behavioral', 'qualities', 'which'): FreqDist({'of': 1}),
#                      ('on', 'the', 'blockhouses'): FreqDist({'by': 1}),
#                      ('which', 'ama', 'category'): FreqDist({'did': 1}),
#                      ('plants', 'usually', 'shaped'): FreqDist({'how': 1}),
#                      ('can', 'distances', 'in'): FreqDist({'space': 1}),
#                      ('of', 'jiaxing', 'what'): FreqDist({'does': 1}),
#                      ('self',
#                       'executing',
#                       'treaties'): FreqDist({'typically': 1}),
#                      ('own', 'their', 'homes'): FreqDist({'how': 1}),
#                      ('a', 'palermo', 'resident'): FreqDist({'what': 1}),
#                      ('last',
#                       'for',
#                       'what'): FreqDist({'parade': 1, 'year': 1}),
#                      ('jay', 'who', 'founded'): FreqDist({'the': 1}),
#                      ('college', 'dropout', 'receive'): FreqDist({'how': 1}),
#                      ('home',
#                       'run',
#                       'record'): FreqDist({'sammy': 1, 'what': 1, 'when': 1}),
#                      ('commitment', 'who', 'insisted'): FreqDist({'that': 1}),
#                      ('in',
#                       'tibet',
#                       'what'): FreqDist({'are': 1,
#                                'does': 1,
#                                'is': 6,
#                                'was': 1,
#                                'were': 1}),
#                      ('expands', 'called', 'what'): FreqDist({'will': 1}),
#                      ('organs', 'are', 'described'): FreqDist({'as': 1}),
#                      ('las', 'two', 'counties'): FreqDist({'to': 1}),
#                      ('organization', 'payed', 'for'): FreqDist({'the': 1}),
#                      ('in', 'the', 'gempei'): FreqDist({'war': 1}),
#                      ('who', 'was', 'employed'): FreqDist({'on': 1}),
#                      ('date', 'before', 'the'): FreqDist({'day': 1}),
#                      ('standards', 'for', 'encoders'): FreqDist({'and': 1}),
#                      ('greek', 'lenited', 'to'): FreqDist({'what': 1}),
#                      ('to', 'address', 'french'): FreqDist({'in': 1}),
#                      ('year', 'does', 'fresno'): FreqDist({'get': 1}),
#                      ('crisis', 'where', 'does'): FreqDist({'the': 1}),
#                      ('marvel', 's', 'first'): FreqDist({'team': 1}),
#                      ('get', 'red', 'or'): FreqDist({'yellow': 1}),
#                      ('was', 'recaptured', 'as'): FreqDist({'a': 1}),
#                      ('yorkers', 'take', 'advantage'): FreqDist({'of': 1}),
#                      ('ascribed', 'to', 'what'): FreqDist({'period': 1}),
#                      ('primary',
#                       'method',
#                       'for'): FreqDist({'determining': 1, 'haa': 1}),
#                      ('same', 'language', 'how'): FreqDist({'many': 1}),
#                      ('name', 'switzer', 'originate'): FreqDist({'from': 1}),
#                      ('is', 'an', 'anglo'): FreqDist({'saxon': 1}),
#                      ('that', 'could', 'trace'): FreqDist({'their': 1}),
#                      ('what', 'artifact', 'did'): FreqDist({'indy': 1}),
#                      ('is', 'the', 'sicilian'): FreqDist({'tristan': 1}),
#                      ('train', 'line', 'is'): FreqDist({'also': 1, 'to': 1}),
#                      ('council', 'what', 'two'): FreqDist({'things': 1}),
#                      ('do', 'during', 'development'): FreqDist({'are': 1}),
#                      ('republic', 'as', 'which'): FreqDist({'city': 1}),
#                      ('does',
#                       'transformation',
#                       'of'): FreqDist({'bacteria': 1}),
#                      ('other', 'player', 'became'): FreqDist({'eligible': 1}),
#                      ('was', 'the', 'cuban'): FreqDist({'missile': 1}),
#                      ('1987', 'what', 'elected'): FreqDist({'government': 1}),
#                      ('what', 'does', 'emergence'): FreqDist({'of': 1}),
#                      ('feist', 'and', 'wilco'): FreqDist({'along': 1}),
#                      ('green', 'who', 'was'): FreqDist({'the': 1}),
#                      ('did',
#                       'consolidation',
#                       'cause'): FreqDist({'jacksonville': 1}),
#                      ('s', 'battery', 'life'): FreqDist({'claims': 1}),
#                      ('did', 'henry', 'renounce'): FreqDist({'upon': 1}),
#                      ('spouse', 'of', 'an'): FreqDist({'arranged': 1}),
#                      ('reaching', 'the', 'fifa'): FreqDist({'world': 1}),
#                      ('versus', 'a', 'ballroom'): FreqDist({'waltz': 1}),
#                      ('region', 'did', 'la'): FreqDist({'malinche': 1}),
#                      ('news', 'end', 'its'): FreqDist({'print': 1}),
#                      ('build', 'their', 'own'): FreqDist({'stanley': 1}),
#                      ('world', 'kanye', 'was'): FreqDist({'criticized': 1}),
#                      ('rights', 'on', 'mobile'): FreqDist({'phones': 1}),
#                      ('effect', 'what', 'percent'): FreqDist({'of': 1}),
#                      ('year', 'did', 'crown'): FreqDist({'holdings': 1}),
#                      ('the', 'limits', 'set'): FreqDist({'by': 1}),
#                      ('removed',
#                       'what',
#                       'classification'): FreqDist({'of': 1}),
#                      ('english', 'colonists', 'what'): FreqDist({'town': 1}),
#                      ('the', 'lions', 'play'): FreqDist({'what': 1}),
#                      ('of', 'assent', 'if'): FreqDist({'it': 1}),
#                      ('can', 'always', 'be'): FreqDist({'seen': 1}),
#                      ('state', 'fossil', 'when'): FreqDist({'was': 1}),
#                      ('what', 'university', 's'): FreqDist({'facility': 2}),
#                      ('did', 'lok', 'ham'): FreqDist({'chan': 1}),
#                      ('march', '2007', 'the'): FreqDist({'mission': 1}),
#                      ('what', 'gases', 'come'): FreqDist({'from': 2}),
#                      ('to', 'be', 'compared'): FreqDist({'to': 2}),
#                      ('objectives',
#                       'does',
#                       'minority'): FreqDist({'leader': 1}),
#                      ('luther',
#                       'added',
#                       'to'): FreqDist({'antisemitism': 1, 'german': 1}),
#                      ('arab',
#                       'translations',
#                       'primarily'): FreqDist({'focused': 1}),
#                      ('was', 'avicenna', 'known'): FreqDist({'for': 1}),
#                      ('hydrocarbons',
#                       'ended',
#                       'organophospates'): FreqDist({'and': 1}),
#                      ('blue', 'chinese', 'luncheon'): FreqDist({'room': 1}),
#                      ('won', 'all', 'of'): FreqDist({'its': 1, 'nyc': 1}),
#                      ('electric', 'motor', 'what'): FreqDist({'is': 1}),
#                      ('does', 'character', '8'): FreqDist({'represent': 1}),
#                      ('income', 'in', '2007'): FreqDist({'how': 1}),
#                      ('york',
#                       'city',
#                       'annex'): FreqDist({'kingsbridge': 1,
#                                'morrisania': 1,
#                                'part': 2,
#                                'west': 1}),
#                      ('who',
#                       'argues',
#                       'that'): FreqDist({'madaris': 1,
#                                'napoleon': 1,
#                                'the': 3,
#                                'there': 2}),
#                      ('year',
#                       'did',
#                       'he'): FreqDist({'become': 1, 'do': 1, 'gain': 1}),
#                      ('or', 'raise', 'the'): FreqDist({'prices': 1}),
#                      ('method', 'that', 'allowed'): FreqDist({'carbon': 1}),
#                      ('do', 'with', 'how'): FreqDist({'important': 1}),
#                      ('given', 'to', 'describe'): FreqDist({'the': 1}),
#                      ('education',
#                       'institutes',
#                       'tafe'): FreqDist({'tasmania': 1}),
#                      ('of',
#                       'what',
#                       'mountains'): FreqDist({'the': 1, 'what': 1}),
#                      ('had', 'a', 'trade'): FreqDist({'embargo': 1}),
#                      ('game', 'when', 'something'): FreqDist({'is': 1}),
#                      ('and', 'the', 'moon'): FreqDist({'from': 1, 'how': 1}),
#                      ('chandragupta',
#                       'maurya',
#                       'defeat'): FreqDist({'what': 1}),
#                      ('refusing', 'to', 'give'): FreqDist({'up': 1}),
#                      ('executive',
#                       'order',
#                       'that'): FreqDist({'required': 1,
#                                'transferred': 1,
#                                'would': 1}),
#                      ('center', 'was', 'the'): FreqDist({'anglican': 1}),
#                      ('as', 'advertising', 'in'): FreqDist({'what': 1}),
#                      ('critic', 'said', 'that'): FreqDist({'the': 1}),
#                      ('house', 'in', 'd'): FreqDist({'c': 1}),
#                      ('cpus', 'that', 'are'): FreqDist({'constructed': 1}),
#                      ('macintosh', 'to', 'become'): FreqDist({'how': 1}),
#                      ('turbine',
#                       'operate',
#                       'what'): FreqDist({'publication': 1}),
#                      ('illuminationist',
#                       'philosophy',
#                       'ibn'): FreqDist({'al': 1}),
#                      ('returned',
#                       'palermo',
#                       'to'): FreqDist({'christianity': 1}),
#                      ('the', 'talks', 'who'): FreqDist({'was': 1}),
#                      ('the', 'economic', 'bailout'): FreqDist({'agreed': 1}),
#                      ('companies', 'what', 'is'): FreqDist({'the': 2}),
#                      ('byzantines', 'help', 'the'): FreqDist({'khazars': 1}),
#                      ('with', 'the', 'notion'): FreqDist({'of': 1}),
#                      ('for', 'a', 'freight'): FreqDist({'elevator': 1}),
#                      ('the', 'demand', 'besides'): FreqDist({'massive': 1}),
#                      ('branch', 'house', 'how'): FreqDist({'many': 1}),
#                      ('guacho', 'y', 'de'): FreqDist({'la': 1}),
#                      ('exchange', 'how', 'many'): FreqDist({'times': 1}),
#                      ('tennessee', 's', '1st'): FreqDist({'congressional': 1}),
#                      ('it', 'about', 'antarctic'): FreqDist({'meteorites': 1}),
#                      ('of', 'warsaw', 'which'): FreqDist({'divides': 1}),
#                      ('was', 'used', 'previous'): FreqDist({'to': 1}),
#                      ('of', 'science', 'studies'): FreqDist({'the': 1}),
#                      ('in', 'ontario', 'how'): FreqDist({'do': 1}),
#                      ('use', 'of', 'ropes'): FreqDist({'in': 1}),
#                      ('school',
#                       'what',
#                       'is'): FreqDist({'another': 3, 'the': 3}),
#                      ('did', 'abdullah', 'have'): FreqDist({'built': 1}),
#                      ('courses',
#                       'are',
#                       'offered'): FreqDist({'by': 1, 'to': 1}),
#                      ('date', 'did', 'pope'): FreqDist({'paul': 1}),
#                      ('doc', 'works', 'from'): FreqDist({'the': 1}),
#                      ('thing', 'during', 'the'): FreqDist({'cambrian': 1}),
#                      ('music', 'for', 'the'): FreqDist({'film': 1}),
#                      ('was', 'darwin', 'working'): FreqDist({'on': 1}),
#                      ('annex', 'the', 'kingdom'): FreqDist({'of': 1}),
#                      ('blown', 'up', 'by'): FreqDist({'the': 1}),
#                      ('they', 'are', 'eaten'): FreqDist({'by': 1}),
#                      ('reactive',
#                       'oxygen',
#                       'species'): FreqDist({'signals': 1}),
#                      ('to', 'mark', 'on'): FreqDist({'the': 1}),
#                      ('granum', 'what', 'are'): FreqDist({'frets': 1}),
#                      ('juvenile',
#                       'platyctenids',
#                       'live'): FreqDist({'when': 1}),
#                      ('1890', 'census', 'how'): FreqDist({'were': 1}),
#                      ('philadelphia', 'for', 'd'): FreqDist({'c': 1}),
#                      ('were', 'written', 'in'): FreqDist({'what': 1}),
#                      ('what',
#                       'court',
#                       'case'): FreqDist({'affirmed': 1,
#                                'desegregated': 1,
#                                'what': 1}),
#                      ('island', 'in', '1872'): FreqDist({'how': 1}),
#                      ('becomes', 'a', 'concern'): FreqDist({'in': 1}),
#                      ('for', 'cases', 'related'): FreqDist({'to': 1}),
#                      ('most',
#                       'competent',
#                       'serbian'): FreqDist({'scientist': 1}),
#                      ('of', 'greece', 'declare'): FreqDist({'that': 1}),
#                      ('son', 'of', 'al'): FreqDist({'hakam': 1}),
#                      ('misguided',
#                       'and',
#                       'illegitimate'): FreqDist({'who': 1}),
#                      ('sir', 'james', 'weddell'): FreqDist({'command': 1}),
#                      ('play', 'what', 'type'): FreqDist({'of': 1}),
#                      ('was', 'nanjing', 'conquered'): FreqDist({'by': 1}),
#                      ('part', 'in', 'there'): FreqDist({'is': 1}),
#                      ('threat', 'each', 'year'): FreqDist({'to': 1}),
#                      ('want', 'a', 'police'): FreqDist({'force': 1}),
#                      ('the', 'largest', 'snes'): FreqDist({'games': 1}),
#                      ('clans', 'and', 'dukes'): FreqDist({'preceded': 1}),
#                      ('norms', 'what', 'practice'): FreqDist({'was': 1}),
#                      ('of', 'actions', 'against'): FreqDist({'jews': 1}),
#                      ('combined',
#                       'with',
#                       'the'): FreqDist({'field': 1, 'richmond': 1, 'u': 1}),
#                      ('the', 'entire', 'program'): FreqDist({'for': 1}),
#                      ('spectre', 'made', 'in'): FreqDist({'its': 1}),
#                      ('policing', 'where', 'were'): FreqDist({'the': 1}),
#                      ('contributions',
#                       'to',
#                       'health'): FreqDist({'issues': 1}),
#                      ('offensive', 'players', 'who'): FreqDist({'do': 1}),
#                      ('nurse', 'can', 'not'): FreqDist({'help': 1}),
#                      ('because', 'wild', 'and'): FreqDist({'domesticated': 1}),
#                      ('crew', 'killed', 'in'): FreqDist({'1834': 1}),
#                      ('1947', 'what', 'company'): FreqDist({'did': 1}),
#                      ('household', 'water', 'why'): FreqDist({'has': 1}),
#                      ('trend', 'towards', 'what'): FreqDist({'type': 1}),
#                      ('present', 'what', 'is'): FreqDist({'the': 1}),
#                      ('did', 'us', 'ground'): FreqDist({'forces': 1}),
#                      ('the', 'archduke', 'pulled'): FreqDist({'back': 1}),
#                      ('what', 'was', 'rooney'): FreqDist({'s': 1}),
#                      ('mess', 'how', 'many'): FreqDist({'players': 1}),
#                      ('field', 'education', 'and'): FreqDist({'a': 1}),
#                      ('does', 'temperley', 'feel'): FreqDist({'that': 1}),
#                      ('rhythms', 'provided', 'by'): FreqDist({'in': 1}),
#                      ('gomes', 'which', 'explorer'): FreqDist({'sailed': 1}),
#                      ('israel', 'which', 'sized'): FreqDist({'cars': 1}),
#                      ('the',
#                       'large',
#                       'catechism'): FreqDist({'directed': 1, 'what': 1}),
#                      ('expensive', 'quick', 'fixes'): FreqDist({'that': 1}),
#                      ('defunded', 'who', 'had'): FreqDist({'established': 1}),
#                      ('s', 'was', 'helpful'): FreqDist({'in': 1}),
#                      ('of', 'relations', 'what'): FreqDist({'does': 1}),
#                      ('scottish',
#                       'parliament',
#                       'when'): FreqDist({'it': 1, 'was': 1}),
#                      ('for', 'nazi', 'collaboration'): FreqDist({'who': 1}),
#                      ('which', 'is', 'preferred'): FreqDist({'the': 1}),
#                      ('adidas', 'clothing', 'line'): FreqDist({'by': 1}),
#                      ('effect', 'on', 'teen'): FreqDist({'physical': 2}),
#                      ('bjts', 'so', 'popular'): FreqDist({'what': 1}),
#                      ('percent', 'of', 'loans'): FreqDist({'did': 1}),
#                      ('in', 'the', 'hagia'): FreqDist({'sophia': 2}),
#                      ('accepted',
#                       'scientific',
#                       'definition'): FreqDist({'for': 1}),
#                      ('justices', 'for', 'the'): FreqDist({'u': 1}),
#                      ('elevators', 'what', 'is'): FreqDist({'a': 1, 'an': 1}),
#                      ('what',
#                       'settlement',
#                       'featured'): FreqDist({'equal': 1}),
#                      ('approve', 'bedaquiline', 'what'): FreqDist({'type': 1}),
#                      ('has', 'been', 'nominated'): FreqDist({'for': 1}),
#                      ('favorite', 'at', 'live'): FreqDist({'shows': 1}),
#                      ('what', 'do', 'dancers'): FreqDist({'lampoon': 1}),
#                      ('stick', 'insects', 'what'): FreqDist({'kind': 1}),
#                      ('election',
#                       'of',
#                       'the'): FreqDist({'labour': 1,
#                                'new': 1,
#                                'throne': 1,
#                                'u': 1}),
#                      ('in', 'which', 'johannes'): FreqDist({'aavik': 1}),
#                      ('did', 'the', 'automaton'): FreqDist({'mimic': 1}),
#                      ('continue', 'to', 'marry'): FreqDist({'exclusively': 1}),
#                      ('christian', 'ac', 'artists'): FreqDist({'on': 1}),
#                      ('for', 'a', 'humid'): FreqDist({'subtropical': 1}),
#                      ('choice', 'needs', 'to'): FreqDist({'be': 1}),
#                      ('advent', 'of', 'heavier'): FreqDist({'than': 1}),
#                      ('who', 'want', 'content'): FreqDist({'for': 1}),
#                      ('s', 'trade', 'deals'): FreqDist({'what': 1}),
#                      ('philosophies',
#                       'in',
#                       'what'): FreqDist({'centuries': 1}),
#                      ('who', 'was', 'left'): FreqDist({'on': 1}),
#                      ('for', 'older', 'working'): FreqDist({'boys': 1}),
#                      ('s', 'bail', 'bond'): FreqDist({'what': 1}),
#                      ('did', 'the', 'marchers'): FreqDist({'wish': 1}),
#                      ('the',
#                       'philippines',
#                       'who'): FreqDist({'brought': 1, 'led': 1}),
#                      ('s', 'attention', 'back'): FreqDist({'to': 1}),
#                      ('of', 'using', 'equalization'): FreqDist({'devices': 1}),
#                      ('common', 'which', 'major'): FreqDist({'latin': 1}),
#                      ('else', 'could', 'push'): FreqDist({'a': 1}),
#                      ('filed', 'by', 'pat'): FreqDist({'rights': 1}),
#                      ('mass', 'is', 'most'): FreqDist({'of': 1}),
#                      ('how', 'many', 'nights'): FreqDist({'did': 3, 'in': 1}),
#                      ('i', 'assume', 'the'): FreqDist({'role': 1}),
#                      ('do', 'what', 'type'): FreqDist({'of': 3}),
#                      ('season', 'is', 'characterized'): FreqDist({'as': 1}),
#                      ('the', 'same', 'letter'): FreqDist({'which': 1}),
#                      ('recently', 'in', '1861'): FreqDist({'when': 1}),
#                      ('gap', 'was', 'there'): FreqDist({'between': 1}),
#                      ('s', 'car', 'wreck'): FreqDist({'what': 1}),
#                      ('copper', 'what', 'color'): FreqDist({'is': 1}),
#                      ('have', 'a', 'chance'): FreqDist({'to': 1}),
#                      ('cathedral', 'is', 'muster'): FreqDist({'what': 1}),
#                      ('extreme', 'metal', 'in'): FreqDist({'the': 1}),
#                      ('treat', 'thailand', 'is'): FreqDist({'thailand': 1}),
#                      ('edgardo', 'mortara', 'when'): FreqDist({'does': 1}),
#                      ('what', 'locale', 'was'): FreqDist({'used': 1}),
#                      ('ages', 'of', 'what'): FreqDist({'nationality': 1}),
#                      ('s', 'best', 'seller'): FreqDist({'in': 1}),
#                      ('most', 'spoken', 'dialogue'): FreqDist({'in': 1}),
#                      ('id', 'the', 'data'): FreqDist({'rate': 1}),
#                      ('the',
#                       'warsaw',
#                       'pact'): FreqDist({'activated': 1,
#                                'are': 1,
#                                'cease': 1,
#                                'despite': 1,
#                                'dissolution': 1,
#                                'established': 1,
#                                'failed': 1,
#                                'formally': 1,
#                                'how': 1,
#                                'in': 2,
#                                's': 1,
#                                'states': 1,
#                                'war': 1,
#                                'was': 1,
#                                'were': 1,
#                                'what': 2,
#                                'which': 3,
#                                'who': 1}),
#                      ('was', 'the', 'quarterback'): FreqDist({'for': 1}),
#                      ('created', 'in', 'cell'): FreqDist({'phones': 1}),
#                      ('at',
#                       'what',
#                       'establishment'): FreqDist({'did': 1, 'was': 1}),
#                      ('kublai', 's', 'chinese'): FreqDist({'advisers': 1}),
#                      ('antoine', 'lavoisier', 's'): FreqDist({'nickname': 1}),
#                      ('defence', 'who', 'is'): FreqDist({'probably': 1}),
#                      ('inventors', 'developed', 'the'): FreqDist({'first': 1}),
#                      ('station', 'is', 'in'): FreqDist({'san': 2}),
#                      ('until', 'it', 'dissolved'): FreqDist({'in': 1}),
#                      ('field', 'theory', 'suggest'): FreqDist({'what': 1}),
#                      ('become', 'preferred', 'how'): FreqDist({'long': 1}),
#                      ('printed',
#                       'by',
#                       'the'): FreqDist({'average': 1, 'edasi': 1}),
#                      ('an', 'annual', 'crop'): FreqDist({'to': 1}),
#                      ('that', 'doctor', 'who'): FreqDist({'has': 2}),
#                      ('of', 'entertainment', 'was'): FreqDist({'held': 1}),
#                      ('byu', 's', 'origin'): FreqDist({'be': 1}),
#                      ('to', 'antarctica', 'to'): FreqDist({'determine': 1}),
#                      ('1995', 'of', 'a'): FreqDist({'drop': 1}),
#                      ('heritage', 'is', 'referred'): FreqDist({'to': 1}),
#                      ('which', 'magazine', 's'): FreqDist({'cover': 1}),
#                      ('buildings', 'face', 'who'): FreqDist({'did': 1}),
#                      ('s', 'brothers', 'when'): FreqDist({'they': 1}),
#                      ('what', 'american', 'is'): FreqDist({'considered': 1}),
#                      ('the', 'player', 'what'): FreqDist({'type': 1}),
#                      ('did', 'merk', 'sponsor'): FreqDist({'in': 1}),
#                      ('meteorite', 'is', 'beside'): FreqDist({'rare': 1}),
#                      ('world', 'tour', 'for'): FreqDist({'which': 1}),
#                      ('type',
#                       'of',
#                       'oscillation'): FreqDist({'integer': 1, 'pitch': 1}),
#                      ('in',
#                       'australia',
#                       'and'): FreqDist({'canada': 1, 'want': 1, 'wanted': 1}),
#                      ('is', 'damaged', 'from'): FreqDist({'just': 1}),
#                      ('regional',
#                       'romance',
#                       'languages'): FreqDist({'in': 1, 'of': 2}),
#                      ('addition', 'to', 'providing'): FreqDist({'for': 1}),
#                      ('on', 'what', 'contributes'): FreqDist({'to': 1}),
#                      ('british', 'press', 'often'): FreqDist({'showed': 1}),
#                      ('to',
#                       'a',
#                       'particular'): FreqDist({'agent': 1,
#                                'ethnic': 1,
#                                'interpretation': 2}),
#                      ('what', 'rebellion', 'began'): FreqDist({'in': 1}),
#                      ('series', 'have', 'aired'): FreqDist({'since': 1}),
#                      ('s', 'seminal', 'work'): FreqDist({'in': 1}),
#                      ('cross', 'in', 'the'): FreqDist({'hagia': 1}),
#                      ('justify',
#                       'my',
#                       'love'): FreqDist({'reached': 1, 'what': 1}),
#                      ('used', 'now', 'to'): FreqDist({'build': 1, 'group': 1}),
#                      ('can', 'reach', 'the'): FreqDist({'internet': 1}),
#                      ('back', 'to', 'life'): FreqDist({'what': 1}),
#                      ('mass', 'produced', 'product'): FreqDist({'from': 1}),
#                      ('having',
#                       'the',
#                       'highest'): FreqDist({'earnings': 1,
#                                'quality': 1,
#                                'ratings': 1}),
#                      ('nbcuniversal',
#                       'reported',
#                       'what'): FreqDist({'did': 1}),
#                      ('long', 'in', 'total'): FreqDist({'was': 1}),
#                      ('of', 'crop', 'was'): FreqDist({'rice': 1}),
#                      ('the', 'equal', 'partnership'): FreqDist({'s': 1}),
#                      ('rhine', 'first', 'formed'): FreqDist({'a': 1}),
#                      ('that', 'human', 'psychology'): FreqDist({'belongs': 1}),
#                      ('beauty', 'food', 'and'): FreqDist({'drink': 1}),
#                      ('melodramas',
#                       'who',
#                       'produced'): FreqDist({'melodramas': 1}),
#                      ('of', 'grasslands', 'and'): FreqDist({'what': 1}),
#                      ('source', 'what', 'happens'): FreqDist({'to': 1}),
#                      ('areas', 'were', 'shown'): FreqDist({'in': 1}),
#                      ('body', 'a', 'characteristic'): FreqDist({'of': 1}),
#                      ('he', 'and', 'his'): FreqDist({'colleagues': 1}),
#                      ('start',
#                       'doing',
#                       'when'): FreqDist({'accused': 1, 'he': 1}),
#                      ('cia', 'budget', 'in'): FreqDist({'1994': 1}),
#                      ('the', 'first', 'presbytery'): FreqDist({'formed': 1}),
#                      ('as', 'what', 'today'): FreqDist({'the': 1, 'what': 1}),
#                      ('german', 'border', 'what'): FreqDist({'diplomatic': 1}),
#                      ('a', 'browser', 'is'): FreqDist({'called': 1, 'to': 1}),
#                      ('u', 's', 'believe'): FreqDist({'caused': 1, 'that': 1}),
#                      ('world', 'cups', 'has'): FreqDist({'england': 1}),
#                      ('taubman', 'goldie', 'when'): FreqDist({'did': 1}),
#                      ('conventions', 'on', 'the'): FreqDist({'rights': 1}),
#                      ('which', 'other', 'continent'): FreqDist({'at': 1}),
#                      ('of',
#                       'michigan',
#                       'in'): FreqDist({'1967': 1, '1970': 1}),
#                      ('in', 'modern', 'languages'): FreqDist({'words': 1}),
#                      ('mention', 'when', 'jesus'): FreqDist({'died': 1}),
#                      ('come',
#                       'to',
#                       'a'): FreqDist({'close': 1, 'consensus': 1, 'halt': 1}),
#                      ('government', 'pass', 'the'): FreqDist({'ownership': 1}),
#                      ('japanese', 'art', 'collection'): FreqDist({'is': 2}),
#                      ('midwives', 'are', 'listed'): FreqDist({'per': 1}),
#                      ('offensive', 'drive', 'of'): FreqDist({'super': 1}),
#                      ('s',
#                       'ideology',
#                       'what'): FreqDist({'does': 1, 'ideology': 1}),
#                      ('criticism', 'of', 'ipods'): FreqDist({'the': 1}),
#                      ('first', 'non', 'english'): FreqDist({'person': 1}),
#                      ('mine', 'that', 'is'): FreqDist({'unusual': 1}),
#                      ('other', 'people', 'allowed'): FreqDist({'in': 1}),
#                      ('did', 'some', 'liberal'): FreqDist({'politicians': 1}),
#                      ('in', 'the', 'sirens'): FreqDist({'of': 1}),
#                      ('created', 'to', 'carry'): FreqDist({'out': 1}),
#                      ('languages', 'recognized', 'as'): FreqDist({'indo': 1}),
#                      ('with', 'the', 'religion'): FreqDist({'s': 1}),
#                      ('celebration', 'known', 'as'): FreqDist({'in': 1}),
#                      ('materials',
#                       'can',
#                       'be'): FreqDist({'engineered': 1, 'used': 1}),
#                      ('repairs', 'to', 'many'): FreqDist({'of': 1}),
#                      ('the',
#                       'permian',
#                       'triassic'): FreqDist({'extinction': 2}),
#                      ('50', 'bars', 'what'): FreqDist({'clouds': 1}),
#                      ('new', 'military', 'port'): FreqDist({'in': 1}),
#                      ('police',
#                       'whose',
#                       'philosophy'): FreqDist({'influenced': 1}),
#                      ('is', 'the', 'edge'): FreqDist({'of': 1}),
#                      ('do', 'plenary', 'meetings'): FreqDist({'take': 1}),
#                      ('not', 'commercially', 'viable'): FreqDist({'where': 1}),
#                      ('if', 'a', 'west'): FreqDist({'fleming': 1}),
#                      ('and', 'online', 'portals'): FreqDist({'replace': 1}),
#                      ('or', 'acrobatics', 'what'): FreqDist({'is': 1}),
#                      ('people', 'would', 'die'): FreqDist({'of': 1}),
#                      ('fewer', 'of', 'what'): FreqDist({'type': 1}),
#                      ('humanism', 'gain', 'yet'): FreqDist({'another': 1}),
#                      ('broncos', 'in', 'tackles'): FreqDist({'who': 1}),
#                      ('best', 'female', 'video'): FreqDist({'which': 1}),
#                      ('may', 'be', 'harmed'): FreqDist({'who': 1}),
#                      ('1970', 'is', 'available'): FreqDist({'on': 1}),
#                      ('with', 'red', 'caps'): FreqDist({'crowded': 1}),
#                      ('person', 'do', 'as'): FreqDist({'that': 1}),
#                      ('experiment', 'had', 'increased'): FreqDist({'what': 1}),
#                      ('place', 'at', 'which'): FreqDist({'stadium': 1}),
#                      ('troops', 'in', 'their'): FreqDist({'employ': 1}),
#                      ('which', 'people', 'threw'): FreqDist({'rocks': 1}),
#                      ('structure',
#                       'what',
#                       'are'): FreqDist({'the': 1, 'two': 1}),
#                      ('type',
#                       'of',
#                       'electric'): FreqDist({'current': 1, 'power': 1}),
#                      ('along', 'with', 'don'): FreqDist({'t': 1}),
#                      ('with', '150', '000'): FreqDist({'members': 1}),
#                      ('did',
#                       'cuban',
#                       'immigrants'): FreqDist({'introduce': 1}),
#                      ('madonna', 'take', 'voice'): FreqDist({'lessons': 1}),
#                      ('the', 'document', 'affronted'): FreqDist({'by': 1}),
#                      ('in', 'protestantism', 'for'): FreqDist({'morals': 1}),
#                      ('when',
#                       'did',
#                       'commercial'): FreqDist({'production': 1, 'sea': 1}),
#                      ('the', 'two', 'conductors'): FreqDist({'in': 1}),
#                      ('jewish', 'faith', 'what'): FreqDist({'term': 1}),
#                      ('day', 'scotland', 'where'): FreqDist({'did': 1}),
#                      ('of', 'chemistry', 'who'): FreqDist({'supported': 1}),
#                      ('temperament', 'to', 'what'): FreqDist({'level': 1}),
#                      ('two', 'islands', 'in'): FreqDist({'the': 1}),
#                      ('correctly',
#                       'predict',
#                       'blackbody'): FreqDist({'emission': 1}),
#                      ('generators',
#                       'what',
#                       'alternate'): FreqDist({'payment': 1}),
#                      ('every',
#                       '100',
#                       'females'): FreqDist({'age': 2, 'how': 2}),
#                      ('been', 'receiving', 'how'): FreqDist({'much': 1}),
#                      ('what', 'was', 'nikola'): FreqDist({'tesla': 1}),
#                      ('forces', 'occur', 'where'): FreqDist({'was': 1}),
#                      ('cyprus', 'in', 'what'): FreqDist({'year': 1}),
#                      ('in', 'history', 'how'): FreqDist({'did': 1, 'many': 2}),
#                      ('communities',
#                       'with',
#                       'what'): FreqDist({'veneration': 1}),
#                      ('at', 'that', 'point'): FreqDist({'how': 1, 'what': 1}),
#                      ('what', 'what', 'idea'): FreqDist({'states': 1}),
#                      ('elevation',
#                       'that',
#                       'waterfalls'): FreqDist({'first': 1}),
#                      ('as',
#                       'what',
#                       'an'): FreqDist({'adolescent': 1, 'axon': 1}),
#                      ('first', 'tropical', 'aquarium'): FreqDist({'in': 1}),
#                      ('size', 'replica', 'in'): FreqDist({'the': 1}),
#                      ('to', 'visible', 'light'): FreqDist({'how': 1}),
#                      ('a', 'term', 'uses'): FreqDist({'to': 1}),
# ...
#                      ('a', 'champion', 'lose'): FreqDist({'a': 1}),
#                      ('including', 'university', 'town'): FreqDist({'the': 1}),
#                      ('as', 'a', 'movement'): FreqDist({'post': 1, 'what': 1}),
#                      ('most', 'which', 'group'): FreqDist({'of': 1}),
#                      ('was', 'the', 'eton'): FreqDist({'mission': 1}),
#                      ('who', 'enacted', 'a'): FreqDist({'law': 1}),
#                      ('grown', 'by', 'thompson'): FreqDist({'seedless': 1}),
#                      ('the', 'venezuelans', 'settle'): FreqDist({'in': 1}),
#                      ('the', 'report', 'in'): FreqDist({'1958': 1}),
#                      ('fire', 'hazards', 'in'): FreqDist({'the': 1}),
#                      ('at', 'least', '70'): FreqDist({'of': 1}),
#                      ('broadway', 'productions', 'what'): FreqDist({'was': 1}),
#                      ('british',
#                       'colonized',
#                       'africa'): FreqDist({'bassett': 1}),
#                      ('1618', 'resulted', 'in'): FreqDist({'what': 1}),
#                      ('have', 'been', 'its'): FreqDist({'two': 1}),
#                      ('had', 'who', 'started'): FreqDist({'at': 1}),
#                      ('genetic',
#                       'origin',
#                       'testing'): FreqDist({'currently': 1}),
#                      ('historical',
#                       'region',
#                       'in'): FreqDist({'southeastern': 1}),
#                      ('and', 'rule', 'policy'): FreqDist({'what': 1}),
#                      ('major', 'epidemic', 'how'): FreqDist({'many': 1}),
#                      ('have', 'in', 'miles'): FreqDist({'on': 1}),
#                      ('locations', 'in', 'houston'): FreqDist({'what': 1}),
#                      ('way', 'leibniz', 's'): FreqDist({'example': 1}),
#                      ('signed', 'the', 'term'): FreqDist({'great': 1}),
#                      ('of', 'china', 'end'): FreqDist({'how': 1}),
#                      ('on',
#                       'russia',
#                       'who'): FreqDist({'arranged': 1, 'demanded': 1}),
#                      ('what', 'music', 'festival'): FreqDist({'does': 1}),
#                      ('diseases', 'what', 'kind'): FreqDist({'of': 1}),
#                      ('hung', 'what', 'was'): FreqDist({'hung': 1}),
#                      ('england',
#                       's',
#                       'south'): FreqDist({'coast': 1, 'east': 1}),
#                      ('thermal', 'energy', 'in'): FreqDist({'a': 1}),
#                      ('affirmative',
#                       'action',
#                       'which'): FreqDist({'piece': 1}),
#                      ('it', 'affects', 'most'): FreqDist({'in': 1}),
#                      ('other', 'city', 'has'): FreqDist({'hosted': 1}),
#                      ('all', 'these', 'tents'): FreqDist({'and': 1}),
#                      ('current', 'where', 'are'): FreqDist({'the': 1}),
#                      ('are',
#                       'some',
#                       'examples'): FreqDist({'of': 27, 'that': 1}),
#                      ('theocratic',
#                       'organization',
#                       'of'): FreqDist({'jehovah': 1}),
#                      ('function',
#                       'are',
#                       'ribozymes'): FreqDist({'capable': 1}),
#                      ('dominic', 'experience', 'a'): FreqDist({'great': 1}),
#                      ('classification', 'did', 'the'): FreqDist({'world': 1}),
#                      ('does', 'the', 'gastric'): FreqDist({'phase': 1}),
#                      ('greece', 's', 'dark'): FreqDist({'ages': 1}),
#                      ('how',
#                       'many',
#                       'astronauts'): FreqDist({'visited': 1, 'was': 1}),
#                      ('is',
#                       'the',
#                       'conventional'): FreqDist({'measurement': 1,
#                                'method': 1}),
#                      ('exuberant', 'houses', 'slow'): FreqDist({'down': 1}),
#                      ('into',
#                       'what',
#                       'can'): FreqDist({'iron': 1, 'regulatory': 1}),
#                      ('archibald', 'gillespie', 'to'): FreqDist({'lead': 1}),
#                      ('find', 'western', 'instruments'): FreqDist({'what': 1}),
#                      ('eukaryotic',
#                       'organelles',
#                       'contain'): FreqDist({'how': 1}),
#                      ('person', 'who', 'hosted'): FreqDist({'chopin': 1}),
#                      ('a', 'view', 'of'): FreqDist({'what': 2}),
#                      ('the', 'monarch', 'of'): FreqDist({'in': 1}),
#                      ('of',
#                       'legitimate',
#                       'expectations'): FreqDist({'have': 1}),
#                      ('bequeathed',
#                       'his',
#                       'large'): FreqDist({'collection': 1}),
#                      ('ocean', 'railroad', 'what'): FreqDist({'group': 1}),
#                      ('what', 'kilns', 'were'): FreqDist({'longquan': 1}),
#                      ('natural', 'things', 'are'): FreqDist({'less': 1}),
#                      ('dame', 'occur', 'where'): FreqDist({'is': 1}),
#                      ('profession',
#                       'approach',
#                       'efforts'): FreqDist({'to': 1}),
#                      ('spain', 'thinking', 'of'): FreqDist({'doing': 1}),
#                      ('jane', 'series', 'who'): FreqDist({'was': 1}),
#                      ('forces',
#                       'and',
#                       'accelerations'): FreqDist({'explained': 1}),
#                      ('populations',
#                       'what',
#                       'populations'): FreqDist({'is': 1}),
#                      ('not', 'predict', 'accurate'): FreqDist({'at': 1}),
#                      ('chapel', 'street', 'in'): FreqDist({'modern': 1}),
#                      ('largest', 'university', 'press'): FreqDist({'in': 1}),
#                      ('throwing', 'objects', 'and'): FreqDist({'slaps': 1}),
#                      ('of', 'jesus', 'fall'): FreqDist({'what': 1}),
#                      ('africa',
#                       'end',
#                       'occupation'): FreqDist({'in': 1, 'of': 1}),
#                      ('was',
#                       'formed',
#                       'during'): FreqDist({'the': 1, 'what': 1}),
#                      ('most', 'walkable', 'large'): FreqDist({'us': 1}),
#                      ('group', 'located', 'in'): FreqDist({'jacksonville': 1}),
#                      ('tourists', 'does', 'nanjing'): FreqDist({'receive': 1}),
#                      ('promise', 'his', 'followers'): FreqDist({'in': 1}),
#                      ('lost', 'his', 'own'): FreqDist({'state': 1}),
#                      ('type', 'of', 'order'): FreqDist({'was': 1, 'what': 1}),
#                      ('to', 'assimilating', 'into'): FreqDist({'german': 1}),
#                      ('dialect', 'usually', 'not'): FreqDist({'have': 1}),
#                      ('shakespeare',
#                       'scholar',
#                       'is'): FreqDist({'a': 1, 'currently': 1}),
#                      ('are', 'common', 'concepts'): FreqDist({'to': 1}),
#                      ('us', 'military', 'base'): FreqDist({'outside': 1}),
#                      ('from', '1997', 'to'): FreqDist({'2004': 1}),
#                      ('of', 'old', 'and'): FreqDist({'those': 1}),
#                      ('irons', 'in', '1939'): FreqDist({'in': 1}),
#                      ('heredity', 'in', 'the'): FreqDist({'world': 1}),
#                      ('were', 'from', 'yugoslavia'): FreqDist({'itself': 1}),
#                      ('as', 'the', 'kinetic'): FreqDist({'energy': 1}),
#                      ('near', 'what', 'tavern'): FreqDist({'did': 1}),
#                      ('a', 'dbms', 'store'): FreqDist({'a': 1}),
#                      ('until', 'how', 'long'): FreqDist({'did': 1}),
#                      ('macarthur',
#                       's',
#                       'headquarters'): FreqDist({'moved': 1}),
#                      ('tijuana', 'cross', 'border'): FreqDist({'terminal': 1}),
#                      ('radford', 'where', 'was'): FreqDist({'middle': 1}),
#                      ('nigerian',
#                       'christians',
#                       'are'): FreqDist({'catholic': 1,
#                                'orthodox': 1,
#                                'protestant': 1}),
#                      ('trip', 'to', 'malvern'): FreqDist({'hills': 1}),
#                      ('hrf', 'height', 'range'): FreqDist({'finder': 1}),
#                      ('relationships',
#                       'between',
#                       'plants'): FreqDist({'animals': 1}),
#                      ('indicted', 'due', 'to'): FreqDist({'corruption': 1}),
#                      ('engine',
#                       'what',
#                       'is'): FreqDist({'565': 1, 'a': 1, 'the': 3}),
#                      ('brought', 'forward', 'one'): FreqDist({'of': 1}),
#                      ('by', 'what', 'location'): FreqDist({'division': 1}),
#                      ('the', 'lungs', 'infected'): FreqDist({'by': 1}),
#                      ('color', 'what', 'year'): FreqDist({'was': 1}),
#                      ('written', 'who', 'is'): FreqDist({'attributed': 1}),
#                      ('for', 'investors', 'prior'): FreqDist({'to': 1}),
#                      ('supercapacitor',
#                       'has',
#                       'achieved'): FreqDist({'what': 1}),
#                      ('did', 'the', 'instituting'): FreqDist({'of': 1}),
#                      ('boardwalk', 'when', 'did'): FreqDist({'superstorm': 1}),
#                      ('the', 'device', 'assigned'): FreqDist({'a': 1}),
#                      ('amended', 'treaty', 'are'): FreqDist({'bound': 1}),
#                      ('game',
#                       'that',
#                       'is'): FreqDist({'increasingly': 1,
#                                'played': 1,
#                                'popular': 1}),
#                      ('did',
#                       'the',
#                       'french'): FreqDist({'and': 2,
#                                'armies': 1,
#                                'army': 1,
#                                'assault': 1,
#                                'assist': 1,
#                                'attack': 1,
#                                'authorities': 1,
#                                'battalion': 1,
#                                'begin': 1,
#                                'believe': 2,
#                                'best': 1,
#                                'build': 1,
#                                'call': 1,
#                                'capture': 2,
#                                'cross': 1,
#                                'dearth': 1,
#                                'defend': 1,
#                                'emperor': 1,
#                                'empire': 1,
#                                'experience': 1,
#                                'find': 1,
#                                'for': 1,
#                                'foreign': 1,
#                                'german': 1,
#                                'get': 1,
#                                'government': 3,
#                                'guard': 1,
#                                'have': 1,
#                                'hold': 1,
#                                'idealogies': 1,
#                                'incursion': 1,
#                                'jacquerie': 1,
#                                'language': 1,
#                                'lay': 1,
#                                'leave': 1,
#                                'lodges': 1,
#                                'lose': 1,
#                                'military': 1,
#                                'navy': 2,
#                                'obtain': 1,
#                                'parliament': 1,
#                                'plan': 1,
#                                'reach': 1,
#                                'revolution': 2,
#                                'rulers': 1,
#                                'senate': 1,
#                                'send': 1,
#                                'spanish': 1,
#                                'spread': 1,
#                                'start': 1,
#                                'suffer': 4,
#                                'take': 3,
#                                'triump': 1,
#                                'troops': 2,
#                                'try': 1,
#                                'victory': 1,
#                                'want': 1}),
#                      ('when', 'antibiotics', 'are'): FreqDist({'used': 1}),
#                      ('presidential',
#                       'elections',
#                       'what'): FreqDist({'party': 1}),
#                      ('kathmandu', 'valley', 'in'): FreqDist({'the': 1}),
#                      ('device', 'unveiled', 'in'): FreqDist({'what': 1}),
#                      ('vista', 'tract', 'what'): FreqDist({'is': 1}),
#                      ('is', 'the', 'guidebook'): FreqDist({'for': 1}),
#                      ('needed', 'provisions', 'did'): FreqDist({'the': 1}),
#                      ('run', 'research', 'institutions'): FreqDist({'in': 1}),
#                      ('testing', 'the', 'older'): FreqDist({'version': 1}),
#                      ('provision',
#                       'of',
#                       'political'): FreqDist({'killings': 1}),
#                      ('spoken', 'in', 'spanish'): FreqDist({'how': 1}),
#                      ('western',
#                       'churches',
#                       'split'): FreqDist({'what': 1, 'when': 1}),
#                      ('shrine', 'in', 'what'): FreqDist({'city': 1}),
#                      ('founded', 'what', 's'): FreqDist({'southampton': 1}),
#                      ('from', 'the', 'lowest'): FreqDist({'form': 1}),
#                      ('the', 'county', 'furthest'): FreqDist({'south': 1}),
#                      ('a', 'surplus', 'did'): FreqDist({'the': 1}),
#                      ('of', 'arms', 'proper'): FreqDist({'and': 1}),
#                      ('the',
#                       'fujiwara',
#                       's'): FreqDist({'governmental': 1, 'influence': 1}),
#                      ('overpopulation', 'why', 'does'): FreqDist({'a': 1}),
#                      ('nuclear',
#                       'geothermal',
#                       'and'): FreqDist({'internal': 1}),
#                      ('in',
#                       'celsius',
#                       'what'): FreqDist({'current': 1, 'is': 3}),
#                      ('jesus', 'side', 'which'): FreqDist({'gospel': 1}),
#                      ('was', 'oxygen', 'liquefied'): FreqDist({'in': 1}),
#                      ('brought', 'evangelicalism', 'to'): FreqDist({'the': 1}),
#                      ('amendment', 'what', 'is'): FreqDist({'now': 1}),
#                      ('produced', 'soap', 'opera'): FreqDist({'did': 1}),
#                      ('adelines', 'where', 'is'): FreqDist({'the': 1}),
#                      ('did', 'cobb', 'and'): FreqDist({'daly': 1}),
#                      ('what',
#                       'political',
#                       'machine'): FreqDist({'controlled': 1}),
#                      ('was', 'supplied', 'in'): FreqDist({'the': 1}),
#                      ('written', 'sir', 'richard'): FreqDist({'blackmore': 1}),
#                      ('26', 'april', '1841'): FreqDist({'how': 1}),
#                      ('uniqueness',
#                       'of',
#                       'mycobacterium'): FreqDist({'tuberculosis': 1}),
#                      ('evidence', 'has', 'recently'): FreqDist({'been': 1}),
#                      ('the', 'future', 'as'): FreqDist({'claimed': 1}),
#                      ('wembley', 'offer', 'that'): FreqDist({'have': 1}),
#                      ('sites', 'be', 'taken'): FreqDist({'down': 1}),
#                      ('environmentally',
#                       'friendly',
#                       'type'): FreqDist({'of': 1}),
#                      ('frank', 'burnet', 'when'): FreqDist({'he': 1}),
#                      ('cm', 's', 'decent'): FreqDist({'back': 1}),
#                      ...})

# %%
cfdist[("stamp",)]
#did not stamp out the
# Out:
# FreqDist({'out': 2})

# %%
cpdist = ConditionalProbDist(cfdist,MLEProbDist)

# %%
nltk.probability.MLEProbDist.freqdist

# %%
def samples(tup):
    return list(cpdist[tup].samples())
    #print(key)

# %%
samples(("stamp", "out", "the"))
# Out:
# ['local', 'interantional']

# %%
cpdist[("empire", "during", "much")].prob('of')
# Out:
# 1.0

# %%
list(range(4,1,-1))
# Out:
# [4, 3, 2]
